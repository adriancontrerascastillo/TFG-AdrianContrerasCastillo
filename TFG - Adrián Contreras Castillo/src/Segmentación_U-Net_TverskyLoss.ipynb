# %% [markdown]
# # Deep Learning: Laparoscopic segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import random
import cv2
import tensorflow as tf
import keras.backend as K
from skimage import exposure
from skimage.color import rgb2gray
from sklearn.model_selection import train_test_split
from glob import glob
import pickle
import segmentation_models as sm
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: False

# %%
SEED = 17
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)

# %%
# https://gist.github.com/IdeaKing/11cf5e146d23c5bb219ba3508cca89ec
def resize_with_pad(image: np.array, 
                    new_shape, 
                    padding_color = (0, 0, 0)) -> np.array:
    """Maintains aspect ratio and resizes with padding.
    Params:
        image: Image to be resized.
        new_shape: Expected (width, height) of new image.
        padding_color: Tuple in BGR of padding color
    Returns:
        image: Resized image with padding
    """
    original_shape = (image.shape[1], image.shape[0])
    ratio = float(max(new_shape))/max(original_shape)
    new_size = tuple([int(x*ratio) for x in original_shape])
    image = cv2.resize(image, new_size, interpolation=cv2.INTER_NEAREST)
    delta_w = new_shape[0] - new_size[0]
    delta_h = new_shape[1] - new_size[1]
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)
    image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT, value=padding_color)
    return image

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 120:-120,:]
    img = resize_with_pad(img, (HEIGHT, WIDTH))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 120:-120,:]
    mask = resize_with_pad(mask, (HEIGHT, WIDTH), (50, 50, 50))
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx], cmap='afmhot')
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
# dump_data(X, y)
# X, y = load_data()
np.unique(y_encoded[idx])
# Out:
# array([ 0,  2,  3,  4, 10], dtype=uint8)

# %%
plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1), cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## U-Net

# %%
def double_conv_block(x, n_filters):

   # Conv2D then ReLU activation
   x = tf.keras.layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
   # Conv2D then ReLU activation
   x = tf.keras.layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)

   return x

def downsample_block(x, n_filters):
   f = double_conv_block(x, n_filters)
   p = tf.keras.layers.MaxPool2D(2)(f)
   p = tf.keras.layers.Dropout(0.2)(p)

   return f, p

def upsample_block(x, conv_features, n_filters):
   # upsample
   x = tf.keras.layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
   # concatenate
   x = tf.keras.layers.concatenate([x, conv_features])
   # dropout
   x = tf.keras.layers.Dropout(0.2)(x)
   # Conv2D twice with ReLU activation
   x = double_conv_block(x, n_filters)

   return x

def build_unet_model(n_filters=64, n_classes=2):
   # inputs
   inputs = tf.keras.layers.Input(shape=(HEIGHT,WIDTH,3))

   # encoder: contracting path - downsample
   # 1 - downsample
   f1, p1 = downsample_block(inputs, n_filters)
   # 2 - downsample
   f2, p2 = downsample_block(p1, n_filters*2)
   # 3 - downsample
   f3, p3 = downsample_block(p2, n_filters*4)
   # 4 - downsample
   f4, p4 = downsample_block(p3, n_filters*8)

   # 5 - bottleneck
   bottleneck = double_conv_block(p4, n_filters*16)

   # decoder: expanding path - upsample
   # 6 - upsample
   u6 = upsample_block(bottleneck, f4, n_filters*8)
   # 7 - upsample
   u7 = upsample_block(u6, f3, n_filters*4)
   # 8 - upsample
   u8 = upsample_block(u7, f2, n_filters*2)
   # 9 - upsample
   u9 = upsample_block(u8, f1, n_filters)

   # outputs
   
   activation = 'sigmoid' if n_classes == 2 else 'softmax'
   outputs = tf.keras.layers.Conv2D(n_classes, 1, padding="same", activation=activation)(u9)

   # unet model with Keras Functional API
   unet_model = tf.keras.Model(inputs, outputs, name="U-Net")

   return unet_model

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

def dice_loss(y_true, y_pred):
    return 1 - dice_coeficient(y_true, y_pred)

def tversky(y_true, y_pred, smooth=1e-6, alpha=0.75):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)
    TP = tf.keras.backend.sum(T * P)
    FN = tf.keras.backend.sum(T * (1 - P))
    FP = tf.keras.backend.sum((1 - T) * P)
    return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true, y_pred)


def focal_tversky_loss(y_true, y_pred, gamma=0.75):
    tv = tversky(y_true, y_pred)
    return tf.keras.backend.pow((1 - tv), gamma)

def generalized_dice_coeff(y_true, y_pred, smooth=1e-9):
    Ncl = y_pred.shape[-1]
    w = np.zeros((Ncl,))
    w = K.sum(y_true, (0,1,2))
    w = 1 / (w ** 2 + smooth)

    y_pred = tf.nn.softmax(y_pred)

    # Compute gen dice coef:
    numerator = y_true * y_pred
    numerator = w * K.sum(numerator, (0,1,2))
    numerator = K.sum(numerator)

    denominator = y_true + y_pred
    denominator = w * K.sum(denominator, (0,1,2))
    denominator = K.sum(denominator)

    return 2. * (numerator + smooth) / (denominator + smooth)


def generalized_dice_loss(y_true, y_pred):
    return 1. - generalized_dice_coeff(y_true, y_pred)

# %%
unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.load_weights('../models/u-net_39-0.22_tversky_loss.hdf5')
unet_model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4), 
    loss=tversky_loss,
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)

unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 64, 64, 32)   896         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 32)   9248        ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 32)   0           ['conv2d_1[0][0]']
#
#  dropout (Dropout)              (None, 32, 32, 32)   0           ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 64)   18496       ['dropout[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   36928       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)  0           ['conv2d_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 16, 16, 64)   0           ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 128)  73856       ['dropout_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 128)   0           ['conv2d_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 8, 8, 128)    0           ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 8, 8, 256)    295168      ['dropout_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 256)    590080      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 256)   0           ['conv2d_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 4, 4, 256)    0           ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 4, 4, 512)    1180160     ['dropout_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 4, 4, 512)    2359808     ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 8, 8, 256)   1179904     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 8, 8, 512)    0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 8, 8, 512)    0           ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 8, 8, 256)    1179904     ['dropout_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 256)    590080      ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 16, 16, 128)  295040     ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 16, 16, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 16, 16, 256)  0           ['concatenate_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 128)  295040      ['dropout_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 128)  147584      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 32, 32, 64)  73792       ['conv2d_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 32, 32, 128)  0           ['concatenate_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 64)   73792       ['dropout_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 64)   36928       ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 64, 64, 32)  18464       ['conv2d_15[0][0]']
#  spose)
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_3[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  dropout_7 (Dropout)            (None, 64, 64, 64)   0           ['concatenate_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 32)   18464       ['dropout_7[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 32)   9248        ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 13)   429         ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 8,630,893
# Trainable params: 8,630,893
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/u-net_tversky.hdf5',
    verbose=1,
    monitor='val_mean_io_u',
    save_best_only=True,
    save_weights_only=True,
    mode='max'
)

print('\n\t TRAINING\n')

model_history = unet_model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.7587 - mean_io_u: 0.5178 - dice_coeficient: 0.2431
# Epoch 1: val_mean_io_u improved from -inf to 0.59744, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 413s 8s/step - loss: 0.7587 - mean_io_u: 0.5178 - dice_coeficient: 0.2431 - val_loss: 0.5478 - val_mean_io_u: 0.5974 - val_dice_coeficient: 0.4528
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5116 - mean_io_u: 0.6216 - dice_coeficient: 0.4886
# Epoch 2: val_mean_io_u improved from 0.59744 to 0.62964, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 440s 9s/step - loss: 0.5116 - mean_io_u: 0.6216 - dice_coeficient: 0.4886 - val_loss: 0.4881 - val_mean_io_u: 0.6296 - val_dice_coeficient: 0.5126
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4810 - mean_io_u: 0.6346 - dice_coeficient: 0.5190
# Epoch 3: val_mean_io_u did not improve from 0.62964
# 51/51 [==============================] - 444s 9s/step - loss: 0.4810 - mean_io_u: 0.6346 - dice_coeficient: 0.5190 - val_loss: 0.4764 - val_mean_io_u: 0.6213 - val_dice_coeficient: 0.5242
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4681 - mean_io_u: 0.6382 - dice_coeficient: 0.5317
# Epoch 4: val_mean_io_u did not improve from 0.62964
# 51/51 [==============================] - 441s 9s/step - loss: 0.4681 - mean_io_u: 0.6382 - dice_coeficient: 0.5317 - val_loss: 0.4688 - val_mean_io_u: 0.6230 - val_dice_coeficient: 0.5318
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4625 - mean_io_u: 0.6438 - dice_coeficient: 0.5374
# Epoch 5: val_mean_io_u improved from 0.62964 to 0.63082, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 445s 9s/step - loss: 0.4625 - mean_io_u: 0.6438 - dice_coeficient: 0.5374 - val_loss: 0.4637 - val_mean_io_u: 0.6308 - val_dice_coeficient: 0.5370
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4597 - mean_io_u: 0.6466 - dice_coeficient: 0.5405
# Epoch 6: val_mean_io_u improved from 0.63082 to 0.63714, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 450s 9s/step - loss: 0.4597 - mean_io_u: 0.6466 - dice_coeficient: 0.5405 - val_loss: 0.4598 - val_mean_io_u: 0.6371 - val_dice_coeficient: 0.5409
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4580 - mean_io_u: 0.6486 - dice_coeficient: 0.5421
# Epoch 7: val_mean_io_u improved from 0.63714 to 0.64027, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 450s 9s/step - loss: 0.4580 - mean_io_u: 0.6486 - dice_coeficient: 0.5421 - val_loss: 0.4584 - val_mean_io_u: 0.6403 - val_dice_coeficient: 0.5423
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4569 - mean_io_u: 0.6500 - dice_coeficient: 0.5434
# Epoch 8: val_mean_io_u did not improve from 0.64027
# 51/51 [==============================] - 404s 8s/step - loss: 0.4569 - mean_io_u: 0.6500 - dice_coeficient: 0.5434 - val_loss: 0.4589 - val_mean_io_u: 0.6393 - val_dice_coeficient: 0.5418
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4563 - mean_io_u: 0.6516 - dice_coeficient: 0.5435
# Epoch 9: val_mean_io_u improved from 0.64027 to 0.64240, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 382s 8s/step - loss: 0.4563 - mean_io_u: 0.6516 - dice_coeficient: 0.5435 - val_loss: 0.4571 - val_mean_io_u: 0.6424 - val_dice_coeficient: 0.5436
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4556 - mean_io_u: 0.6529 - dice_coeficient: 0.5444
# Epoch 10: val_mean_io_u improved from 0.64240 to 0.64321, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 404s 8s/step - loss: 0.4556 - mean_io_u: 0.6529 - dice_coeficient: 0.5444 - val_loss: 0.4568 - val_mean_io_u: 0.6432 - val_dice_coeficient: 0.5439
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4551 - mean_io_u: 0.6536 - dice_coeficient: 0.5449
# Epoch 11: val_mean_io_u improved from 0.64321 to 0.64796, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 410s 8s/step - loss: 0.4551 - mean_io_u: 0.6536 - dice_coeficient: 0.5449 - val_loss: 0.4556 - val_mean_io_u: 0.6480 - val_dice_coeficient: 0.5451
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4541 - mean_io_u: 0.6541 - dice_coeficient: 0.5458
# Epoch 12: val_mean_io_u did not improve from 0.64796
# 51/51 [==============================] - 420s 8s/step - loss: 0.4541 - mean_io_u: 0.6541 - dice_coeficient: 0.5458 - val_loss: 0.4546 - val_mean_io_u: 0.6476 - val_dice_coeficient: 0.5461
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4329 - mean_io_u: 0.6646 - dice_coeficient: 0.5673
# Epoch 13: val_mean_io_u improved from 0.64796 to 0.68447, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 445s 9s/step - loss: 0.4329 - mean_io_u: 0.6646 - dice_coeficient: 0.5673 - val_loss: 0.3915 - val_mean_io_u: 0.6845 - val_dice_coeficient: 0.6090
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3795 - mean_io_u: 0.6971 - dice_coeficient: 0.6207
# Epoch 14: val_mean_io_u improved from 0.68447 to 0.70322, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 431s 8s/step - loss: 0.3795 - mean_io_u: 0.6971 - dice_coeficient: 0.6207 - val_loss: 0.3706 - val_mean_io_u: 0.7032 - val_dice_coeficient: 0.6299
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3319 - mean_io_u: 0.7248 - dice_coeficient: 0.6684
# Epoch 15: val_mean_io_u improved from 0.70322 to 0.77003, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 407s 8s/step - loss: 0.3319 - mean_io_u: 0.7248 - dice_coeficient: 0.6684 - val_loss: 0.2715 - val_mean_io_u: 0.7700 - val_dice_coeficient: 0.7294
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2620 - mean_io_u: 0.7720 - dice_coeficient: 0.7384
# Epoch 16: val_mean_io_u did not improve from 0.77003
# 51/51 [==============================] - 431s 8s/step - loss: 0.2620 - mean_io_u: 0.7720 - dice_coeficient: 0.7384 - val_loss: 0.2435 - val_mean_io_u: 0.7667 - val_dice_coeficient: 0.7573
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2395 - mean_io_u: 0.7739 - dice_coeficient: 0.7608
# Epoch 17: val_mean_io_u improved from 0.77003 to 0.77346, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 411s 8s/step - loss: 0.2395 - mean_io_u: 0.7739 - dice_coeficient: 0.7608 - val_loss: 0.2384 - val_mean_io_u: 0.7735 - val_dice_coeficient: 0.7624
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2184 - mean_io_u: 0.7850 - dice_coeficient: 0.7819
# Epoch 18: val_mean_io_u improved from 0.77346 to 0.80741, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 407s 8s/step - loss: 0.2184 - mean_io_u: 0.7850 - dice_coeficient: 0.7819 - val_loss: 0.1785 - val_mean_io_u: 0.8074 - val_dice_coeficient: 0.8223
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1748 - mean_io_u: 0.8175 - dice_coeficient: 0.8252
# Epoch 19: val_mean_io_u improved from 0.80741 to 0.82041, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 406s 8s/step - loss: 0.1748 - mean_io_u: 0.8175 - dice_coeficient: 0.8252 - val_loss: 0.1739 - val_mean_io_u: 0.8204 - val_dice_coeficient: 0.8269
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1715 - mean_io_u: 0.8232 - dice_coeficient: 0.8286
# Epoch 20: val_mean_io_u improved from 0.82041 to 0.82285, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 409s 8s/step - loss: 0.1715 - mean_io_u: 0.8232 - dice_coeficient: 0.8286 - val_loss: 0.1711 - val_mean_io_u: 0.8228 - val_dice_coeficient: 0.8296
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1698 - mean_io_u: 0.8255 - dice_coeficient: 0.8302
# Epoch 21: val_mean_io_u improved from 0.82285 to 0.82647, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 407s 8s/step - loss: 0.1698 - mean_io_u: 0.8255 - dice_coeficient: 0.8302 - val_loss: 0.1684 - val_mean_io_u: 0.8265 - val_dice_coeficient: 0.8323
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1687 - mean_io_u: 0.8274 - dice_coeficient: 0.8313
# Epoch 22: val_mean_io_u improved from 0.82647 to 0.82696, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.1687 - mean_io_u: 0.8274 - dice_coeficient: 0.8313 - val_loss: 0.1672 - val_mean_io_u: 0.8270 - val_dice_coeficient: 0.8335
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1676 - mean_io_u: 0.8288 - dice_coeficient: 0.8321
# Epoch 23: val_mean_io_u improved from 0.82696 to 0.82801, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 444s 9s/step - loss: 0.1676 - mean_io_u: 0.8288 - dice_coeficient: 0.8321 - val_loss: 0.1666 - val_mean_io_u: 0.8280 - val_dice_coeficient: 0.8341
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1671 - mean_io_u: 0.8299 - dice_coeficient: 0.8328
# Epoch 24: val_mean_io_u improved from 0.82801 to 0.82903, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 440s 9s/step - loss: 0.1671 - mean_io_u: 0.8299 - dice_coeficient: 0.8328 - val_loss: 0.1664 - val_mean_io_u: 0.8290 - val_dice_coeficient: 0.8344
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1665 - mean_io_u: 0.8307 - dice_coeficient: 0.8334
# Epoch 25: val_mean_io_u improved from 0.82903 to 0.83019, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 443s 9s/step - loss: 0.1665 - mean_io_u: 0.8307 - dice_coeficient: 0.8334 - val_loss: 0.1653 - val_mean_io_u: 0.8302 - val_dice_coeficient: 0.8354
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1660 - mean_io_u: 0.8311 - dice_coeficient: 0.8340
# Epoch 26: val_mean_io_u did not improve from 0.83019
# 51/51 [==============================] - 439s 9s/step - loss: 0.1660 - mean_io_u: 0.8311 - dice_coeficient: 0.8340 - val_loss: 0.1657 - val_mean_io_u: 0.8298 - val_dice_coeficient: 0.8350
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1655 - mean_io_u: 0.8319 - dice_coeficient: 0.8346
# Epoch 27: val_mean_io_u improved from 0.83019 to 0.83182, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 442s 9s/step - loss: 0.1655 - mean_io_u: 0.8319 - dice_coeficient: 0.8346 - val_loss: 0.1646 - val_mean_io_u: 0.8318 - val_dice_coeficient: 0.8361
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1650 - mean_io_u: 0.8326 - dice_coeficient: 0.8351
# Epoch 28: val_mean_io_u improved from 0.83182 to 0.83299, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 444s 9s/step - loss: 0.1650 - mean_io_u: 0.8326 - dice_coeficient: 0.8351 - val_loss: 0.1638 - val_mean_io_u: 0.8330 - val_dice_coeficient: 0.8369
# Epoch 29/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1646 - mean_io_u: 0.8330 - dice_coeficient: 0.8355
# Epoch 29: val_mean_io_u did not improve from 0.83299
# 51/51 [==============================] - 424s 8s/step - loss: 0.1646 - mean_io_u: 0.8330 - dice_coeficient: 0.8355 - val_loss: 0.1641 - val_mean_io_u: 0.8330 - val_dice_coeficient: 0.8366
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1642 - mean_io_u: 0.8339 - dice_coeficient: 0.8357
# Epoch 30: val_mean_io_u did not improve from 0.83299
# 51/51 [==============================] - 404s 8s/step - loss: 0.1642 - mean_io_u: 0.8339 - dice_coeficient: 0.8357 - val_loss: 0.1643 - val_mean_io_u: 0.8329 - val_dice_coeficient: 0.8364
# Epoch 31/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1639 - mean_io_u: 0.8338 - dice_coeficient: 0.8363
# Epoch 31: val_mean_io_u improved from 0.83299 to 0.83364, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 402s 8s/step - loss: 0.1639 - mean_io_u: 0.8338 - dice_coeficient: 0.8363 - val_loss: 0.1632 - val_mean_io_u: 0.8336 - val_dice_coeficient: 0.8376
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1637 - mean_io_u: 0.8342 - dice_coeficient: 0.8362
# Epoch 32: val_mean_io_u improved from 0.83364 to 0.83404, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 403s 8s/step - loss: 0.1637 - mean_io_u: 0.8342 - dice_coeficient: 0.8362 - val_loss: 0.1632 - val_mean_io_u: 0.8340 - val_dice_coeficient: 0.8375
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1635 - mean_io_u: 0.8347 - dice_coeficient: 0.8368
# Epoch 33: val_mean_io_u improved from 0.83404 to 0.83411, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 403s 8s/step - loss: 0.1635 - mean_io_u: 0.8347 - dice_coeficient: 0.8368 - val_loss: 0.1631 - val_mean_io_u: 0.8341 - val_dice_coeficient: 0.8376
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1631 - mean_io_u: 0.8350 - dice_coeficient: 0.8369
# Epoch 34: val_mean_io_u improved from 0.83411 to 0.83503, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 402s 8s/step - loss: 0.1631 - mean_io_u: 0.8350 - dice_coeficient: 0.8369 - val_loss: 0.1624 - val_mean_io_u: 0.8350 - val_dice_coeficient: 0.8384
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1629 - mean_io_u: 0.8351 - dice_coeficient: 0.8371
# Epoch 35: val_mean_io_u did not improve from 0.83503
# 51/51 [==============================] - 402s 8s/step - loss: 0.1629 - mean_io_u: 0.8351 - dice_coeficient: 0.8371 - val_loss: 0.1625 - val_mean_io_u: 0.8350 - val_dice_coeficient: 0.8382
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1625 - mean_io_u: 0.8356 - dice_coeficient: 0.8375
# Epoch 36: val_mean_io_u improved from 0.83503 to 0.83587, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 402s 8s/step - loss: 0.1625 - mean_io_u: 0.8356 - dice_coeficient: 0.8375 - val_loss: 0.1620 - val_mean_io_u: 0.8359 - val_dice_coeficient: 0.8387
# Epoch 37/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1624 - mean_io_u: 0.8359 - dice_coeficient: 0.8375
# Epoch 37: val_mean_io_u did not improve from 0.83587
# 51/51 [==============================] - 405s 8s/step - loss: 0.1624 - mean_io_u: 0.8359 - dice_coeficient: 0.8375 - val_loss: 0.1620 - val_mean_io_u: 0.8358 - val_dice_coeficient: 0.8387
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1621 - mean_io_u: 0.8359 - dice_coeficient: 0.8380
# Epoch 38: val_mean_io_u did not improve from 0.83587
# 51/51 [==============================] - 402s 8s/step - loss: 0.1621 - mean_io_u: 0.8359 - dice_coeficient: 0.8380 - val_loss: 0.1617 - val_mean_io_u: 0.8354 - val_dice_coeficient: 0.8390
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1621 - mean_io_u: 0.8362 - dice_coeficient: 0.8380
# Epoch 39: val_mean_io_u did not improve from 0.83587
# 51/51 [==============================] - 403s 8s/step - loss: 0.1621 - mean_io_u: 0.8362 - dice_coeficient: 0.8380 - val_loss: 0.1616 - val_mean_io_u: 0.8350 - val_dice_coeficient: 0.8392
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1617 - mean_io_u: 0.8364 - dice_coeficient: 0.8383
# Epoch 40: val_mean_io_u improved from 0.83587 to 0.83630, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 403s 8s/step - loss: 0.1617 - mean_io_u: 0.8364 - dice_coeficient: 0.8383 - val_loss: 0.1615 - val_mean_io_u: 0.8363 - val_dice_coeficient: 0.8392
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1617 - mean_io_u: 0.8368 - dice_coeficient: 0.8382
# Epoch 41: val_mean_io_u did not improve from 0.83630
# 51/51 [==============================] - 402s 8s/step - loss: 0.1617 - mean_io_u: 0.8368 - dice_coeficient: 0.8382 - val_loss: 0.1616 - val_mean_io_u: 0.8353 - val_dice_coeficient: 0.8391
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1615 - mean_io_u: 0.8369 - dice_coeficient: 0.8386
# Epoch 42: val_mean_io_u did not improve from 0.83630
# 51/51 [==============================] - 402s 8s/step - loss: 0.1615 - mean_io_u: 0.8369 - dice_coeficient: 0.8386 - val_loss: 0.1620 - val_mean_io_u: 0.8358 - val_dice_coeficient: 0.8387
# Epoch 43/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1614 - mean_io_u: 0.8372 - dice_coeficient: 0.8388
# Epoch 43: val_mean_io_u improved from 0.83630 to 0.83714, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 400s 8s/step - loss: 0.1614 - mean_io_u: 0.8372 - dice_coeficient: 0.8388 - val_loss: 0.1606 - val_mean_io_u: 0.8371 - val_dice_coeficient: 0.8401
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1612 - mean_io_u: 0.8371 - dice_coeficient: 0.8389
# Epoch 44: val_mean_io_u did not improve from 0.83714
# 51/51 [==============================] - 399s 8s/step - loss: 0.1612 - mean_io_u: 0.8371 - dice_coeficient: 0.8389 - val_loss: 0.1612 - val_mean_io_u: 0.8368 - val_dice_coeficient: 0.8395
# Epoch 45/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1610 - mean_io_u: 0.8371 - dice_coeficient: 0.8388
# Epoch 45: val_mean_io_u did not improve from 0.83714
# 51/51 [==============================] - 397s 8s/step - loss: 0.1610 - mean_io_u: 0.8371 - dice_coeficient: 0.8388 - val_loss: 0.1606 - val_mean_io_u: 0.8369 - val_dice_coeficient: 0.8401
# Epoch 46/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1609 - mean_io_u: 0.8375 - dice_coeficient: 0.8390
# Epoch 46: val_mean_io_u did not improve from 0.83714
# 51/51 [==============================] - 402s 8s/step - loss: 0.1609 - mean_io_u: 0.8375 - dice_coeficient: 0.8390 - val_loss: 0.1612 - val_mean_io_u: 0.8364 - val_dice_coeficient: 0.8395
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1609 - mean_io_u: 0.8373 - dice_coeficient: 0.8389
# Epoch 47: val_mean_io_u improved from 0.83714 to 0.83724, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 391s 8s/step - loss: 0.1609 - mean_io_u: 0.8373 - dice_coeficient: 0.8389 - val_loss: 0.1604 - val_mean_io_u: 0.8372 - val_dice_coeficient: 0.8403
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1607 - mean_io_u: 0.8378 - dice_coeficient: 0.8392
# Epoch 48: val_mean_io_u improved from 0.83724 to 0.83747, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 391s 8s/step - loss: 0.1607 - mean_io_u: 0.8378 - dice_coeficient: 0.8392 - val_loss: 0.1603 - val_mean_io_u: 0.8375 - val_dice_coeficient: 0.8404
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1605 - mean_io_u: 0.8378 - dice_coeficient: 0.8393
# Epoch 49: val_mean_io_u did not improve from 0.83747
# 51/51 [==============================] - 390s 8s/step - loss: 0.1605 - mean_io_u: 0.8378 - dice_coeficient: 0.8393 - val_loss: 0.1605 - val_mean_io_u: 0.8367 - val_dice_coeficient: 0.8402
# Epoch 50/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1604 - mean_io_u: 0.8378 - dice_coeficient: 0.8396
# Epoch 50: val_mean_io_u did not improve from 0.83747
# 51/51 [==============================] - 396s 8s/step - loss: 0.1604 - mean_io_u: 0.8378 - dice_coeficient: 0.8396 - val_loss: 0.1605 - val_mean_io_u: 0.8373 - val_dice_coeficient: 0.8403
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1602 - mean_io_u: 0.8385 - dice_coeficient: 0.8398
# Epoch 51: val_mean_io_u improved from 0.83747 to 0.83802, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 400s 8s/step - loss: 0.1602 - mean_io_u: 0.8385 - dice_coeficient: 0.8398 - val_loss: 0.1603 - val_mean_io_u: 0.8380 - val_dice_coeficient: 0.8404
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1601 - mean_io_u: 0.8383 - dice_coeficient: 0.8397
# Epoch 52: val_mean_io_u did not improve from 0.83802
# 51/51 [==============================] - 399s 8s/step - loss: 0.1601 - mean_io_u: 0.8383 - dice_coeficient: 0.8397 - val_loss: 0.1606 - val_mean_io_u: 0.8375 - val_dice_coeficient: 0.8401
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1600 - mean_io_u: 0.8383 - dice_coeficient: 0.8400
# Epoch 53: val_mean_io_u did not improve from 0.83802
# 51/51 [==============================] - 398s 8s/step - loss: 0.1600 - mean_io_u: 0.8383 - dice_coeficient: 0.8400 - val_loss: 0.1605 - val_mean_io_u: 0.8369 - val_dice_coeficient: 0.8402
# Epoch 54/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1601 - mean_io_u: 0.8383 - dice_coeficient: 0.8401
# Epoch 54: val_mean_io_u did not improve from 0.83802
# 51/51 [==============================] - 398s 8s/step - loss: 0.1601 - mean_io_u: 0.8383 - dice_coeficient: 0.8401 - val_loss: 0.1603 - val_mean_io_u: 0.8370 - val_dice_coeficient: 0.8404
# Epoch 55/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1599 - mean_io_u: 0.8388 - dice_coeficient: 0.8400
# Epoch 55: val_mean_io_u improved from 0.83802 to 0.83852, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 399s 8s/step - loss: 0.1599 - mean_io_u: 0.8388 - dice_coeficient: 0.8400 - val_loss: 0.1598 - val_mean_io_u: 0.8385 - val_dice_coeficient: 0.8409
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1598 - mean_io_u: 0.8390 - dice_coeficient: 0.8404
# Epoch 56: val_mean_io_u did not improve from 0.83852
# 51/51 [==============================] - 399s 8s/step - loss: 0.1598 - mean_io_u: 0.8390 - dice_coeficient: 0.8404 - val_loss: 0.1600 - val_mean_io_u: 0.8378 - val_dice_coeficient: 0.8407
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1597 - mean_io_u: 0.8395 - dice_coeficient: 0.8403
# Epoch 57: val_mean_io_u did not improve from 0.83852
# 51/51 [==============================] - 397s 8s/step - loss: 0.1597 - mean_io_u: 0.8395 - dice_coeficient: 0.8403 - val_loss: 0.1601 - val_mean_io_u: 0.8375 - val_dice_coeficient: 0.8406
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1596 - mean_io_u: 0.8392 - dice_coeficient: 0.8404
# Epoch 58: val_mean_io_u improved from 0.83852 to 0.83891, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 399s 8s/step - loss: 0.1596 - mean_io_u: 0.8392 - dice_coeficient: 0.8404 - val_loss: 0.1598 - val_mean_io_u: 0.8389 - val_dice_coeficient: 0.8410
# Epoch 59/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1595 - mean_io_u: 0.8396 - dice_coeficient: 0.8405
# Epoch 59: val_mean_io_u improved from 0.83891 to 0.83959, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 398s 8s/step - loss: 0.1595 - mean_io_u: 0.8396 - dice_coeficient: 0.8405 - val_loss: 0.1598 - val_mean_io_u: 0.8396 - val_dice_coeficient: 0.8409
# Epoch 60/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1594 - mean_io_u: 0.8398 - dice_coeficient: 0.8407
# Epoch 60: val_mean_io_u did not improve from 0.83959
# 51/51 [==============================] - 398s 8s/step - loss: 0.1594 - mean_io_u: 0.8398 - dice_coeficient: 0.8407 - val_loss: 0.1598 - val_mean_io_u: 0.8388 - val_dice_coeficient: 0.8409
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1594 - mean_io_u: 0.8399 - dice_coeficient: 0.8405
# Epoch 61: val_mean_io_u did not improve from 0.83959
# 51/51 [==============================] - 398s 8s/step - loss: 0.1594 - mean_io_u: 0.8399 - dice_coeficient: 0.8405 - val_loss: 0.1595 - val_mean_io_u: 0.8386 - val_dice_coeficient: 0.8412
# Epoch 62/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1593 - mean_io_u: 0.8401 - dice_coeficient: 0.8407
# Epoch 62: val_mean_io_u did not improve from 0.83959
# 51/51 [==============================] - 398s 8s/step - loss: 0.1593 - mean_io_u: 0.8401 - dice_coeficient: 0.8407 - val_loss: 0.1598 - val_mean_io_u: 0.8390 - val_dice_coeficient: 0.8409
# Epoch 63/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1592 - mean_io_u: 0.8401 - dice_coeficient: 0.8406
# Epoch 63: val_mean_io_u did not improve from 0.83959
# 51/51 [==============================] - 398s 8s/step - loss: 0.1592 - mean_io_u: 0.8401 - dice_coeficient: 0.8406 - val_loss: 0.1596 - val_mean_io_u: 0.8386 - val_dice_coeficient: 0.8411
# Epoch 64/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1592 - mean_io_u: 0.8404 - dice_coeficient: 0.8408
# Epoch 64: val_mean_io_u did not improve from 0.83959
# 51/51 [==============================] - 402s 8s/step - loss: 0.1592 - mean_io_u: 0.8404 - dice_coeficient: 0.8408 - val_loss: 0.1595 - val_mean_io_u: 0.8383 - val_dice_coeficient: 0.8412
# Epoch 65/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1590 - mean_io_u: 0.8404 - dice_coeficient: 0.8411
# Epoch 65: val_mean_io_u did not improve from 0.83959
# 51/51 [==============================] - 396s 8s/step - loss: 0.1590 - mean_io_u: 0.8404 - dice_coeficient: 0.8411 - val_loss: 0.1598 - val_mean_io_u: 0.8394 - val_dice_coeficient: 0.8409
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1590 - mean_io_u: 0.8407 - dice_coeficient: 0.8412
# Epoch 66: val_mean_io_u improved from 0.83959 to 0.83990, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 395s 8s/step - loss: 0.1590 - mean_io_u: 0.8407 - dice_coeficient: 0.8412 - val_loss: 0.1593 - val_mean_io_u: 0.8399 - val_dice_coeficient: 0.8414
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1590 - mean_io_u: 0.8408 - dice_coeficient: 0.8411
# Epoch 67: val_mean_io_u improved from 0.83990 to 0.83994, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 395s 8s/step - loss: 0.1590 - mean_io_u: 0.8408 - dice_coeficient: 0.8411 - val_loss: 0.1593 - val_mean_io_u: 0.8399 - val_dice_coeficient: 0.8414
# Epoch 68/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1588 - mean_io_u: 0.8410 - dice_coeficient: 0.8413
# Epoch 68: val_mean_io_u did not improve from 0.83994
# 51/51 [==============================] - 394s 8s/step - loss: 0.1588 - mean_io_u: 0.8410 - dice_coeficient: 0.8413 - val_loss: 0.1596 - val_mean_io_u: 0.8387 - val_dice_coeficient: 0.8411
# Epoch 69/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1588 - mean_io_u: 0.8414 - dice_coeficient: 0.8411
# Epoch 69: val_mean_io_u did not improve from 0.83994
# 51/51 [==============================] - 396s 8s/step - loss: 0.1588 - mean_io_u: 0.8414 - dice_coeficient: 0.8411 - val_loss: 0.1593 - val_mean_io_u: 0.8399 - val_dice_coeficient: 0.8414
# Epoch 70/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1588 - mean_io_u: 0.8415 - dice_coeficient: 0.8412
# Epoch 70: val_mean_io_u improved from 0.83994 to 0.84014, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 397s 8s/step - loss: 0.1588 - mean_io_u: 0.8415 - dice_coeficient: 0.8412 - val_loss: 0.1593 - val_mean_io_u: 0.8401 - val_dice_coeficient: 0.8414
# Epoch 71/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1587 - mean_io_u: 0.8415 - dice_coeficient: 0.8413
# Epoch 71: val_mean_io_u improved from 0.84014 to 0.84052, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 394s 8s/step - loss: 0.1587 - mean_io_u: 0.8415 - dice_coeficient: 0.8413 - val_loss: 0.1590 - val_mean_io_u: 0.8405 - val_dice_coeficient: 0.8417
# Epoch 72/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1586 - mean_io_u: 0.8414 - dice_coeficient: 0.8411
# Epoch 72: val_mean_io_u did not improve from 0.84052
# 51/51 [==============================] - 394s 8s/step - loss: 0.1586 - mean_io_u: 0.8414 - dice_coeficient: 0.8411 - val_loss: 0.1589 - val_mean_io_u: 0.8404 - val_dice_coeficient: 0.8418
# Epoch 73/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1586 - mean_io_u: 0.8421 - dice_coeficient: 0.8414
# Epoch 73: val_mean_io_u improved from 0.84052 to 0.84153, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 396s 8s/step - loss: 0.1586 - mean_io_u: 0.8421 - dice_coeficient: 0.8414 - val_loss: 0.1591 - val_mean_io_u: 0.8415 - val_dice_coeficient: 0.8416
# Epoch 74/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1585 - mean_io_u: 0.8423 - dice_coeficient: 0.8415
# Epoch 74: val_mean_io_u did not improve from 0.84153
# 51/51 [==============================] - 394s 8s/step - loss: 0.1585 - mean_io_u: 0.8423 - dice_coeficient: 0.8415 - val_loss: 0.1590 - val_mean_io_u: 0.8409 - val_dice_coeficient: 0.8417
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1585 - mean_io_u: 0.8423 - dice_coeficient: 0.8415
# Epoch 75: val_mean_io_u improved from 0.84153 to 0.84190, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 394s 8s/step - loss: 0.1585 - mean_io_u: 0.8423 - dice_coeficient: 0.8415 - val_loss: 0.1591 - val_mean_io_u: 0.8419 - val_dice_coeficient: 0.8416
# Epoch 76/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1584 - mean_io_u: 0.8427 - dice_coeficient: 0.8414
# Epoch 76: val_mean_io_u did not improve from 0.84190
# 51/51 [==============================] - 394s 8s/step - loss: 0.1584 - mean_io_u: 0.8427 - dice_coeficient: 0.8414 - val_loss: 0.1591 - val_mean_io_u: 0.8413 - val_dice_coeficient: 0.8416
# Epoch 77/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1583 - mean_io_u: 0.8430 - dice_coeficient: 0.8415
# Epoch 77: val_mean_io_u improved from 0.84190 to 0.84212, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 393s 8s/step - loss: 0.1583 - mean_io_u: 0.8430 - dice_coeficient: 0.8415 - val_loss: 0.1592 - val_mean_io_u: 0.8421 - val_dice_coeficient: 0.8415
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1584 - mean_io_u: 0.8432 - dice_coeficient: 0.8415
# Epoch 78: val_mean_io_u did not improve from 0.84212
# 51/51 [==============================] - 395s 8s/step - loss: 0.1584 - mean_io_u: 0.8432 - dice_coeficient: 0.8415 - val_loss: 0.1590 - val_mean_io_u: 0.8412 - val_dice_coeficient: 0.8417
# Epoch 79/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1583 - mean_io_u: 0.8431 - dice_coeficient: 0.8415
# Epoch 79: val_mean_io_u did not improve from 0.84212
# 51/51 [==============================] - 396s 8s/step - loss: 0.1583 - mean_io_u: 0.8431 - dice_coeficient: 0.8415 - val_loss: 0.1590 - val_mean_io_u: 0.8421 - val_dice_coeficient: 0.8417
# Epoch 80/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1583 - mean_io_u: 0.8433 - dice_coeficient: 0.8418
# Epoch 80: val_mean_io_u did not improve from 0.84212
# 51/51 [==============================] - 394s 8s/step - loss: 0.1583 - mean_io_u: 0.8433 - dice_coeficient: 0.8418 - val_loss: 0.1587 - val_mean_io_u: 0.8419 - val_dice_coeficient: 0.8420
# Epoch 81/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1582 - mean_io_u: 0.8435 - dice_coeficient: 0.8416
# Epoch 81: val_mean_io_u improved from 0.84212 to 0.84359, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 396s 8s/step - loss: 0.1582 - mean_io_u: 0.8435 - dice_coeficient: 0.8416 - val_loss: 0.1587 - val_mean_io_u: 0.8436 - val_dice_coeficient: 0.8420
# Epoch 82/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1581 - mean_io_u: 0.8440 - dice_coeficient: 0.8419
# Epoch 82: val_mean_io_u did not improve from 0.84359
# 51/51 [==============================] - 397s 8s/step - loss: 0.1581 - mean_io_u: 0.8440 - dice_coeficient: 0.8419 - val_loss: 0.1589 - val_mean_io_u: 0.8426 - val_dice_coeficient: 0.8418
# Epoch 83/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1581 - mean_io_u: 0.8442 - dice_coeficient: 0.8418
# Epoch 83: val_mean_io_u did not improve from 0.84359
# 51/51 [==============================] - 396s 8s/step - loss: 0.1581 - mean_io_u: 0.8442 - dice_coeficient: 0.8418 - val_loss: 0.1586 - val_mean_io_u: 0.8433 - val_dice_coeficient: 0.8421
# Epoch 84/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1580 - mean_io_u: 0.8444 - dice_coeficient: 0.8419
# Epoch 84: val_mean_io_u did not improve from 0.84359
# 51/51 [==============================] - 396s 8s/step - loss: 0.1580 - mean_io_u: 0.8444 - dice_coeficient: 0.8419 - val_loss: 0.1586 - val_mean_io_u: 0.8435 - val_dice_coeficient: 0.8421
# Epoch 85/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1580 - mean_io_u: 0.8446 - dice_coeficient: 0.8418
# Epoch 85: val_mean_io_u did not improve from 0.84359
# 51/51 [==============================] - 394s 8s/step - loss: 0.1580 - mean_io_u: 0.8446 - dice_coeficient: 0.8418 - val_loss: 0.1588 - val_mean_io_u: 0.8431 - val_dice_coeficient: 0.8419
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1579 - mean_io_u: 0.8445 - dice_coeficient: 0.8420
# Epoch 86: val_mean_io_u did not improve from 0.84359
# 51/51 [==============================] - 395s 8s/step - loss: 0.1579 - mean_io_u: 0.8445 - dice_coeficient: 0.8420 - val_loss: 0.1586 - val_mean_io_u: 0.8434 - val_dice_coeficient: 0.8421
# Epoch 87/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1580 - mean_io_u: 0.8445 - dice_coeficient: 0.8421
# Epoch 87: val_mean_io_u improved from 0.84359 to 0.84369, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 394s 8s/step - loss: 0.1580 - mean_io_u: 0.8445 - dice_coeficient: 0.8421 - val_loss: 0.1584 - val_mean_io_u: 0.8437 - val_dice_coeficient: 0.8423
# Epoch 88/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1579 - mean_io_u: 0.8453 - dice_coeficient: 0.8420
# Epoch 88: val_mean_io_u improved from 0.84369 to 0.84488, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 396s 8s/step - loss: 0.1579 - mean_io_u: 0.8453 - dice_coeficient: 0.8420 - val_loss: 0.1584 - val_mean_io_u: 0.8449 - val_dice_coeficient: 0.8423
# Epoch 89/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1554 - mean_io_u: 0.8422 - dice_coeficient: 0.8448
# Epoch 89: val_mean_io_u did not improve from 0.84488
# 51/51 [==============================] - 393s 8s/step - loss: 0.1554 - mean_io_u: 0.8422 - dice_coeficient: 0.8448 - val_loss: 0.1283 - val_mean_io_u: 0.8367 - val_dice_coeficient: 0.8722
# Epoch 90/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1080 - mean_io_u: 0.8649 - dice_coeficient: 0.8920
# Epoch 90: val_mean_io_u improved from 0.84488 to 0.87523, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 399s 8s/step - loss: 0.1080 - mean_io_u: 0.8649 - dice_coeficient: 0.8920 - val_loss: 0.1015 - val_mean_io_u: 0.8752 - val_dice_coeficient: 0.8990
# Epoch 91/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0992 - mean_io_u: 0.8770 - dice_coeficient: 0.9007
# Epoch 91: val_mean_io_u improved from 0.87523 to 0.87657, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 397s 8s/step - loss: 0.0992 - mean_io_u: 0.8770 - dice_coeficient: 0.9007 - val_loss: 0.0998 - val_mean_io_u: 0.8766 - val_dice_coeficient: 0.9006
# Epoch 92/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0978 - mean_io_u: 0.8794 - dice_coeficient: 0.9025
# Epoch 92: val_mean_io_u improved from 0.87657 to 0.87923, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 395s 8s/step - loss: 0.0978 - mean_io_u: 0.8794 - dice_coeficient: 0.9025 - val_loss: 0.0979 - val_mean_io_u: 0.8792 - val_dice_coeficient: 0.9025
# Epoch 93/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0969 - mean_io_u: 0.8811 - dice_coeficient: 0.9032
# Epoch 93: val_mean_io_u improved from 0.87923 to 0.88173, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 396s 8s/step - loss: 0.0969 - mean_io_u: 0.8811 - dice_coeficient: 0.9032 - val_loss: 0.0976 - val_mean_io_u: 0.8817 - val_dice_coeficient: 0.9028
# Epoch 94/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0964 - mean_io_u: 0.8829 - dice_coeficient: 0.9035
# Epoch 94: val_mean_io_u did not improve from 0.88173
# 51/51 [==============================] - 395s 8s/step - loss: 0.0964 - mean_io_u: 0.8829 - dice_coeficient: 0.9035 - val_loss: 0.0976 - val_mean_io_u: 0.8807 - val_dice_coeficient: 0.9028
# Epoch 95/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0960 - mean_io_u: 0.8836 - dice_coeficient: 0.9040
# Epoch 95: val_mean_io_u improved from 0.88173 to 0.88395, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 394s 8s/step - loss: 0.0960 - mean_io_u: 0.8836 - dice_coeficient: 0.9040 - val_loss: 0.0969 - val_mean_io_u: 0.8839 - val_dice_coeficient: 0.9036
# Epoch 96/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0956 - mean_io_u: 0.8850 - dice_coeficient: 0.9044
# Epoch 96: val_mean_io_u improved from 0.88395 to 0.88424, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 396s 8s/step - loss: 0.0956 - mean_io_u: 0.8850 - dice_coeficient: 0.9044 - val_loss: 0.0968 - val_mean_io_u: 0.8842 - val_dice_coeficient: 0.9036
# Epoch 97/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0954 - mean_io_u: 0.8851 - dice_coeficient: 0.9047
# Epoch 97: val_mean_io_u did not improve from 0.88424
# 51/51 [==============================] - 400s 8s/step - loss: 0.0954 - mean_io_u: 0.8851 - dice_coeficient: 0.9047 - val_loss: 0.0967 - val_mean_io_u: 0.8839 - val_dice_coeficient: 0.9037
# Epoch 98/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0952 - mean_io_u: 0.8864 - dice_coeficient: 0.9045
# Epoch 98: val_mean_io_u improved from 0.88424 to 0.88504, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 399s 8s/step - loss: 0.0952 - mean_io_u: 0.8864 - dice_coeficient: 0.9045 - val_loss: 0.0964 - val_mean_io_u: 0.8850 - val_dice_coeficient: 0.9040
# Epoch 99/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0951 - mean_io_u: 0.8863 - dice_coeficient: 0.9048
# Epoch 99: val_mean_io_u improved from 0.88504 to 0.88550, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 399s 8s/step - loss: 0.0951 - mean_io_u: 0.8863 - dice_coeficient: 0.9048 - val_loss: 0.0965 - val_mean_io_u: 0.8855 - val_dice_coeficient: 0.9039
# Epoch 100/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0950 - mean_io_u: 0.8873 - dice_coeficient: 0.9049
# Epoch 100: val_mean_io_u improved from 0.88550 to 0.88671, saving model to ../models\u-net_tversky.hdf5
# 51/51 [==============================] - 401s 8s/step - loss: 0.0950 - mean_io_u: 0.8873 - dice_coeficient: 0.9049 - val_loss: 0.0963 - val_mean_io_u: 0.8867 - val_dice_coeficient: 0.9042

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='lower right')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/u-net_100epochs.hdf5')

# %%
pred = unet_model.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 20s 377ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1), cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx], cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
# --
# **TFG - Adrián Contreras Castillo**
# --
