# %% [markdown]
# # Deep Learning: Laparoscopic segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import random
import cv2
import tensorflow as tf
import keras.backend as K
from skimage import exposure
from skimage.color import rgb2gray
from sklearn.model_selection import train_test_split
from glob import glob
import pickle
import segmentation_models as sm
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: False

# %%
SEED = 17
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)
CLASS_WEIGHTS = [2.45780159e-01, 2.24610010e-01, 2.24005501e-01, 1.87119512e-02,
 1.46965911e-01, 2.54698498e-02, 2.35562466e-02, 4.28713053e-03,
 3.93593665e-04, 1.38500705e-02, 6.78984614e-02, 1.01436955e-04,
 4.36967906e-03]

# %%
# https://gist.github.com/IdeaKing/11cf5e146d23c5bb219ba3508cca89ec
def resize_with_pad(image: np.array, 
                    new_shape, 
                    padding_color = (0, 0, 0)) -> np.array:
    """Maintains aspect ratio and resizes with padding.
    Params:
        image: Image to be resized.
        new_shape: Expected (width, height) of new image.
        padding_color: Tuple in BGR of padding color
    Returns:
        image: Resized image with padding
    """
    original_shape = (image.shape[1], image.shape[0])
    ratio = float(max(new_shape))/max(original_shape)
    new_size = tuple([int(x*ratio) for x in original_shape])
    image = cv2.resize(image, new_size, interpolation=cv2.INTER_NEAREST)
    delta_w = new_shape[0] - new_size[0]
    delta_h = new_shape[1] - new_size[1]
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)
    image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT, value=padding_color)
    return image

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 120:-120,:]
    img = resize_with_pad(img, (HEIGHT, WIDTH))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 120:-120,:]
    mask = resize_with_pad(mask, (HEIGHT, WIDTH), (50, 50, 50))
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx], cmap='afmhot')
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
# dump_data(X, y)
# X, y = load_data()
np.unique(y_encoded[idx])
# Out:
# array([ 0,  2,  3,  4, 10], dtype=uint8)

# %%
plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1), cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## U-Net

# %%
def double_conv_block(x, n_filters):

   # Conv2D then ReLU activation
   x = tf.keras.layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
   # Conv2D then ReLU activation
   x = tf.keras.layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)

   return x

def downsample_block(x, n_filters):
   f = double_conv_block(x, n_filters)
   p = tf.keras.layers.MaxPool2D(2)(f)
   p = tf.keras.layers.BatchNormalization()(p)
   p = tf.keras.layers.Dropout(0.2)(p)

   return f, p

def upsample_block(x, conv_features, n_filters):
   # upsample
   x = tf.keras.layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
   # concatenate
   x = tf.keras.layers.concatenate([x, conv_features])
   # dropout
   x = tf.keras.layers.BatchNormalization()(x)
   x = tf.keras.layers.Dropout(0.2)(x)
   # Conv2D twice with ReLU activation
   x = double_conv_block(x, n_filters)

   return x

def build_unet_model(n_filters=64, n_classes=2):
   # inputs
   inputs = tf.keras.layers.Input(shape=(HEIGHT,WIDTH,3))

   # encoder: contracting path - downsample
   # 1 - downsample
   f1, p1 = downsample_block(inputs, n_filters)
   # 2 - downsample
   f2, p2 = downsample_block(p1, n_filters*2)
   # 3 - downsample
   f3, p3 = downsample_block(p2, n_filters*4)
   # 4 - downsample
   f4, p4 = downsample_block(p3, n_filters*8)

   # 5 - bottleneck
   bottleneck = double_conv_block(p4, n_filters*16)

   # decoder: expanding path - upsample
   # 6 - upsample
   u6 = upsample_block(bottleneck, f4, n_filters*8)
   # 7 - upsample
   u7 = upsample_block(u6, f3, n_filters*4)
   # 8 - upsample
   u8 = upsample_block(u7, f2, n_filters*2)
   # 9 - upsample
   u9 = upsample_block(u8, f1, n_filters)

   # outputs
   
   activation = 'sigmoid' if n_classes == 2 else 'softmax'
   outputs = tf.keras.layers.Conv2D(n_classes, 1, padding="same", activation=activation)(u9)

   # unet model with Keras Functional API
   unet_model = tf.keras.Model(inputs, outputs, name="U-Net")

   return unet_model

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

def dice_loss(y_true, y_pred):
    return 1 - dice_coeficient(y_true, y_pred)

def tversky(y_true, y_pred, smooth=1e-6, alpha=0.75):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)
    TP = tf.keras.backend.sum(T * P)
    FN = tf.keras.backend.sum(T * (1 - P))
    FP = tf.keras.backend.sum((1 - T) * P)
    return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true, y_pred)


def focal_tversky_loss(y_true, y_pred, gamma=0.75):
    tv = tversky(y_true, y_pred)
    return tf.keras.backend.pow((1 - tv), gamma)

def generalized_dice_coeff(y_true, y_pred, smooth=1e-9):
    Ncl = y_pred.shape[-1]
    w = np.zeros((Ncl,))
    w = K.sum(y_true, (0,1,2))
    w = 1 / (w ** 2 + smooth)

    y_pred = tf.nn.softmax(y_pred)

    # Compute gen dice coef:
    numerator = y_true * y_pred
    numerator = w * K.sum(numerator, (0,1,2))
    numerator = K.sum(numerator)

    denominator = y_true + y_pred
    denominator = w * K.sum(denominator, (0,1,2))
    denominator = K.sum(denominator)

    return 2. * (numerator + smooth) / (denominator + smooth)


def generalized_dice_loss(y_true, y_pred):
    return 1. - generalized_dice_coeff(y_true, y_pred)

# %%
unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.load_weights('../models/u-net_39-0.22_tversky_loss.hdf5')
unet_model.compile(
    optimizer=tf.keras.optimizers.Adam(5e-4), 
    loss=sm.losses.DiceLoss(class_weights=CLASS_WEIGHTS),
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)

unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   9248        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 32)   128         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   18496       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16, 64)   256         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 128)  147584      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 128)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 8, 8, 128)    512         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 128)    0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 256)    295168      dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 256)    590080      conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 256)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 4, 4, 256)    1024        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 4, 4, 256)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 512)    1180160     dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 512)    2359808     conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 256)    1179904     conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 512)    0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 512)    2048        concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 512)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 256)    1179904     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 128)  295040      conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 256)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 256)  1024        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  295040      dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 64)   73792       conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 128)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 128)  512         concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 64)   73792       dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 64)   36928       conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 32)   18464       conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 64)   0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 64)   256         concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 32)   18464       dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 32)   9248        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 13)   429         conv2d_17[0][0]
# ==================================================================================================
# Total params: 8,636,653
# Trainable params: 8,633,773
# Non-trainable params: 2,880
# __________________________________________________________________________________________________

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/u-net-BN_diceLoss.hdf5',
    verbose=1,
    monitor='val_mean_io_u',
    save_best_only=True,
    save_weights_only=True,
    mode='max'
)

print('\n\t TRAINING\n')

model_history = unet_model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - 529s 10s/step - loss: 0.9555 - mean_io_u: 0.4642 - dice_coeficient: 0.6224 - val_loss: 0.9712 - val_mean_io_u: 0.4616 - val_dice_coeficient: 0.3743
#
# Epoch 00001: val_mean_io_u improved from -inf to 0.46160, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 2/100
# 51/51 [==============================] - 538s 11s/step - loss: 0.9407 - mean_io_u: 0.5143 - dice_coeficient: 0.7986 - val_loss: 0.9773 - val_mean_io_u: 0.4615 - val_dice_coeficient: 0.3935
#
# Epoch 00002: val_mean_io_u did not improve from 0.46160
# Epoch 3/100
# 51/51 [==============================] - 475s 9s/step - loss: 0.9388 - mean_io_u: 0.5909 - dice_coeficient: 0.8114 - val_loss: 0.9738 - val_mean_io_u: 0.4616 - val_dice_coeficient: 0.4565
#
# Epoch 00003: val_mean_io_u did not improve from 0.46160
# Epoch 4/100
# 51/51 [==============================] - 465s 9s/step - loss: 0.9379 - mean_io_u: 0.6326 - dice_coeficient: 0.8200 - val_loss: 0.9694 - val_mean_io_u: 0.4618 - val_dice_coeficient: 0.4984
#
# Epoch 00004: val_mean_io_u improved from 0.46160 to 0.46179, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 5/100
# 51/51 [==============================] - 9731s 194s/step - loss: 0.9375 - mean_io_u: 0.6612 - dice_coeficient: 0.8244 - val_loss: 0.9587 - val_mean_io_u: 0.4719 - val_dice_coeficient: 0.5855
#
# Epoch 00005: val_mean_io_u improved from 0.46179 to 0.47189, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 6/100
# 51/51 [==============================] - 462s 9s/step - loss: 0.9373 - mean_io_u: 0.6855 - dice_coeficient: 0.8271 - val_loss: 0.9476 - val_mean_io_u: 0.4934 - val_dice_coeficient: 0.7038
#
# Epoch 00006: val_mean_io_u improved from 0.47189 to 0.49343, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 7/100
# 51/51 [==============================] - 1036s 21s/step - loss: 0.9372 - mean_io_u: 0.6978 - dice_coeficient: 0.8286 - val_loss: 0.9436 - val_mean_io_u: 0.5430 - val_dice_coeficient: 0.7506
#
# Epoch 00007: val_mean_io_u improved from 0.49343 to 0.54301, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 8/100
# 51/51 [==============================] - 510s 10s/step - loss: 0.9370 - mean_io_u: 0.6948 - dice_coeficient: 0.8304 - val_loss: 0.9400 - val_mean_io_u: 0.5710 - val_dice_coeficient: 0.7916
#
# Epoch 00008: val_mean_io_u improved from 0.54301 to 0.57103, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 9/100
# 51/51 [==============================] - 459s 9s/step - loss: 0.9363 - mean_io_u: 0.7128 - dice_coeficient: 0.8375 - val_loss: 0.9377 - val_mean_io_u: 0.6277 - val_dice_coeficient: 0.8173
#
# Epoch 00009: val_mean_io_u improved from 0.57103 to 0.62774, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 10/100
# 51/51 [==============================] - 34036s 681s/step - loss: 0.9359 - mean_io_u: 0.7599 - dice_coeficient: 0.8423 - val_loss: 0.9362 - val_mean_io_u: 0.6849 - val_dice_coeficient: 0.8355
#
# Epoch 00010: val_mean_io_u improved from 0.62774 to 0.68490, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 11/100
# 51/51 [==============================] - 492s 10s/step - loss: 0.9358 - mean_io_u: 0.7696 - dice_coeficient: 0.8433 - val_loss: 0.9359 - val_mean_io_u: 0.7280 - val_dice_coeficient: 0.8398
#
# Epoch 00011: val_mean_io_u improved from 0.68490 to 0.72798, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 12/100
# 51/51 [==============================] - 508s 10s/step - loss: 0.9357 - mean_io_u: 0.7765 - dice_coeficient: 0.8439 - val_loss: 0.9358 - val_mean_io_u: 0.7511 - val_dice_coeficient: 0.8414
#
# Epoch 00012: val_mean_io_u improved from 0.72798 to 0.75112, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 13/100
# 51/51 [==============================] - 495s 10s/step - loss: 0.9356 - mean_io_u: 0.7809 - dice_coeficient: 0.8445 - val_loss: 0.9356 - val_mean_io_u: 0.7678 - val_dice_coeficient: 0.8442
#
# Epoch 00013: val_mean_io_u improved from 0.75112 to 0.76780, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 14/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9356 - mean_io_u: 0.7864 - dice_coeficient: 0.8452 - val_loss: 0.9356 - val_mean_io_u: 0.7802 - val_dice_coeficient: 0.8447
#
# Epoch 00014: val_mean_io_u improved from 0.76780 to 0.78022, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 15/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9355 - mean_io_u: 0.7917 - dice_coeficient: 0.8458 - val_loss: 0.9355 - val_mean_io_u: 0.7896 - val_dice_coeficient: 0.8439
#
# Epoch 00015: val_mean_io_u improved from 0.78022 to 0.78955, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 16/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9355 - mean_io_u: 0.7956 - dice_coeficient: 0.8462 - val_loss: 0.9355 - val_mean_io_u: 0.7915 - val_dice_coeficient: 0.8451
#
# Epoch 00016: val_mean_io_u improved from 0.78955 to 0.79151, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 17/100
# 51/51 [==============================] - 500s 10s/step - loss: 0.9355 - mean_io_u: 0.8005 - dice_coeficient: 0.8469 - val_loss: 0.9354 - val_mean_io_u: 0.8043 - val_dice_coeficient: 0.8464
#
# Epoch 00017: val_mean_io_u improved from 0.79151 to 0.80432, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 18/100
# 51/51 [==============================] - 504s 10s/step - loss: 0.9354 - mean_io_u: 0.8037 - dice_coeficient: 0.8470 - val_loss: 0.9354 - val_mean_io_u: 0.8077 - val_dice_coeficient: 0.8467
#
# Epoch 00018: val_mean_io_u improved from 0.80432 to 0.80765, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 19/100
# 51/51 [==============================] - 498s 10s/step - loss: 0.9354 - mean_io_u: 0.8070 - dice_coeficient: 0.8474 - val_loss: 0.9354 - val_mean_io_u: 0.8085 - val_dice_coeficient: 0.8467
#
# Epoch 00019: val_mean_io_u improved from 0.80765 to 0.80849, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 20/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9354 - mean_io_u: 0.8099 - dice_coeficient: 0.8478 - val_loss: 0.9353 - val_mean_io_u: 0.8088 - val_dice_coeficient: 0.8473
#
# Epoch 00020: val_mean_io_u improved from 0.80849 to 0.80884, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 21/100
# 51/51 [==============================] - 495s 10s/step - loss: 0.9354 - mean_io_u: 0.8127 - dice_coeficient: 0.8478 - val_loss: 0.9353 - val_mean_io_u: 0.8149 - val_dice_coeficient: 0.8480
#
# Epoch 00021: val_mean_io_u improved from 0.80884 to 0.81486, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 22/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9353 - mean_io_u: 0.8153 - dice_coeficient: 0.8481 - val_loss: 0.9353 - val_mean_io_u: 0.8219 - val_dice_coeficient: 0.8484
#
# Epoch 00022: val_mean_io_u improved from 0.81486 to 0.82187, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 23/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9353 - mean_io_u: 0.8169 - dice_coeficient: 0.8481 - val_loss: 0.9353 - val_mean_io_u: 0.8228 - val_dice_coeficient: 0.8495
#
# Epoch 00023: val_mean_io_u improved from 0.82187 to 0.82280, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 24/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9353 - mean_io_u: 0.8189 - dice_coeficient: 0.8486 - val_loss: 0.9353 - val_mean_io_u: 0.8209 - val_dice_coeficient: 0.8491
#
# Epoch 00024: val_mean_io_u did not improve from 0.82280
# Epoch 25/100
# 51/51 [==============================] - 499s 10s/step - loss: 0.9353 - mean_io_u: 0.8207 - dice_coeficient: 0.8487 - val_loss: 0.9352 - val_mean_io_u: 0.8247 - val_dice_coeficient: 0.8490
#
# Epoch 00025: val_mean_io_u improved from 0.82280 to 0.82472, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 26/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9353 - mean_io_u: 0.8223 - dice_coeficient: 0.8489 - val_loss: 0.9352 - val_mean_io_u: 0.8245 - val_dice_coeficient: 0.8490
#
# Epoch 00026: val_mean_io_u did not improve from 0.82472
# Epoch 27/100
# 51/51 [==============================] - 495s 10s/step - loss: 0.9353 - mean_io_u: 0.8248 - dice_coeficient: 0.8492 - val_loss: 0.9352 - val_mean_io_u: 0.8301 - val_dice_coeficient: 0.8493
#
# Epoch 00027: val_mean_io_u improved from 0.82472 to 0.83010, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 28/100
# 51/51 [==============================] - 521s 10s/step - loss: 0.9352 - mean_io_u: 0.8248 - dice_coeficient: 0.8494 - val_loss: 0.9352 - val_mean_io_u: 0.8225 - val_dice_coeficient: 0.8489
#
# Epoch 00028: val_mean_io_u did not improve from 0.83010
# Epoch 29/100
# 51/51 [==============================] - 543s 11s/step - loss: 0.9352 - mean_io_u: 0.8256 - dice_coeficient: 0.8496 - val_loss: 0.9352 - val_mean_io_u: 0.8270 - val_dice_coeficient: 0.8488
#
# Epoch 00029: val_mean_io_u did not improve from 0.83010
# Epoch 30/100
# 51/51 [==============================] - 538s 11s/step - loss: 0.9348 - mean_io_u: 0.8239 - dice_coeficient: 0.8540 - val_loss: 0.9340 - val_mean_io_u: 0.8305 - val_dice_coeficient: 0.8604
#
# Epoch 00030: val_mean_io_u improved from 0.83010 to 0.83051, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 31/100
# 51/51 [==============================] - 540s 11s/step - loss: 0.9336 - mean_io_u: 0.8341 - dice_coeficient: 0.8686 - val_loss: 0.9335 - val_mean_io_u: 0.8344 - val_dice_coeficient: 0.8674
#
# Epoch 00031: val_mean_io_u improved from 0.83051 to 0.83442, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 32/100
# 51/51 [==============================] - 538s 11s/step - loss: 0.9335 - mean_io_u: 0.8385 - dice_coeficient: 0.8698 - val_loss: 0.9335 - val_mean_io_u: 0.8392 - val_dice_coeficient: 0.8681
#
# Epoch 00032: val_mean_io_u improved from 0.83442 to 0.83922, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 33/100
# 51/51 [==============================] - 538s 11s/step - loss: 0.9335 - mean_io_u: 0.8403 - dice_coeficient: 0.8706 - val_loss: 0.9335 - val_mean_io_u: 0.8425 - val_dice_coeficient: 0.8692
#
# Epoch 00033: val_mean_io_u improved from 0.83922 to 0.84247, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 34/100
# 51/51 [==============================] - 511s 10s/step - loss: 0.9334 - mean_io_u: 0.8427 - dice_coeficient: 0.8708 - val_loss: 0.9334 - val_mean_io_u: 0.8432 - val_dice_coeficient: 0.8694
#
# Epoch 00034: val_mean_io_u improved from 0.84247 to 0.84322, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 35/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9334 - mean_io_u: 0.8442 - dice_coeficient: 0.8710 - val_loss: 0.9334 - val_mean_io_u: 0.8421 - val_dice_coeficient: 0.8681
#
# Epoch 00035: val_mean_io_u did not improve from 0.84322
# Epoch 36/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9334 - mean_io_u: 0.8450 - dice_coeficient: 0.8713 - val_loss: 0.9334 - val_mean_io_u: 0.8446 - val_dice_coeficient: 0.8697
#
# Epoch 00036: val_mean_io_u improved from 0.84322 to 0.84457, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 37/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9334 - mean_io_u: 0.8468 - dice_coeficient: 0.8713 - val_loss: 0.9334 - val_mean_io_u: 0.8507 - val_dice_coeficient: 0.8698
#
# Epoch 00037: val_mean_io_u improved from 0.84457 to 0.85069, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 38/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9334 - mean_io_u: 0.8479 - dice_coeficient: 0.8716 - val_loss: 0.9334 - val_mean_io_u: 0.8484 - val_dice_coeficient: 0.8689
#
# Epoch 00038: val_mean_io_u did not improve from 0.85069
# Epoch 39/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9334 - mean_io_u: 0.8495 - dice_coeficient: 0.8717 - val_loss: 0.9334 - val_mean_io_u: 0.8482 - val_dice_coeficient: 0.8697
#
# Epoch 00039: val_mean_io_u did not improve from 0.85069
# Epoch 40/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9333 - mean_io_u: 0.8510 - dice_coeficient: 0.8719 - val_loss: 0.9333 - val_mean_io_u: 0.8559 - val_dice_coeficient: 0.8703
#
# Epoch 00040: val_mean_io_u improved from 0.85069 to 0.85589, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 41/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9333 - mean_io_u: 0.8521 - dice_coeficient: 0.8722 - val_loss: 0.9333 - val_mean_io_u: 0.8504 - val_dice_coeficient: 0.8704
#
# Epoch 00041: val_mean_io_u did not improve from 0.85589
# Epoch 42/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9333 - mean_io_u: 0.8538 - dice_coeficient: 0.8723 - val_loss: 0.9333 - val_mean_io_u: 0.8543 - val_dice_coeficient: 0.8705
#
# Epoch 00042: val_mean_io_u did not improve from 0.85589
# Epoch 43/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9333 - mean_io_u: 0.8537 - dice_coeficient: 0.8724 - val_loss: 0.9334 - val_mean_io_u: 0.8545 - val_dice_coeficient: 0.8701
#
# Epoch 00043: val_mean_io_u did not improve from 0.85589
# Epoch 44/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9333 - mean_io_u: 0.8544 - dice_coeficient: 0.8725 - val_loss: 0.9333 - val_mean_io_u: 0.8561 - val_dice_coeficient: 0.8704
#
# Epoch 00044: val_mean_io_u improved from 0.85589 to 0.85611, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 45/100
# 51/51 [==============================] - 498s 10s/step - loss: 0.9333 - mean_io_u: 0.8561 - dice_coeficient: 0.8724 - val_loss: 0.9333 - val_mean_io_u: 0.8576 - val_dice_coeficient: 0.8708
#
# Epoch 00045: val_mean_io_u improved from 0.85611 to 0.85757, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 46/100
# 51/51 [==============================] - 501s 10s/step - loss: 0.9333 - mean_io_u: 0.8562 - dice_coeficient: 0.8725 - val_loss: 0.9333 - val_mean_io_u: 0.8558 - val_dice_coeficient: 0.8701
#
# Epoch 00046: val_mean_io_u did not improve from 0.85757
# Epoch 47/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9333 - mean_io_u: 0.8569 - dice_coeficient: 0.8726 - val_loss: 0.9333 - val_mean_io_u: 0.8586 - val_dice_coeficient: 0.8710
#
# Epoch 00047: val_mean_io_u improved from 0.85757 to 0.85856, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 48/100
# 51/51 [==============================] - 498s 10s/step - loss: 0.9333 - mean_io_u: 0.8579 - dice_coeficient: 0.8727 - val_loss: 0.9333 - val_mean_io_u: 0.8573 - val_dice_coeficient: 0.8701
#
# Epoch 00048: val_mean_io_u did not improve from 0.85856
# Epoch 49/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9333 - mean_io_u: 0.8586 - dice_coeficient: 0.8728 - val_loss: 0.9333 - val_mean_io_u: 0.8592 - val_dice_coeficient: 0.8712
#
# Epoch 00049: val_mean_io_u improved from 0.85856 to 0.85923, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 50/100
# 51/51 [==============================] - 495s 10s/step - loss: 0.9332 - mean_io_u: 0.8592 - dice_coeficient: 0.8729 - val_loss: 0.9334 - val_mean_io_u: 0.8579 - val_dice_coeficient: 0.8702
#
# Epoch 00050: val_mean_io_u did not improve from 0.85923
# Epoch 51/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9332 - mean_io_u: 0.8593 - dice_coeficient: 0.8731 - val_loss: 0.9333 - val_mean_io_u: 0.8595 - val_dice_coeficient: 0.8711
#
# Epoch 00051: val_mean_io_u improved from 0.85923 to 0.85945, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 52/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9332 - mean_io_u: 0.8600 - dice_coeficient: 0.8729 - val_loss: 0.9333 - val_mean_io_u: 0.8601 - val_dice_coeficient: 0.8712
#
# Epoch 00052: val_mean_io_u improved from 0.85945 to 0.86012, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 53/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9332 - mean_io_u: 0.8599 - dice_coeficient: 0.8730 - val_loss: 0.9333 - val_mean_io_u: 0.8599 - val_dice_coeficient: 0.8710
#
# Epoch 00053: val_mean_io_u did not improve from 0.86012
# Epoch 54/100
# 51/51 [==============================] - 499s 10s/step - loss: 0.9332 - mean_io_u: 0.8604 - dice_coeficient: 0.8732 - val_loss: 0.9333 - val_mean_io_u: 0.8593 - val_dice_coeficient: 0.8708
#
# Epoch 00054: val_mean_io_u did not improve from 0.86012
# Epoch 55/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9332 - mean_io_u: 0.8612 - dice_coeficient: 0.8730 - val_loss: 0.9333 - val_mean_io_u: 0.8608 - val_dice_coeficient: 0.8709
#
# Epoch 00055: val_mean_io_u improved from 0.86012 to 0.86084, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 56/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9332 - mean_io_u: 0.8616 - dice_coeficient: 0.8734 - val_loss: 0.9332 - val_mean_io_u: 0.8606 - val_dice_coeficient: 0.8712
#
# Epoch 00056: val_mean_io_u did not improve from 0.86084
# Epoch 57/100
# 51/51 [==============================] - 499s 10s/step - loss: 0.9332 - mean_io_u: 0.8621 - dice_coeficient: 0.8735 - val_loss: 0.9333 - val_mean_io_u: 0.8617 - val_dice_coeficient: 0.8711
#
# Epoch 00057: val_mean_io_u improved from 0.86084 to 0.86168, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 58/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9332 - mean_io_u: 0.8624 - dice_coeficient: 0.8736 - val_loss: 0.9332 - val_mean_io_u: 0.8608 - val_dice_coeficient: 0.8705
#
# Epoch 00058: val_mean_io_u did not improve from 0.86168
# Epoch 59/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9332 - mean_io_u: 0.8629 - dice_coeficient: 0.8737 - val_loss: 0.9332 - val_mean_io_u: 0.8618 - val_dice_coeficient: 0.8714
#
# Epoch 00059: val_mean_io_u improved from 0.86168 to 0.86185, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 60/100
# 51/51 [==============================] - 499s 10s/step - loss: 0.9332 - mean_io_u: 0.8633 - dice_coeficient: 0.8738 - val_loss: 0.9333 - val_mean_io_u: 0.8627 - val_dice_coeficient: 0.8721
#
# Epoch 00060: val_mean_io_u improved from 0.86185 to 0.86274, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 61/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9332 - mean_io_u: 0.8632 - dice_coeficient: 0.8735 - val_loss: 0.9333 - val_mean_io_u: 0.8644 - val_dice_coeficient: 0.8718
#
# Epoch 00061: val_mean_io_u improved from 0.86274 to 0.86441, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 62/100
# 51/51 [==============================] - 498s 10s/step - loss: 0.9332 - mean_io_u: 0.8636 - dice_coeficient: 0.8737 - val_loss: 0.9332 - val_mean_io_u: 0.8619 - val_dice_coeficient: 0.8710
#
# Epoch 00062: val_mean_io_u did not improve from 0.86441
# Epoch 63/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9332 - mean_io_u: 0.8645 - dice_coeficient: 0.8736 - val_loss: 0.9332 - val_mean_io_u: 0.8635 - val_dice_coeficient: 0.8718
#
# Epoch 00063: val_mean_io_u did not improve from 0.86441
# Epoch 64/100
# 51/51 [==============================] - 498s 10s/step - loss: 0.9332 - mean_io_u: 0.8645 - dice_coeficient: 0.8739 - val_loss: 0.9332 - val_mean_io_u: 0.8651 - val_dice_coeficient: 0.8720
#
# Epoch 00064: val_mean_io_u improved from 0.86441 to 0.86512, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 65/100
# 51/51 [==============================] - 495s 10s/step - loss: 0.9332 - mean_io_u: 0.8659 - dice_coeficient: 0.8740 - val_loss: 0.9332 - val_mean_io_u: 0.8671 - val_dice_coeficient: 0.8721
#
# Epoch 00065: val_mean_io_u improved from 0.86512 to 0.86710, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 66/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9332 - mean_io_u: 0.8662 - dice_coeficient: 0.8742 - val_loss: 0.9332 - val_mean_io_u: 0.8622 - val_dice_coeficient: 0.8713
#
# Epoch 00066: val_mean_io_u did not improve from 0.86710
# Epoch 67/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9332 - mean_io_u: 0.8663 - dice_coeficient: 0.8741 - val_loss: 0.9332 - val_mean_io_u: 0.8652 - val_dice_coeficient: 0.8714
#
# Epoch 00067: val_mean_io_u did not improve from 0.86710
# Epoch 68/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9332 - mean_io_u: 0.8665 - dice_coeficient: 0.8741 - val_loss: 0.9332 - val_mean_io_u: 0.8656 - val_dice_coeficient: 0.8713
#
# Epoch 00068: val_mean_io_u did not improve from 0.86710
# Epoch 69/100
# 51/51 [==============================] - 502s 10s/step - loss: 0.9332 - mean_io_u: 0.8667 - dice_coeficient: 0.8740 - val_loss: 0.9332 - val_mean_io_u: 0.8635 - val_dice_coeficient: 0.8710
#
# Epoch 00069: val_mean_io_u did not improve from 0.86710
# Epoch 70/100
# 51/51 [==============================] - 495s 10s/step - loss: 0.9332 - mean_io_u: 0.8673 - dice_coeficient: 0.8741 - val_loss: 0.9332 - val_mean_io_u: 0.8679 - val_dice_coeficient: 0.8722
#
# Epoch 00070: val_mean_io_u improved from 0.86710 to 0.86790, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 71/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9332 - mean_io_u: 0.8681 - dice_coeficient: 0.8742 - val_loss: 0.9332 - val_mean_io_u: 0.8685 - val_dice_coeficient: 0.8722
#
# Epoch 00071: val_mean_io_u improved from 0.86790 to 0.86853, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 72/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9332 - mean_io_u: 0.8681 - dice_coeficient: 0.8740 - val_loss: 0.9332 - val_mean_io_u: 0.8668 - val_dice_coeficient: 0.8711
#
# Epoch 00072: val_mean_io_u did not improve from 0.86853
# Epoch 73/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9332 - mean_io_u: 0.8679 - dice_coeficient: 0.8742 - val_loss: 0.9332 - val_mean_io_u: 0.8684 - val_dice_coeficient: 0.8719
#
# Epoch 00073: val_mean_io_u did not improve from 0.86853
# Epoch 74/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9331 - mean_io_u: 0.8688 - dice_coeficient: 0.8743 - val_loss: 0.9332 - val_mean_io_u: 0.8670 - val_dice_coeficient: 0.8720
#
# Epoch 00074: val_mean_io_u did not improve from 0.86853
# Epoch 75/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9331 - mean_io_u: 0.8693 - dice_coeficient: 0.8743 - val_loss: 0.9332 - val_mean_io_u: 0.8674 - val_dice_coeficient: 0.8720
#
# Epoch 00075: val_mean_io_u did not improve from 0.86853
# Epoch 76/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9331 - mean_io_u: 0.8686 - dice_coeficient: 0.8742 - val_loss: 0.9332 - val_mean_io_u: 0.8676 - val_dice_coeficient: 0.8718
#
# Epoch 00076: val_mean_io_u did not improve from 0.86853
# Epoch 77/100
# 51/51 [==============================] - 498s 10s/step - loss: 0.9331 - mean_io_u: 0.8695 - dice_coeficient: 0.8742 - val_loss: 0.9332 - val_mean_io_u: 0.8674 - val_dice_coeficient: 0.8714
#
# Epoch 00077: val_mean_io_u did not improve from 0.86853
# Epoch 78/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9331 - mean_io_u: 0.8701 - dice_coeficient: 0.8743 - val_loss: 0.9332 - val_mean_io_u: 0.8690 - val_dice_coeficient: 0.8719
#
# Epoch 00078: val_mean_io_u improved from 0.86853 to 0.86904, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 79/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9331 - mean_io_u: 0.8701 - dice_coeficient: 0.8743 - val_loss: 0.9332 - val_mean_io_u: 0.8684 - val_dice_coeficient: 0.8711
#
# Epoch 00079: val_mean_io_u did not improve from 0.86904
# Epoch 80/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9331 - mean_io_u: 0.8711 - dice_coeficient: 0.8745 - val_loss: 0.9332 - val_mean_io_u: 0.8693 - val_dice_coeficient: 0.8722
#
# Epoch 00080: val_mean_io_u improved from 0.86904 to 0.86928, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 81/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9331 - mean_io_u: 0.8711 - dice_coeficient: 0.8744 - val_loss: 0.9332 - val_mean_io_u: 0.8680 - val_dice_coeficient: 0.8710
#
# Epoch 00081: val_mean_io_u did not improve from 0.86928
# Epoch 82/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9331 - mean_io_u: 0.8709 - dice_coeficient: 0.8746 - val_loss: 0.9332 - val_mean_io_u: 0.8691 - val_dice_coeficient: 0.8720
#
# Epoch 00082: val_mean_io_u did not improve from 0.86928
# Epoch 83/100
# 51/51 [==============================] - 498s 10s/step - loss: 0.9331 - mean_io_u: 0.8711 - dice_coeficient: 0.8745 - val_loss: 0.9332 - val_mean_io_u: 0.8689 - val_dice_coeficient: 0.8714
#
# Epoch 00083: val_mean_io_u did not improve from 0.86928
# Epoch 84/100
# 51/51 [==============================] - 503s 10s/step - loss: 0.9331 - mean_io_u: 0.8711 - dice_coeficient: 0.8746 - val_loss: 0.9332 - val_mean_io_u: 0.8698 - val_dice_coeficient: 0.8717
#
# Epoch 00084: val_mean_io_u improved from 0.86928 to 0.86981, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 85/100
# 51/51 [==============================] - 495s 10s/step - loss: 0.9331 - mean_io_u: 0.8715 - dice_coeficient: 0.8746 - val_loss: 0.9332 - val_mean_io_u: 0.8683 - val_dice_coeficient: 0.8713
#
# Epoch 00085: val_mean_io_u did not improve from 0.86981
# Epoch 86/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9331 - mean_io_u: 0.8717 - dice_coeficient: 0.8746 - val_loss: 0.9332 - val_mean_io_u: 0.8686 - val_dice_coeficient: 0.8718
#
# Epoch 00086: val_mean_io_u did not improve from 0.86981
# Epoch 87/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9331 - mean_io_u: 0.8723 - dice_coeficient: 0.8748 - val_loss: 0.9332 - val_mean_io_u: 0.8708 - val_dice_coeficient: 0.8717
#
# Epoch 00087: val_mean_io_u improved from 0.86981 to 0.87082, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 88/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9331 - mean_io_u: 0.8725 - dice_coeficient: 0.8746 - val_loss: 0.9332 - val_mean_io_u: 0.8712 - val_dice_coeficient: 0.8719
#
# Epoch 00088: val_mean_io_u improved from 0.87082 to 0.87121, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 89/100
# 51/51 [==============================] - 498s 10s/step - loss: 0.9331 - mean_io_u: 0.8722 - dice_coeficient: 0.8748 - val_loss: 0.9332 - val_mean_io_u: 0.8716 - val_dice_coeficient: 0.8720
#
# Epoch 00089: val_mean_io_u improved from 0.87121 to 0.87162, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 90/100
# 51/51 [==============================] - 498s 10s/step - loss: 0.9331 - mean_io_u: 0.8730 - dice_coeficient: 0.8748 - val_loss: 0.9332 - val_mean_io_u: 0.8712 - val_dice_coeficient: 0.8718
#
# Epoch 00090: val_mean_io_u did not improve from 0.87162
# Epoch 91/100
# 51/51 [==============================] - 499s 10s/step - loss: 0.9331 - mean_io_u: 0.8732 - dice_coeficient: 0.8749 - val_loss: 0.9332 - val_mean_io_u: 0.8719 - val_dice_coeficient: 0.8724
#
# Epoch 00091: val_mean_io_u improved from 0.87162 to 0.87190, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 92/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9331 - mean_io_u: 0.8735 - dice_coeficient: 0.8752 - val_loss: 0.9332 - val_mean_io_u: 0.8725 - val_dice_coeficient: 0.8724
#
# Epoch 00092: val_mean_io_u improved from 0.87190 to 0.87249, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 93/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9331 - mean_io_u: 0.8732 - dice_coeficient: 0.8750 - val_loss: 0.9332 - val_mean_io_u: 0.8715 - val_dice_coeficient: 0.8718
#
# Epoch 00093: val_mean_io_u did not improve from 0.87249
# Epoch 94/100
# 51/51 [==============================] - 495s 10s/step - loss: 0.9331 - mean_io_u: 0.8739 - dice_coeficient: 0.8750 - val_loss: 0.9332 - val_mean_io_u: 0.8719 - val_dice_coeficient: 0.8723
#
# Epoch 00094: val_mean_io_u did not improve from 0.87249
# Epoch 95/100
# 51/51 [==============================] - 497s 10s/step - loss: 0.9331 - mean_io_u: 0.8741 - dice_coeficient: 0.8749 - val_loss: 0.9332 - val_mean_io_u: 0.8721 - val_dice_coeficient: 0.8725
#
# Epoch 00095: val_mean_io_u did not improve from 0.87249
# Epoch 96/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9331 - mean_io_u: 0.8740 - dice_coeficient: 0.8749 - val_loss: 0.9332 - val_mean_io_u: 0.8727 - val_dice_coeficient: 0.8725
#
# Epoch 00096: val_mean_io_u improved from 0.87249 to 0.87275, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 97/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9331 - mean_io_u: 0.8742 - dice_coeficient: 0.8751 - val_loss: 0.9332 - val_mean_io_u: 0.8731 - val_dice_coeficient: 0.8724
#
# Epoch 00097: val_mean_io_u improved from 0.87275 to 0.87306, saving model to ../models\u-net-BN_diceLoss.hdf5
# Epoch 98/100
# 51/51 [==============================] - 499s 10s/step - loss: 0.9331 - mean_io_u: 0.8743 - dice_coeficient: 0.8746 - val_loss: 0.9332 - val_mean_io_u: 0.8722 - val_dice_coeficient: 0.8718
#
# Epoch 00098: val_mean_io_u did not improve from 0.87306
# Epoch 99/100
# 51/51 [==============================] - 495s 10s/step - loss: 0.9331 - mean_io_u: 0.8746 - dice_coeficient: 0.8747 - val_loss: 0.9332 - val_mean_io_u: 0.8726 - val_dice_coeficient: 0.8721
#
# Epoch 00099: val_mean_io_u did not improve from 0.87306
# Epoch 100/100
# 51/51 [==============================] - 496s 10s/step - loss: 0.9331 - mean_io_u: 0.8748 - dice_coeficient: 0.8749 - val_loss: 0.9332 - val_mean_io_u: 0.8722 - val_dice_coeficient: 0.8720
#
# Epoch 00100: val_mean_io_u did not improve from 0.87306

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='lower right')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/u-net_100epochs.hdf5')

# %%
pred = unet_model.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1), cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx], cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
# --
# **TFG - Adrián Contreras Castillo**
# --
