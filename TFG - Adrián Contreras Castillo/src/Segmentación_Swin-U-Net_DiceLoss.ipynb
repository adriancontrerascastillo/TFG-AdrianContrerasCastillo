# %% [markdown]
# # Deep Learning: Laparoscopic segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import cv2
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
from glob import glob
import segmentation_models as sm
from keras_vision_transformer import swin_layers
from keras_vision_transformer import transformer_layers
from keras_vision_transformer import utils
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: False

# %%
SEED = 17
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)
CLASS_WEIGHTS = [2.45780159e-01, 2.24610010e-01, 2.24005501e-01, 1.87119512e-02,
 1.46965911e-01, 2.54698498e-02, 2.35562466e-02, 4.28713053e-03,
 3.93593665e-04, 1.38500705e-02, 6.78984614e-02, 1.01436955e-04,
 4.36967906e-03]

# %%
# https://gist.github.com/IdeaKing/11cf5e146d23c5bb219ba3508cca89ec
def resize_with_pad(image: np.array, 
                    new_shape, 
                    padding_color = (0, 0, 0)) -> np.array:
    """Maintains aspect ratio and resizes with padding.
    Params:
        image: Image to be resized.
        new_shape: Expected (width, height) of new image.
        padding_color: Tuple in BGR of padding color
    Returns:
        image: Resized image with padding
    """
    original_shape = (image.shape[1], image.shape[0])
    ratio = float(max(new_shape))/max(original_shape)
    new_size = tuple([int(x*ratio) for x in original_shape])
    image = cv2.resize(image, new_size, interpolation=cv2.INTER_NEAREST)
    delta_w = new_shape[0] - new_size[0]
    delta_h = new_shape[1] - new_size[1]
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)
    image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT, value=padding_color)
    return image

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 120:-120,:]
    img = resize_with_pad(img, (HEIGHT, WIDTH))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 120:-120,:]
    mask = resize_with_pad(mask, (HEIGHT, WIDTH), (50, 50, 50))
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx], cmap='afmhot')
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1), cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 
import gc
del X
del y
gc.collect()
# Out:
# 7929

# %% [markdown]
# ## Swin-U-Net

# %% [markdown]
# ### Losses

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

def dice_loss(y_true, y_pred):
    return 1 - dice_coeficient(y_true, y_pred)

def tversky(y_true, y_pred, smooth=1e-6, alpha=0.75):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)
    TP = tf.keras.backend.sum(T * P)
    FN = tf.keras.backend.sum(T * (1 - P))
    FP = tf.keras.backend.sum((1 - T) * P)
    return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true, y_pred)


# def focal_tversky_loss(y_true, y_pred, gamma=0.75):
#     tv = tversky(y_true, y_pred)
#     return tf.keras.backend.pow((1 - tv), gamma)

# %% [markdown]
# ### Swin transformer stack

# %%
def swin_transformer_stack(X, stack_num, embed_dim, num_patch, num_heads, window_size, num_mlp, shift_window=True, name=''):
    '''
    Stacked Swin Transformers that share the same token size.
    
    Alternated Window-MSA and Swin-MSA will be configured if `shift_window=True`, Window-MSA only otherwise.
    *Dropout is turned off.
    '''
    # Turn-off dropouts
    mlp_drop_rate = 0 # Droupout after each MLP layer
    attn_drop_rate = 0 # Dropout after Swin-Attention
    proj_drop_rate = 0 # Dropout at the end of each Swin-Attention block, i.e., after linear projections
    drop_path_rate = 0 # Drop-path within skip-connections
    
    qkv_bias = True # Convert embedded patches to query, key, and values with a learnable additive value
    qk_scale = None # None: Re-scale query based on embed dimensions per attention head # Float for user specified scaling factor
    
    if shift_window:
        shift_size = window_size // 2
    else:
        shift_size = 0
    
    for i in range(stack_num):
    
        if i % 2 == 0:
            shift_size_temp = 0
        else:
            shift_size_temp = shift_size

        X = swin_layers.SwinTransformerBlock(dim=embed_dim, 
                                             num_patch=num_patch, 
                                             num_heads=num_heads, 
                                             window_size=window_size, 
                                             shift_size=shift_size_temp, 
                                             num_mlp=num_mlp, 
                                             qkv_bias=qkv_bias, 
                                             qk_scale=qk_scale,
                                             mlp_drop=mlp_drop_rate, 
                                             attn_drop=attn_drop_rate, 
                                             proj_drop=proj_drop_rate, 
                                             drop_path_prob=drop_path_rate, 
                                             name='name{}'.format(i))(X)
    return X


def swin_unet_2d_base(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet'):
    '''
    The base of Swin-UNET.
    
    The general structure:
    
    1. Input image --> a sequence of patches --> tokenize these patches
    2. Downsampling: swin-transformer --> patch merging (pooling)
    3. Upsampling: concatenate --> swin-transfprmer --> patch expanding (unpooling)
    4. Model head
    
    '''
    # Compute number be patches to be embeded
    input_size = input_tensor.shape.as_list()[1:]
    num_patch_x = input_size[0]//patch_size[0]
    num_patch_y = input_size[1]//patch_size[1]
    
    # Number of Embedded dimensions
    embed_dim = filter_num_begin
    
    depth_ = depth
    
    X_skip = []

    X = input_tensor
    
    # Patch extraction
    X = transformer_layers.patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = transformer_layers.patch_embedding(num_patch_x*num_patch_y, embed_dim)(X)
    
    # The first Swin Transformer stack
    X = swin_transformer_stack(X, 
                               stack_num=stack_num_down, 
                               embed_dim=embed_dim, 
                               num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], 
                               window_size=window_size[0], 
                               num_mlp=num_mlp, 
                               shift_window=shift_window, 
                               name='{}_swin_down0'.format(name))
    X_skip.append(X)
    
    # Downsampling blocks
    for i in range(depth_-1):
        
        # Patch merging
        X = transformer_layers.patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)
        
        # update token shape info
        embed_dim = embed_dim*2
        num_patch_x = num_patch_x//2
        num_patch_y = num_patch_y//2
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_down, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i+1], 
                                   window_size=window_size[i+1], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_down{}'.format(name, i+1))
        
        # Store tensors for concat
        X_skip.append(X)
        
    # reverse indexing encoded tensors and hyperparams
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]
    
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    
    depth_decode = len(X_decode)
    
    for i in range(depth_decode):
        
        # Patch expanding
        X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                               embed_dim=embed_dim, 
                                               upsample_rate=2, 
                                               return_vector=True)(X)
        

        # update token shape info
        embed_dim = embed_dim//2
        num_patch_x = num_patch_x*2
        num_patch_y = num_patch_y*2
        
        # Concatenation and linear projection
        X = tf.keras.layers.concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = tf.keras.layers.Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_up, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], 
                                   window_size=window_size[i], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_up{}'.format(name, i))
        
    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- "patch_size[0]" is used; it assumes patch_size = (size, size)
    
    X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                           embed_dim=embed_dim, 
                                           upsample_rate=patch_size[0], 
                                           return_vector=False)(X)
    
    return X

# %% [markdown]
# ### Hyperparameters

# %%
filter_num_begin = 128     # number of channels in the first downsampling block; it is also the number of embedded dimensions
depth = 4                  # the depth of SwinUNET; depth=4 means three down/upsampling levels and a bottom level 
stack_num_down = 2         # number of Swin Transformers per downsampling level
stack_num_up = 2           # number of Swin Transformers per upsampling level
patch_size = (4, 4)        # Extract 4-by-4 patches from the input image. Height and width of the patch must be equal.
num_heads = [4, 8, 8, 8]   # number of attention heads per down/upsampling level
window_size = [4, 2, 2, 2] # the size of attention window per down/upsampling level
num_mlp = 512              # number of MLP nodes within the Transformer
shift_window=True          # Apply window shifting, i.e., Swin-MSA

# %% [markdown]
# ### Model configuration

# %%
# Input section
IN = tf.keras.layers.Input((WIDTH, HEIGHT, 3))

# Base architecture
X = swin_unet_2d_base(IN, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, 
                      shift_window=shift_window, name='swin_unet')

# Output section
n_labels = 13
OUT = tf.keras.layers.Conv2D(n_labels, kernel_size=1, use_bias=False, activation='softmax')(X)

# Define a learning rate schedule
learning_rate = 5e-4
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=learning_rate, decay_steps=10000, decay_rate=0.9
)

# Create the optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule, clipvalue=0.5)

# Model configuration
swin_transformer = tf.keras.models.Model(inputs=[IN,], outputs=[OUT,])

swin_transformer.compile(
    optimizer=optimizer,
    loss=sm.losses.DiceLoss(class_weights=CLASS_WEIGHTS),
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)

swin_transformer.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  patch_extract_1 (patch_extract  (None, 256, 48)     0           ['input_2[0][0]']
#  )
#
#  patch_embedding_1 (patch_embed  (None, 256, 128)    39040       ['patch_extract_1[0][0]']
#  ding)
#
#  swin_transformer_block_14 (Swi  (None, 256, 128)    198724      ['patch_embedding_1[0][0]']
#  nTransformerBlock)
#
#  swin_transformer_block_15 (Swi  (None, 256, 128)    202820      ['swin_transformer_block_14[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_merging_3 (patch_merging  (None, 64, 256)     131072      ['swin_transformer_block_15[0][0]
#  )                                                               ']
#
#  swin_transformer_block_16 (Swi  (None, 64, 256)     527192      ['patch_merging_3[0][0]']
#  nTransformerBlock)
#
#  swin_transformer_block_17 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_16[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_merging_4 (patch_merging  (None, 16, 512)     524288      ['swin_transformer_block_17[0][0]
#  )                                                               ']
#
#  swin_transformer_block_18 (Swi  (None, 16, 512)     1578072     ['patch_merging_4[0][0]']
#  nTransformerBlock)
#
#  swin_transformer_block_19 (Swi  (None, 16, 512)     1578136     ['swin_transformer_block_18[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_merging_5 (patch_merging  (None, 4, 1024)     2097152     ['swin_transformer_block_19[0][0]
#  )                                                               ']
#
#  swin_transformer_block_20 (Swi  (None, 4, 1024)     5252696     ['patch_merging_5[0][0]']
#  nTransformerBlock)
#
#  swin_transformer_block_21 (Swi  (None, 4, 1024)     5252712     ['swin_transformer_block_20[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_4 (patch_expan  (None, 16, 512)     2097152     ['swin_transformer_block_21[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_0 (Concatenat  (None, 16, 1024)    0           ['patch_expanding_4[0][0]',
#  e)                                                               'swin_transformer_block_19[0][0]
#                                                                  ']
#
#  swin_unet_concat_linear_proj_0  (None, 16, 512)     524288      ['swin_unet_concat_0[0][0]']
#   (Dense)
#
#  swin_transformer_block_22 (Swi  (None, 16, 512)     1578072     ['swin_unet_concat_linear_proj_0[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_23 (Swi  (None, 16, 512)     1578136     ['swin_transformer_block_22[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_5 (patch_expan  (None, 64, 256)     524288      ['swin_transformer_block_23[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_1 (Concatenat  (None, 64, 512)     0           ['patch_expanding_5[0][0]',
#  e)                                                               'swin_transformer_block_17[0][0]
#                                                                  ']
#
#  swin_unet_concat_linear_proj_1  (None, 64, 256)     131072      ['swin_unet_concat_1[0][0]']
#   (Dense)
#
#  swin_transformer_block_24 (Swi  (None, 64, 256)     527192      ['swin_unet_concat_linear_proj_1[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_25 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_24[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_6 (patch_expan  (None, 256, 128)    131072      ['swin_transformer_block_25[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_2 (Concatenat  (None, 256, 256)    0           ['patch_expanding_6[0][0]',
#  e)                                                               'swin_transformer_block_15[0][0]
#                                                                  ']
#
#  swin_unet_concat_linear_proj_2  (None, 256, 128)    32768       ['swin_unet_concat_2[0][0]']
#   (Dense)
#
#  swin_transformer_block_26 (Swi  (None, 256, 128)    198360      ['swin_unet_concat_linear_proj_2[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_27 (Swi  (None, 256, 128)    199384      ['swin_transformer_block_26[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_7 (patch_expan  (None, 64, 64, 32)  65536       ['swin_transformer_block_27[0][0]
#  ding)                                                           ']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 13)   416         ['patch_expanding_7[0][0]']
#
# ==================================================================================================
# Total params: 26,024,536
# Trainable params: 26,018,056
# Non-trainable params: 6,480
# __________________________________________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/swin-unet_diceLoss.hdf5',
    verbose=1,
    monitor='val_mean_io_u',
    save_best_only=True,
    save_weights_only=True,
    mode='max'
)

print('\n\t TRAINING\n')

model_history = swin_transformer.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9577 - mean_io_u: 0.6536 - dice_coeficient: 0.5791
# Epoch 1: val_mean_io_u improved from -inf to 0.76106, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 440s 8s/step - loss: 0.9577 - mean_io_u: 0.6536 - dice_coeficient: 0.5791 - val_loss: 0.9470 - val_mean_io_u: 0.7611 - val_dice_coeficient: 0.7218
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9426 - mean_io_u: 0.7886 - dice_coeficient: 0.7662
# Epoch 2: val_mean_io_u improved from 0.76106 to 0.80632, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 404s 8s/step - loss: 0.9426 - mean_io_u: 0.7886 - dice_coeficient: 0.7662 - val_loss: 0.9402 - val_mean_io_u: 0.8063 - val_dice_coeficient: 0.7940
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9380 - mean_io_u: 0.8155 - dice_coeficient: 0.8168
# Epoch 3: val_mean_io_u improved from 0.80632 to 0.81797, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 411s 8s/step - loss: 0.9380 - mean_io_u: 0.8155 - dice_coeficient: 0.8168 - val_loss: 0.9362 - val_mean_io_u: 0.8180 - val_dice_coeficient: 0.8334
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9345 - mean_io_u: 0.8307 - dice_coeficient: 0.8511
# Epoch 4: val_mean_io_u improved from 0.81797 to 0.83951, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 402s 8s/step - loss: 0.9345 - mean_io_u: 0.8307 - dice_coeficient: 0.8511 - val_loss: 0.9333 - val_mean_io_u: 0.8395 - val_dice_coeficient: 0.8642
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9325 - mean_io_u: 0.8434 - dice_coeficient: 0.8707
# Epoch 5: val_mean_io_u improved from 0.83951 to 0.84591, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 398s 8s/step - loss: 0.9325 - mean_io_u: 0.8434 - dice_coeficient: 0.8707 - val_loss: 0.9322 - val_mean_io_u: 0.8459 - val_dice_coeficient: 0.8750
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9316 - mean_io_u: 0.8509 - dice_coeficient: 0.8811
# Epoch 6: val_mean_io_u improved from 0.84591 to 0.84858, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 402s 8s/step - loss: 0.9316 - mean_io_u: 0.8509 - dice_coeficient: 0.8811 - val_loss: 0.9314 - val_mean_io_u: 0.8486 - val_dice_coeficient: 0.8825
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9310 - mean_io_u: 0.8561 - dice_coeficient: 0.8877
# Epoch 7: val_mean_io_u improved from 0.84858 to 0.86044, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 514s 10s/step - loss: 0.9310 - mean_io_u: 0.8561 - dice_coeficient: 0.8877 - val_loss: 0.9308 - val_mean_io_u: 0.8604 - val_dice_coeficient: 0.8908
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9304 - mean_io_u: 0.8622 - dice_coeficient: 0.8943
# Epoch 8: val_mean_io_u improved from 0.86044 to 0.86256, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 455s 9s/step - loss: 0.9304 - mean_io_u: 0.8622 - dice_coeficient: 0.8943 - val_loss: 0.9304 - val_mean_io_u: 0.8626 - val_dice_coeficient: 0.8953
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9300 - mean_io_u: 0.8676 - dice_coeficient: 0.8996
# Epoch 9: val_mean_io_u improved from 0.86256 to 0.87096, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 408s 8s/step - loss: 0.9300 - mean_io_u: 0.8676 - dice_coeficient: 0.8996 - val_loss: 0.9296 - val_mean_io_u: 0.8710 - val_dice_coeficient: 0.9068
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9289 - mean_io_u: 0.8796 - dice_coeficient: 0.9141
# Epoch 10: val_mean_io_u improved from 0.87096 to 0.88375, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 395s 8s/step - loss: 0.9289 - mean_io_u: 0.8796 - dice_coeficient: 0.9141 - val_loss: 0.9289 - val_mean_io_u: 0.8838 - val_dice_coeficient: 0.9162
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9285 - mean_io_u: 0.8863 - dice_coeficient: 0.9188
# Epoch 11: val_mean_io_u improved from 0.88375 to 0.88894, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 387s 8s/step - loss: 0.9285 - mean_io_u: 0.8863 - dice_coeficient: 0.9188 - val_loss: 0.9286 - val_mean_io_u: 0.8889 - val_dice_coeficient: 0.9192
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9282 - mean_io_u: 0.8927 - dice_coeficient: 0.9244
# Epoch 12: val_mean_io_u improved from 0.88894 to 0.89891, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 410s 8s/step - loss: 0.9282 - mean_io_u: 0.8927 - dice_coeficient: 0.9244 - val_loss: 0.9279 - val_mean_io_u: 0.8989 - val_dice_coeficient: 0.9319
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9276 - mean_io_u: 0.9040 - dice_coeficient: 0.9358
# Epoch 13: val_mean_io_u improved from 0.89891 to 0.90734, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 398s 8s/step - loss: 0.9276 - mean_io_u: 0.9040 - dice_coeficient: 0.9358 - val_loss: 0.9275 - val_mean_io_u: 0.9073 - val_dice_coeficient: 0.9391
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9272 - mean_io_u: 0.9110 - dice_coeficient: 0.9418
# Epoch 14: val_mean_io_u improved from 0.90734 to 0.91151, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 400s 8s/step - loss: 0.9272 - mean_io_u: 0.9110 - dice_coeficient: 0.9418 - val_loss: 0.9273 - val_mean_io_u: 0.9115 - val_dice_coeficient: 0.9411
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9271 - mean_io_u: 0.9145 - dice_coeficient: 0.9436
# Epoch 15: val_mean_io_u improved from 0.91151 to 0.91476, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 438s 9s/step - loss: 0.9271 - mean_io_u: 0.9145 - dice_coeficient: 0.9436 - val_loss: 0.9273 - val_mean_io_u: 0.9148 - val_dice_coeficient: 0.9421
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9270 - mean_io_u: 0.9170 - dice_coeficient: 0.9444
# Epoch 16: val_mean_io_u improved from 0.91476 to 0.91627, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 440s 9s/step - loss: 0.9270 - mean_io_u: 0.9170 - dice_coeficient: 0.9444 - val_loss: 0.9271 - val_mean_io_u: 0.9163 - val_dice_coeficient: 0.9429
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9269 - mean_io_u: 0.9196 - dice_coeficient: 0.9460
# Epoch 17: val_mean_io_u improved from 0.91627 to 0.91835, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 439s 9s/step - loss: 0.9269 - mean_io_u: 0.9196 - dice_coeficient: 0.9460 - val_loss: 0.9270 - val_mean_io_u: 0.9183 - val_dice_coeficient: 0.9444
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9268 - mean_io_u: 0.9218 - dice_coeficient: 0.9470
# Epoch 18: val_mean_io_u improved from 0.91835 to 0.92063, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 438s 9s/step - loss: 0.9268 - mean_io_u: 0.9218 - dice_coeficient: 0.9470 - val_loss: 0.9270 - val_mean_io_u: 0.9206 - val_dice_coeficient: 0.9451
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9267 - mean_io_u: 0.9236 - dice_coeficient: 0.9478
# Epoch 19: val_mean_io_u improved from 0.92063 to 0.92350, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 438s 9s/step - loss: 0.9267 - mean_io_u: 0.9236 - dice_coeficient: 0.9478 - val_loss: 0.9269 - val_mean_io_u: 0.9235 - val_dice_coeficient: 0.9464
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9266 - mean_io_u: 0.9258 - dice_coeficient: 0.9491
# Epoch 20: val_mean_io_u improved from 0.92350 to 0.92479, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 435s 9s/step - loss: 0.9266 - mean_io_u: 0.9258 - dice_coeficient: 0.9491 - val_loss: 0.9268 - val_mean_io_u: 0.9248 - val_dice_coeficient: 0.9469
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9266 - mean_io_u: 0.9275 - dice_coeficient: 0.9498
# Epoch 21: val_mean_io_u improved from 0.92479 to 0.92613, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 424s 8s/step - loss: 0.9266 - mean_io_u: 0.9275 - dice_coeficient: 0.9498 - val_loss: 0.9268 - val_mean_io_u: 0.9261 - val_dice_coeficient: 0.9476
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9265 - mean_io_u: 0.9289 - dice_coeficient: 0.9504
# Epoch 22: val_mean_io_u improved from 0.92613 to 0.92705, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 428s 8s/step - loss: 0.9265 - mean_io_u: 0.9289 - dice_coeficient: 0.9504 - val_loss: 0.9268 - val_mean_io_u: 0.9270 - val_dice_coeficient: 0.9478
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9265 - mean_io_u: 0.9300 - dice_coeficient: 0.9508
# Epoch 23: val_mean_io_u improved from 0.92705 to 0.92878, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 436s 9s/step - loss: 0.9265 - mean_io_u: 0.9300 - dice_coeficient: 0.9508 - val_loss: 0.9267 - val_mean_io_u: 0.9288 - val_dice_coeficient: 0.9483
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9264 - mean_io_u: 0.9314 - dice_coeficient: 0.9512
# Epoch 24: val_mean_io_u improved from 0.92878 to 0.92989, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.9264 - mean_io_u: 0.9314 - dice_coeficient: 0.9512 - val_loss: 0.9267 - val_mean_io_u: 0.9299 - val_dice_coeficient: 0.9487
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9264 - mean_io_u: 0.9327 - dice_coeficient: 0.9517
# Epoch 25: val_mean_io_u improved from 0.92989 to 0.93026, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 388s 8s/step - loss: 0.9264 - mean_io_u: 0.9327 - dice_coeficient: 0.9517 - val_loss: 0.9267 - val_mean_io_u: 0.9303 - val_dice_coeficient: 0.9487
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9263 - mean_io_u: 0.9337 - dice_coeficient: 0.9523
# Epoch 26: val_mean_io_u improved from 0.93026 to 0.93104, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 376s 7s/step - loss: 0.9263 - mean_io_u: 0.9337 - dice_coeficient: 0.9523 - val_loss: 0.9267 - val_mean_io_u: 0.9310 - val_dice_coeficient: 0.9489
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9263 - mean_io_u: 0.9347 - dice_coeficient: 0.9526
# Epoch 27: val_mean_io_u improved from 0.93104 to 0.93270, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 377s 7s/step - loss: 0.9263 - mean_io_u: 0.9347 - dice_coeficient: 0.9526 - val_loss: 0.9266 - val_mean_io_u: 0.9327 - val_dice_coeficient: 0.9497
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9263 - mean_io_u: 0.9356 - dice_coeficient: 0.9530
# Epoch 28: val_mean_io_u improved from 0.93270 to 0.93310, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 407s 8s/step - loss: 0.9263 - mean_io_u: 0.9356 - dice_coeficient: 0.9530 - val_loss: 0.9266 - val_mean_io_u: 0.9331 - val_dice_coeficient: 0.9498
# Epoch 29/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9262 - mean_io_u: 0.9371 - dice_coeficient: 0.9538
# Epoch 29: val_mean_io_u improved from 0.93310 to 0.93517, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 400s 8s/step - loss: 0.9262 - mean_io_u: 0.9371 - dice_coeficient: 0.9538 - val_loss: 0.9266 - val_mean_io_u: 0.9352 - val_dice_coeficient: 0.9506
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9262 - mean_io_u: 0.9382 - dice_coeficient: 0.9545
# Epoch 30: val_mean_io_u improved from 0.93517 to 0.93608, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 396s 8s/step - loss: 0.9262 - mean_io_u: 0.9382 - dice_coeficient: 0.9545 - val_loss: 0.9265 - val_mean_io_u: 0.9361 - val_dice_coeficient: 0.9515
# Epoch 31/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9262 - mean_io_u: 0.9392 - dice_coeficient: 0.9549
# Epoch 31: val_mean_io_u improved from 0.93608 to 0.93728, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 394s 8s/step - loss: 0.9262 - mean_io_u: 0.9392 - dice_coeficient: 0.9549 - val_loss: 0.9265 - val_mean_io_u: 0.9373 - val_dice_coeficient: 0.9516
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9261 - mean_io_u: 0.9400 - dice_coeficient: 0.9552
# Epoch 32: val_mean_io_u improved from 0.93728 to 0.93756, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 405s 8s/step - loss: 0.9261 - mean_io_u: 0.9400 - dice_coeficient: 0.9552 - val_loss: 0.9265 - val_mean_io_u: 0.9376 - val_dice_coeficient: 0.9518
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9261 - mean_io_u: 0.9406 - dice_coeficient: 0.9554
# Epoch 33: val_mean_io_u improved from 0.93756 to 0.93810, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 433s 9s/step - loss: 0.9261 - mean_io_u: 0.9406 - dice_coeficient: 0.9554 - val_loss: 0.9265 - val_mean_io_u: 0.9381 - val_dice_coeficient: 0.9517
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9261 - mean_io_u: 0.9413 - dice_coeficient: 0.9556
# Epoch 34: val_mean_io_u improved from 0.93810 to 0.93884, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 398s 8s/step - loss: 0.9261 - mean_io_u: 0.9413 - dice_coeficient: 0.9556 - val_loss: 0.9265 - val_mean_io_u: 0.9388 - val_dice_coeficient: 0.9521
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9261 - mean_io_u: 0.9420 - dice_coeficient: 0.9559
# Epoch 35: val_mean_io_u did not improve from 0.93884
# 51/51 [==============================] - 426s 8s/step - loss: 0.9261 - mean_io_u: 0.9420 - dice_coeficient: 0.9559 - val_loss: 0.9265 - val_mean_io_u: 0.9388 - val_dice_coeficient: 0.9518
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9261 - mean_io_u: 0.9427 - dice_coeficient: 0.9561
# Epoch 36: val_mean_io_u improved from 0.93884 to 0.94048, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 418s 8s/step - loss: 0.9261 - mean_io_u: 0.9427 - dice_coeficient: 0.9561 - val_loss: 0.9264 - val_mean_io_u: 0.9405 - val_dice_coeficient: 0.9528
# Epoch 37/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9260 - mean_io_u: 0.9434 - dice_coeficient: 0.9565
# Epoch 37: val_mean_io_u did not improve from 0.94048
# 51/51 [==============================] - 427s 8s/step - loss: 0.9260 - mean_io_u: 0.9434 - dice_coeficient: 0.9565 - val_loss: 0.9264 - val_mean_io_u: 0.9403 - val_dice_coeficient: 0.9525
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9260 - mean_io_u: 0.9438 - dice_coeficient: 0.9565
# Epoch 38: val_mean_io_u improved from 0.94048 to 0.94058, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 429s 8s/step - loss: 0.9260 - mean_io_u: 0.9438 - dice_coeficient: 0.9565 - val_loss: 0.9264 - val_mean_io_u: 0.9406 - val_dice_coeficient: 0.9526
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9260 - mean_io_u: 0.9442 - dice_coeficient: 0.9565
# Epoch 39: val_mean_io_u improved from 0.94058 to 0.94150, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 447s 9s/step - loss: 0.9260 - mean_io_u: 0.9442 - dice_coeficient: 0.9565 - val_loss: 0.9264 - val_mean_io_u: 0.9415 - val_dice_coeficient: 0.9529
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9260 - mean_io_u: 0.9449 - dice_coeficient: 0.9569
# Epoch 40: val_mean_io_u improved from 0.94150 to 0.94196, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 397s 8s/step - loss: 0.9260 - mean_io_u: 0.9449 - dice_coeficient: 0.9569 - val_loss: 0.9264 - val_mean_io_u: 0.9420 - val_dice_coeficient: 0.9530
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9260 - mean_io_u: 0.9454 - dice_coeficient: 0.9571
# Epoch 41: val_mean_io_u did not improve from 0.94196
# 51/51 [==============================] - 400s 8s/step - loss: 0.9260 - mean_io_u: 0.9454 - dice_coeficient: 0.9571 - val_loss: 0.9264 - val_mean_io_u: 0.9416 - val_dice_coeficient: 0.9528
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9260 - mean_io_u: 0.9458 - dice_coeficient: 0.9572
# Epoch 42: val_mean_io_u improved from 0.94196 to 0.94232, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 429s 8s/step - loss: 0.9260 - mean_io_u: 0.9458 - dice_coeficient: 0.9572 - val_loss: 0.9264 - val_mean_io_u: 0.9423 - val_dice_coeficient: 0.9531
# Epoch 43/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9260 - mean_io_u: 0.9463 - dice_coeficient: 0.9575
# Epoch 43: val_mean_io_u improved from 0.94232 to 0.94296, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 466s 9s/step - loss: 0.9260 - mean_io_u: 0.9463 - dice_coeficient: 0.9575 - val_loss: 0.9264 - val_mean_io_u: 0.9430 - val_dice_coeficient: 0.9532
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9260 - mean_io_u: 0.9467 - dice_coeficient: 0.9575
# Epoch 44: val_mean_io_u improved from 0.94296 to 0.94331, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 451s 9s/step - loss: 0.9260 - mean_io_u: 0.9467 - dice_coeficient: 0.9575 - val_loss: 0.9264 - val_mean_io_u: 0.9433 - val_dice_coeficient: 0.9533
# Epoch 45/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9259 - mean_io_u: 0.9472 - dice_coeficient: 0.9578
# Epoch 45: val_mean_io_u improved from 0.94331 to 0.94387, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 425s 8s/step - loss: 0.9259 - mean_io_u: 0.9472 - dice_coeficient: 0.9578 - val_loss: 0.9263 - val_mean_io_u: 0.9439 - val_dice_coeficient: 0.9535
# Epoch 46/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9259 - mean_io_u: 0.9475 - dice_coeficient: 0.9578
# Epoch 46: val_mean_io_u did not improve from 0.94387
# 51/51 [==============================] - 408s 8s/step - loss: 0.9259 - mean_io_u: 0.9475 - dice_coeficient: 0.9578 - val_loss: 0.9264 - val_mean_io_u: 0.9437 - val_dice_coeficient: 0.9534
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9259 - mean_io_u: 0.9478 - dice_coeficient: 0.9578
# Epoch 47: val_mean_io_u improved from 0.94387 to 0.94424, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 414s 8s/step - loss: 0.9259 - mean_io_u: 0.9478 - dice_coeficient: 0.9578 - val_loss: 0.9263 - val_mean_io_u: 0.9442 - val_dice_coeficient: 0.9535
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9259 - mean_io_u: 0.9483 - dice_coeficient: 0.9581
# Epoch 48: val_mean_io_u improved from 0.94424 to 0.94470, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 437s 9s/step - loss: 0.9259 - mean_io_u: 0.9483 - dice_coeficient: 0.9581 - val_loss: 0.9263 - val_mean_io_u: 0.9447 - val_dice_coeficient: 0.9536
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9259 - mean_io_u: 0.9487 - dice_coeficient: 0.9581
# Epoch 49: val_mean_io_u improved from 0.94470 to 0.94506, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 442s 9s/step - loss: 0.9259 - mean_io_u: 0.9487 - dice_coeficient: 0.9581 - val_loss: 0.9263 - val_mean_io_u: 0.9451 - val_dice_coeficient: 0.9538
# Epoch 50/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9259 - mean_io_u: 0.9492 - dice_coeficient: 0.9585
# Epoch 50: val_mean_io_u improved from 0.94506 to 0.94539, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 450s 9s/step - loss: 0.9259 - mean_io_u: 0.9492 - dice_coeficient: 0.9585 - val_loss: 0.9263 - val_mean_io_u: 0.9454 - val_dice_coeficient: 0.9539
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9257 - mean_io_u: 0.9521 - dice_coeficient: 0.9612
# Epoch 51: val_mean_io_u improved from 0.94539 to 0.94884, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 434s 9s/step - loss: 0.9257 - mean_io_u: 0.9521 - dice_coeficient: 0.9612 - val_loss: 0.9261 - val_mean_io_u: 0.9488 - val_dice_coeficient: 0.9573
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9256 - mean_io_u: 0.9537 - dice_coeficient: 0.9625
# Epoch 52: val_mean_io_u improved from 0.94884 to 0.94948, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 407s 8s/step - loss: 0.9256 - mean_io_u: 0.9537 - dice_coeficient: 0.9625 - val_loss: 0.9261 - val_mean_io_u: 0.9495 - val_dice_coeficient: 0.9576
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9256 - mean_io_u: 0.9539 - dice_coeficient: 0.9627
# Epoch 53: val_mean_io_u improved from 0.94948 to 0.95237, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 411s 8s/step - loss: 0.9256 - mean_io_u: 0.9539 - dice_coeficient: 0.9627 - val_loss: 0.9259 - val_mean_io_u: 0.9524 - val_dice_coeficient: 0.9608
# Epoch 54/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9254 - mean_io_u: 0.9578 - dice_coeficient: 0.9664
# Epoch 54: val_mean_io_u improved from 0.95237 to 0.95381, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 402s 8s/step - loss: 0.9254 - mean_io_u: 0.9578 - dice_coeficient: 0.9664 - val_loss: 0.9259 - val_mean_io_u: 0.9538 - val_dice_coeficient: 0.9615
# Epoch 55/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9254 - mean_io_u: 0.9586 - dice_coeficient: 0.9668
# Epoch 55: val_mean_io_u improved from 0.95381 to 0.95423, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 409s 8s/step - loss: 0.9254 - mean_io_u: 0.9586 - dice_coeficient: 0.9668 - val_loss: 0.9258 - val_mean_io_u: 0.9542 - val_dice_coeficient: 0.9618
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9254 - mean_io_u: 0.9589 - dice_coeficient: 0.9670
# Epoch 56: val_mean_io_u improved from 0.95423 to 0.95429, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 386s 8s/step - loss: 0.9254 - mean_io_u: 0.9589 - dice_coeficient: 0.9670 - val_loss: 0.9258 - val_mean_io_u: 0.9543 - val_dice_coeficient: 0.9617
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9254 - mean_io_u: 0.9592 - dice_coeficient: 0.9671
# Epoch 57: val_mean_io_u improved from 0.95429 to 0.95470, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 410s 8s/step - loss: 0.9254 - mean_io_u: 0.9592 - dice_coeficient: 0.9671 - val_loss: 0.9258 - val_mean_io_u: 0.9547 - val_dice_coeficient: 0.9619
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9254 - mean_io_u: 0.9595 - dice_coeficient: 0.9672
# Epoch 58: val_mean_io_u improved from 0.95470 to 0.95479, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 394s 8s/step - loss: 0.9254 - mean_io_u: 0.9595 - dice_coeficient: 0.9672 - val_loss: 0.9258 - val_mean_io_u: 0.9548 - val_dice_coeficient: 0.9620
# Epoch 59/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9253 - mean_io_u: 0.9598 - dice_coeficient: 0.9674
# Epoch 59: val_mean_io_u improved from 0.95479 to 0.95494, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 374s 7s/step - loss: 0.9253 - mean_io_u: 0.9598 - dice_coeficient: 0.9674 - val_loss: 0.9258 - val_mean_io_u: 0.9549 - val_dice_coeficient: 0.9620
# Epoch 60/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9253 - mean_io_u: 0.9600 - dice_coeficient: 0.9674
# Epoch 60: val_mean_io_u improved from 0.95494 to 0.95497, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 397s 8s/step - loss: 0.9253 - mean_io_u: 0.9600 - dice_coeficient: 0.9674 - val_loss: 0.9258 - val_mean_io_u: 0.9550 - val_dice_coeficient: 0.9619
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9254 - mean_io_u: 0.9601 - dice_coeficient: 0.9673
# Epoch 61: val_mean_io_u improved from 0.95497 to 0.95560, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 428s 8s/step - loss: 0.9254 - mean_io_u: 0.9601 - dice_coeficient: 0.9673 - val_loss: 0.9258 - val_mean_io_u: 0.9556 - val_dice_coeficient: 0.9623
# Epoch 62/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9635 - dice_coeficient: 0.9706
# Epoch 62: val_mean_io_u improved from 0.95560 to 0.95958, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 438s 9s/step - loss: 0.9252 - mean_io_u: 0.9635 - dice_coeficient: 0.9706 - val_loss: 0.9256 - val_mean_io_u: 0.9596 - val_dice_coeficient: 0.9660
# Epoch 63/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9646 - dice_coeficient: 0.9714
# Epoch 63: val_mean_io_u did not improve from 0.95958
# 51/51 [==============================] - 395s 8s/step - loss: 0.9251 - mean_io_u: 0.9646 - dice_coeficient: 0.9714 - val_loss: 0.9256 - val_mean_io_u: 0.9592 - val_dice_coeficient: 0.9658
# Epoch 64/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9650 - dice_coeficient: 0.9717
# Epoch 64: val_mean_io_u did not improve from 0.95958
# 51/51 [==============================] - 400s 8s/step - loss: 0.9251 - mean_io_u: 0.9650 - dice_coeficient: 0.9717 - val_loss: 0.9256 - val_mean_io_u: 0.9594 - val_dice_coeficient: 0.9658
# Epoch 65/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9652 - dice_coeficient: 0.9718
# Epoch 65: val_mean_io_u improved from 0.95958 to 0.96006, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 403s 8s/step - loss: 0.9251 - mean_io_u: 0.9652 - dice_coeficient: 0.9718 - val_loss: 0.9256 - val_mean_io_u: 0.9601 - val_dice_coeficient: 0.9663
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9654 - dice_coeficient: 0.9720
# Epoch 66: val_mean_io_u improved from 0.96006 to 0.96029, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 395s 8s/step - loss: 0.9251 - mean_io_u: 0.9654 - dice_coeficient: 0.9720 - val_loss: 0.9256 - val_mean_io_u: 0.9603 - val_dice_coeficient: 0.9662
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9655 - dice_coeficient: 0.9718
# Epoch 67: val_mean_io_u did not improve from 0.96029
# 51/51 [==============================] - 391s 8s/step - loss: 0.9251 - mean_io_u: 0.9655 - dice_coeficient: 0.9718 - val_loss: 0.9256 - val_mean_io_u: 0.9602 - val_dice_coeficient: 0.9662
# Epoch 68/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9658 - dice_coeficient: 0.9721
# Epoch 68: val_mean_io_u improved from 0.96029 to 0.96064, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 404s 8s/step - loss: 0.9251 - mean_io_u: 0.9658 - dice_coeficient: 0.9721 - val_loss: 0.9256 - val_mean_io_u: 0.9606 - val_dice_coeficient: 0.9664
# Epoch 69/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9660 - dice_coeficient: 0.9721
# Epoch 69: val_mean_io_u improved from 0.96064 to 0.96081, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 404s 8s/step - loss: 0.9251 - mean_io_u: 0.9660 - dice_coeficient: 0.9721 - val_loss: 0.9256 - val_mean_io_u: 0.9608 - val_dice_coeficient: 0.9663
# Epoch 70/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9662 - dice_coeficient: 0.9722
# Epoch 70: val_mean_io_u improved from 0.96081 to 0.96088, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 402s 8s/step - loss: 0.9251 - mean_io_u: 0.9662 - dice_coeficient: 0.9722 - val_loss: 0.9256 - val_mean_io_u: 0.9609 - val_dice_coeficient: 0.9664
# Epoch 71/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9665 - dice_coeficient: 0.9723
# Epoch 71: val_mean_io_u did not improve from 0.96088
# 51/51 [==============================] - 401s 8s/step - loss: 0.9251 - mean_io_u: 0.9665 - dice_coeficient: 0.9723 - val_loss: 0.9256 - val_mean_io_u: 0.9608 - val_dice_coeficient: 0.9663
# Epoch 72/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9250 - mean_io_u: 0.9673 - dice_coeficient: 0.9729
# Epoch 72: val_mean_io_u improved from 0.96088 to 0.96408, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 419s 8s/step - loss: 0.9250 - mean_io_u: 0.9673 - dice_coeficient: 0.9729 - val_loss: 0.9254 - val_mean_io_u: 0.9641 - val_dice_coeficient: 0.9697
# Epoch 73/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9704 - dice_coeficient: 0.9761
# Epoch 73: val_mean_io_u improved from 0.96408 to 0.96486, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 445s 9s/step - loss: 0.9248 - mean_io_u: 0.9704 - dice_coeficient: 0.9761 - val_loss: 0.9253 - val_mean_io_u: 0.9649 - val_dice_coeficient: 0.9701
# Epoch 74/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9707 - dice_coeficient: 0.9762
# Epoch 74: val_mean_io_u improved from 0.96486 to 0.96491, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 442s 9s/step - loss: 0.9248 - mean_io_u: 0.9707 - dice_coeficient: 0.9762 - val_loss: 0.9253 - val_mean_io_u: 0.9649 - val_dice_coeficient: 0.9702
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9709 - dice_coeficient: 0.9764
# Epoch 75: val_mean_io_u improved from 0.96491 to 0.96514, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 440s 9s/step - loss: 0.9248 - mean_io_u: 0.9709 - dice_coeficient: 0.9764 - val_loss: 0.9253 - val_mean_io_u: 0.9651 - val_dice_coeficient: 0.9702
# Epoch 76/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9712 - dice_coeficient: 0.9765
# Epoch 76: val_mean_io_u improved from 0.96514 to 0.96534, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 448s 9s/step - loss: 0.9248 - mean_io_u: 0.9712 - dice_coeficient: 0.9765 - val_loss: 0.9253 - val_mean_io_u: 0.9653 - val_dice_coeficient: 0.9704
# Epoch 77/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9713 - dice_coeficient: 0.9765
# Epoch 77: val_mean_io_u improved from 0.96534 to 0.96545, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 422s 8s/step - loss: 0.9248 - mean_io_u: 0.9713 - dice_coeficient: 0.9765 - val_loss: 0.9253 - val_mean_io_u: 0.9655 - val_dice_coeficient: 0.9704
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9715 - dice_coeficient: 0.9766
# Epoch 78: val_mean_io_u improved from 0.96545 to 0.96562, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 443s 9s/step - loss: 0.9248 - mean_io_u: 0.9715 - dice_coeficient: 0.9766 - val_loss: 0.9253 - val_mean_io_u: 0.9656 - val_dice_coeficient: 0.9704
# Epoch 79/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9715 - dice_coeficient: 0.9766
# Epoch 79: val_mean_io_u improved from 0.96562 to 0.96566, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 411s 8s/step - loss: 0.9248 - mean_io_u: 0.9715 - dice_coeficient: 0.9766 - val_loss: 0.9253 - val_mean_io_u: 0.9657 - val_dice_coeficient: 0.9704
# Epoch 80/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9716 - dice_coeficient: 0.9765
# Epoch 80: val_mean_io_u improved from 0.96566 to 0.96573, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 417s 8s/step - loss: 0.9248 - mean_io_u: 0.9716 - dice_coeficient: 0.9765 - val_loss: 0.9253 - val_mean_io_u: 0.9657 - val_dice_coeficient: 0.9704
# Epoch 81/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9718 - dice_coeficient: 0.9766
# Epoch 81: val_mean_io_u did not improve from 0.96573
# 51/51 [==============================] - 401s 8s/step - loss: 0.9248 - mean_io_u: 0.9718 - dice_coeficient: 0.9766 - val_loss: 0.9253 - val_mean_io_u: 0.9657 - val_dice_coeficient: 0.9703
# Epoch 82/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9247 - mean_io_u: 0.9737 - dice_coeficient: 0.9785
# Epoch 82: val_mean_io_u improved from 0.96573 to 0.96945, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 408s 8s/step - loss: 0.9247 - mean_io_u: 0.9737 - dice_coeficient: 0.9785 - val_loss: 0.9251 - val_mean_io_u: 0.9694 - val_dice_coeficient: 0.9739
# Epoch 83/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9245 - mean_io_u: 0.9760 - dice_coeficient: 0.9806
# Epoch 83: val_mean_io_u improved from 0.96945 to 0.96975, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 438s 9s/step - loss: 0.9245 - mean_io_u: 0.9760 - dice_coeficient: 0.9806 - val_loss: 0.9251 - val_mean_io_u: 0.9698 - val_dice_coeficient: 0.9741
# Epoch 84/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9245 - mean_io_u: 0.9761 - dice_coeficient: 0.9806
# Epoch 84: val_mean_io_u improved from 0.96975 to 0.97008, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 439s 9s/step - loss: 0.9245 - mean_io_u: 0.9761 - dice_coeficient: 0.9806 - val_loss: 0.9250 - val_mean_io_u: 0.9701 - val_dice_coeficient: 0.9744
# Epoch 85/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9245 - mean_io_u: 0.9764 - dice_coeficient: 0.9808
# Epoch 85: val_mean_io_u improved from 0.97008 to 0.97019, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 437s 9s/step - loss: 0.9245 - mean_io_u: 0.9764 - dice_coeficient: 0.9808 - val_loss: 0.9250 - val_mean_io_u: 0.9702 - val_dice_coeficient: 0.9744
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9245 - mean_io_u: 0.9766 - dice_coeficient: 0.9809
# Epoch 86: val_mean_io_u did not improve from 0.97019
# 51/51 [==============================] - 456s 9s/step - loss: 0.9245 - mean_io_u: 0.9766 - dice_coeficient: 0.9809 - val_loss: 0.9250 - val_mean_io_u: 0.9702 - val_dice_coeficient: 0.9744
# Epoch 87/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9245 - mean_io_u: 0.9768 - dice_coeficient: 0.9810
# Epoch 87: val_mean_io_u improved from 0.97019 to 0.97050, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 438s 9s/step - loss: 0.9245 - mean_io_u: 0.9768 - dice_coeficient: 0.9810 - val_loss: 0.9250 - val_mean_io_u: 0.9705 - val_dice_coeficient: 0.9746
# Epoch 88/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9245 - mean_io_u: 0.9769 - dice_coeficient: 0.9811
# Epoch 88: val_mean_io_u did not improve from 0.97050
# 51/51 [==============================] - 435s 9s/step - loss: 0.9245 - mean_io_u: 0.9769 - dice_coeficient: 0.9811 - val_loss: 0.9250 - val_mean_io_u: 0.9700 - val_dice_coeficient: 0.9742
# Epoch 89/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9245 - mean_io_u: 0.9770 - dice_coeficient: 0.9811
# Epoch 89: val_mean_io_u did not improve from 0.97050
# 51/51 [==============================] - 429s 8s/step - loss: 0.9245 - mean_io_u: 0.9770 - dice_coeficient: 0.9811 - val_loss: 0.9250 - val_mean_io_u: 0.9703 - val_dice_coeficient: 0.9744
# Epoch 90/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9245 - mean_io_u: 0.9770 - dice_coeficient: 0.9811
# Epoch 90: val_mean_io_u did not improve from 0.97050
# 51/51 [==============================] - 394s 8s/step - loss: 0.9245 - mean_io_u: 0.9770 - dice_coeficient: 0.9811 - val_loss: 0.9250 - val_mean_io_u: 0.9705 - val_dice_coeficient: 0.9745
# Epoch 91/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9245 - mean_io_u: 0.9771 - dice_coeficient: 0.9811
# Epoch 91: val_mean_io_u improved from 0.97050 to 0.97059, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 397s 8s/step - loss: 0.9245 - mean_io_u: 0.9771 - dice_coeficient: 0.9811 - val_loss: 0.9250 - val_mean_io_u: 0.9706 - val_dice_coeficient: 0.9744
# Epoch 92/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9245 - mean_io_u: 0.9773 - dice_coeficient: 0.9812
# Epoch 92: val_mean_io_u did not improve from 0.97059
# 51/51 [==============================] - 403s 8s/step - loss: 0.9245 - mean_io_u: 0.9773 - dice_coeficient: 0.9812 - val_loss: 0.9250 - val_mean_io_u: 0.9706 - val_dice_coeficient: 0.9744
# Epoch 93/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9245 - mean_io_u: 0.9774 - dice_coeficient: 0.9812
# Epoch 93: val_mean_io_u improved from 0.97059 to 0.97079, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 433s 9s/step - loss: 0.9245 - mean_io_u: 0.9774 - dice_coeficient: 0.9812 - val_loss: 0.9250 - val_mean_io_u: 0.9708 - val_dice_coeficient: 0.9745
# Epoch 94/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9245 - mean_io_u: 0.9776 - dice_coeficient: 0.9813
# Epoch 94: val_mean_io_u improved from 0.97079 to 0.97088, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 436s 9s/step - loss: 0.9245 - mean_io_u: 0.9776 - dice_coeficient: 0.9813 - val_loss: 0.9250 - val_mean_io_u: 0.9709 - val_dice_coeficient: 0.9747
# Epoch 95/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9244 - mean_io_u: 0.9777 - dice_coeficient: 0.9814
# Epoch 95: val_mean_io_u improved from 0.97088 to 0.97101, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 433s 8s/step - loss: 0.9244 - mean_io_u: 0.9777 - dice_coeficient: 0.9814 - val_loss: 0.9250 - val_mean_io_u: 0.9710 - val_dice_coeficient: 0.9747
# Epoch 96/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9244 - mean_io_u: 0.9777 - dice_coeficient: 0.9814
# Epoch 96: val_mean_io_u did not improve from 0.97101
# 51/51 [==============================] - 434s 9s/step - loss: 0.9244 - mean_io_u: 0.9777 - dice_coeficient: 0.9814 - val_loss: 0.9250 - val_mean_io_u: 0.9707 - val_dice_coeficient: 0.9744
# Epoch 97/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9244 - mean_io_u: 0.9778 - dice_coeficient: 0.9814
# Epoch 97: val_mean_io_u improved from 0.97101 to 0.97110, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 445s 9s/step - loss: 0.9244 - mean_io_u: 0.9778 - dice_coeficient: 0.9814 - val_loss: 0.9250 - val_mean_io_u: 0.9711 - val_dice_coeficient: 0.9746
# Epoch 98/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9245 - mean_io_u: 0.9778 - dice_coeficient: 0.9813
# Epoch 98: val_mean_io_u did not improve from 0.97110
# 51/51 [==============================] - 435s 9s/step - loss: 0.9245 - mean_io_u: 0.9778 - dice_coeficient: 0.9813 - val_loss: 0.9250 - val_mean_io_u: 0.9710 - val_dice_coeficient: 0.9746
# Epoch 99/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9244 - mean_io_u: 0.9780 - dice_coeficient: 0.9814
# Epoch 99: val_mean_io_u improved from 0.97110 to 0.97129, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 435s 9s/step - loss: 0.9244 - mean_io_u: 0.9780 - dice_coeficient: 0.9814 - val_loss: 0.9250 - val_mean_io_u: 0.9713 - val_dice_coeficient: 0.9747
# Epoch 100/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9244 - mean_io_u: 0.9782 - dice_coeficient: 0.9815
# Epoch 100: val_mean_io_u did not improve from 0.97129
# 51/51 [==============================] - 433s 8s/step - loss: 0.9244 - mean_io_u: 0.9782 - dice_coeficient: 0.9815 - val_loss: 0.9250 - val_mean_io_u: 0.9711 - val_dice_coeficient: 0.9745

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model metrics')
plt.ylabel('score')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='lower right')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/swin-unet_Weights.hdf5')

# %%
pred = swin_transformer.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 35s 580ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1), cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx], cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
# --
# **TFG - Adrián Contreras Castillo**
# --
