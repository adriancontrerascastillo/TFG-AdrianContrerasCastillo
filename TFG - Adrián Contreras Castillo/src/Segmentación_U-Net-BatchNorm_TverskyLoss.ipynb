# %% [markdown]
# # Deep Learning: Laparoscopic segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import random
import cv2
import tensorflow as tf
import keras.backend as K
from skimage import exposure
from skimage.color import rgb2gray
from sklearn.model_selection import train_test_split
from glob import glob
import pickle
import segmentation_models as sm
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: False

# %%
SEED = 17
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)

# %%
# https://gist.github.com/IdeaKing/11cf5e146d23c5bb219ba3508cca89ec
def resize_with_pad(image: np.array, 
                    new_shape, 
                    padding_color = (0, 0, 0)) -> np.array:
    """Maintains aspect ratio and resizes with padding.
    Params:
        image: Image to be resized.
        new_shape: Expected (width, height) of new image.
        padding_color: Tuple in BGR of padding color
    Returns:
        image: Resized image with padding
    """
    original_shape = (image.shape[1], image.shape[0])
    ratio = float(max(new_shape))/max(original_shape)
    new_size = tuple([int(x*ratio) for x in original_shape])
    image = cv2.resize(image, new_size, interpolation=cv2.INTER_NEAREST)
    delta_w = new_shape[0] - new_size[0]
    delta_h = new_shape[1] - new_size[1]
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)
    image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT, value=padding_color)
    return image

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 120:-120,:]
    img = resize_with_pad(img, (HEIGHT, WIDTH))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 120:-120,:]
    mask = resize_with_pad(mask, (HEIGHT, WIDTH), (50, 50, 50))
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx], cmap='afmhot')
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
# dump_data(X, y)
# X, y = load_data()
np.unique(y_encoded[idx])
# Out:
# array([ 0,  2,  3,  4, 10], dtype=uint8)

# %%
plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1), cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## U-Net

# %%
def double_conv_block(x, n_filters):

   # Conv2D then ReLU activation
   x = tf.keras.layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
   # Conv2D then ReLU activation
   x = tf.keras.layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)

   return x

def downsample_block(x, n_filters):
   f = double_conv_block(x, n_filters)
   p = tf.keras.layers.MaxPool2D(2)(f)
   p = tf.keras.layers.BatchNormalization()(p)
   p = tf.keras.layers.Dropout(0.2)(p)

   return f, p

def upsample_block(x, conv_features, n_filters):
   # upsample
   x = tf.keras.layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
   # concatenate
   x = tf.keras.layers.concatenate([x, conv_features])
   # dropout
   x = tf.keras.layers.BatchNormalization()(x)
   x = tf.keras.layers.Dropout(0.2)(x)
   # Conv2D twice with ReLU activation
   x = double_conv_block(x, n_filters)

   return x

def build_unet_model(n_filters=64, n_classes=2):
   # inputs
   inputs = tf.keras.layers.Input(shape=(HEIGHT,WIDTH,3))

   # encoder: contracting path - downsample
   # 1 - downsample
   f1, p1 = downsample_block(inputs, n_filters)
   # 2 - downsample
   f2, p2 = downsample_block(p1, n_filters*2)
   # 3 - downsample
   f3, p3 = downsample_block(p2, n_filters*4)
   # 4 - downsample
   f4, p4 = downsample_block(p3, n_filters*8)

   # 5 - bottleneck
   bottleneck = double_conv_block(p4, n_filters*16)

   # decoder: expanding path - upsample
   # 6 - upsample
   u6 = upsample_block(bottleneck, f4, n_filters*8)
   # 7 - upsample
   u7 = upsample_block(u6, f3, n_filters*4)
   # 8 - upsample
   u8 = upsample_block(u7, f2, n_filters*2)
   # 9 - upsample
   u9 = upsample_block(u8, f1, n_filters)

   # outputs
   
   activation = 'sigmoid' if n_classes == 2 else 'softmax'
   outputs = tf.keras.layers.Conv2D(n_classes, 1, padding="same", activation=activation)(u9)

   # unet model with Keras Functional API
   unet_model = tf.keras.Model(inputs, outputs, name="U-Net")

   return unet_model

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

def dice_loss(y_true, y_pred):
    return 1 - dice_coeficient(y_true, y_pred)

def tversky(y_true, y_pred, smooth=1e-6, alpha=0.75):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)
    TP = tf.keras.backend.sum(T * P)
    FN = tf.keras.backend.sum(T * (1 - P))
    FP = tf.keras.backend.sum((1 - T) * P)
    return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true, y_pred)


def focal_tversky_loss(y_true, y_pred, gamma=0.75):
    tv = tversky(y_true, y_pred)
    return tf.keras.backend.pow((1 - tv), gamma)

def generalized_dice_coeff(y_true, y_pred, smooth=1e-9):
    Ncl = y_pred.shape[-1]
    w = np.zeros((Ncl,))
    w = K.sum(y_true, (0,1,2))
    w = 1 / (w ** 2 + smooth)

    y_pred = tf.nn.softmax(y_pred)

    # Compute gen dice coef:
    numerator = y_true * y_pred
    numerator = w * K.sum(numerator, (0,1,2))
    numerator = K.sum(numerator)

    denominator = y_true + y_pred
    denominator = w * K.sum(denominator, (0,1,2))
    denominator = K.sum(denominator)

    return 2. * (numerator + smooth) / (denominator + smooth)


def generalized_dice_loss(y_true, y_pred):
    return 1. - generalized_dice_coeff(y_true, y_pred)

# %%
unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.load_weights('../models/u-net_39-0.22_tversky_loss.hdf5')
unet_model.compile(
    optimizer=tf.keras.optimizers.Adam(5e-4), 
    loss=tversky_loss,
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)

unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 64, 64, 32)   896         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 32)   9248        ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 32)   0           ['conv2d_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 32)  128         ['max_pooling2d[0][0]']
#  alization)
#
#  dropout (Dropout)              (None, 32, 32, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 64)   18496       ['dropout[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   36928       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)  0           ['conv2d_3[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 64)  256         ['max_pooling2d_1[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 16, 16, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 128)  73856       ['dropout_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 128)   0           ['conv2d_5[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 8, 8, 128)   512         ['max_pooling2d_2[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 8, 8, 128)    0           ['batch_normalization_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 8, 8, 256)    295168      ['dropout_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 256)    590080      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 256)   0           ['conv2d_7[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 4, 4, 256)   1024        ['max_pooling2d_3[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 4, 4, 256)    0           ['batch_normalization_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 4, 4, 512)    1180160     ['dropout_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 4, 4, 512)    2359808     ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 8, 8, 256)   1179904     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 8, 8, 512)    0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 8, 8, 512)   2048        ['concatenate[0][0]']
#  rmalization)
#
#  dropout_4 (Dropout)            (None, 8, 8, 512)    0           ['batch_normalization_4[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 8, 8, 256)    1179904     ['dropout_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 256)    590080      ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 16, 16, 128)  295040     ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 16, 16, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 256)  1024       ['concatenate_1[0][0]']
#  rmalization)
#
#  dropout_5 (Dropout)            (None, 16, 16, 256)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 128)  295040      ['dropout_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 128)  147584      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 32, 32, 64)  73792       ['conv2d_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 128)  512        ['concatenate_2[0][0]']
#  rmalization)
#
#  dropout_6 (Dropout)            (None, 32, 32, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 64)   73792       ['dropout_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 64)   36928       ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 64, 64, 32)  18464       ['conv2d_15[0][0]']
#  spose)
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_3[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 64)  256         ['concatenate_3[0][0]']
#  rmalization)
#
#  dropout_7 (Dropout)            (None, 64, 64, 64)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 32)   18464       ['dropout_7[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 32)   9248        ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 13)   429         ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 8,636,653
# Trainable params: 8,633,773
# Non-trainable params: 2,880
# __________________________________________________________________________________________________

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/u-net-BN_tversky.hdf5',
    verbose=1,
    monitor='val_mean_io_u',
    save_best_only=True,
    save_weights_only=True,
    mode='max'
)

print('\n\t TRAINING\n')

model_history = unet_model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4840 - mean_io_u: 0.4732 - dice_coeficient: 0.5175
# Epoch 1: val_mean_io_u improved from -inf to 0.46178, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 433s 8s/step - loss: 0.4840 - mean_io_u: 0.4732 - dice_coeficient: 0.5175 - val_loss: 0.6873 - val_mean_io_u: 0.4618 - val_dice_coeficient: 0.3130
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1689 - mean_io_u: 0.5502 - dice_coeficient: 0.8315
# Epoch 2: val_mean_io_u improved from 0.46178 to 0.46420, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 423s 8s/step - loss: 0.1689 - mean_io_u: 0.5502 - dice_coeficient: 0.8315 - val_loss: 0.5982 - val_mean_io_u: 0.4642 - val_dice_coeficient: 0.4025
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1206 - mean_io_u: 0.6591 - dice_coeficient: 0.8794
# Epoch 3: val_mean_io_u did not improve from 0.46420
# 51/51 [==============================] - 421s 8s/step - loss: 0.1206 - mean_io_u: 0.6591 - dice_coeficient: 0.8794 - val_loss: 0.3579 - val_mean_io_u: 0.4617 - val_dice_coeficient: 0.6428
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1103 - mean_io_u: 0.7191 - dice_coeficient: 0.8895
# Epoch 4: val_mean_io_u did not improve from 0.46420
# 51/51 [==============================] - 424s 8s/step - loss: 0.1103 - mean_io_u: 0.7191 - dice_coeficient: 0.8895 - val_loss: 0.2874 - val_mean_io_u: 0.4618 - val_dice_coeficient: 0.7133
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1062 - mean_io_u: 0.7541 - dice_coeficient: 0.8937
# Epoch 5: val_mean_io_u did not improve from 0.46420
# 51/51 [==============================] - 441s 9s/step - loss: 0.1062 - mean_io_u: 0.7541 - dice_coeficient: 0.8937 - val_loss: 0.2193 - val_mean_io_u: 0.4632 - val_dice_coeficient: 0.7813
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1034 - mean_io_u: 0.7802 - dice_coeficient: 0.8966
# Epoch 6: val_mean_io_u improved from 0.46420 to 0.48845, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.1034 - mean_io_u: 0.7802 - dice_coeficient: 0.8966 - val_loss: 0.1657 - val_mean_io_u: 0.4884 - val_dice_coeficient: 0.8348
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1015 - mean_io_u: 0.7949 - dice_coeficient: 0.8985
# Epoch 7: val_mean_io_u improved from 0.48845 to 0.53793, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 433s 8s/step - loss: 0.1015 - mean_io_u: 0.7949 - dice_coeficient: 0.8985 - val_loss: 0.1372 - val_mean_io_u: 0.5379 - val_dice_coeficient: 0.8634
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1002 - mean_io_u: 0.8091 - dice_coeficient: 0.8999
# Epoch 8: val_mean_io_u improved from 0.53793 to 0.61935, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 428s 8s/step - loss: 0.1002 - mean_io_u: 0.8091 - dice_coeficient: 0.8999 - val_loss: 0.1155 - val_mean_io_u: 0.6193 - val_dice_coeficient: 0.8850
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0992 - mean_io_u: 0.8194 - dice_coeficient: 0.9008
# Epoch 9: val_mean_io_u improved from 0.61935 to 0.70467, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 428s 8s/step - loss: 0.0992 - mean_io_u: 0.8194 - dice_coeficient: 0.9008 - val_loss: 0.1071 - val_mean_io_u: 0.7047 - val_dice_coeficient: 0.8933
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0984 - mean_io_u: 0.8270 - dice_coeficient: 0.9016
# Epoch 10: val_mean_io_u improved from 0.70467 to 0.76071, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.0984 - mean_io_u: 0.8270 - dice_coeficient: 0.9016 - val_loss: 0.1029 - val_mean_io_u: 0.7607 - val_dice_coeficient: 0.8976
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0975 - mean_io_u: 0.8376 - dice_coeficient: 0.9024
# Epoch 11: val_mean_io_u improved from 0.76071 to 0.80198, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 430s 8s/step - loss: 0.0975 - mean_io_u: 0.8376 - dice_coeficient: 0.9024 - val_loss: 0.1008 - val_mean_io_u: 0.8020 - val_dice_coeficient: 0.8996
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0969 - mean_io_u: 0.8422 - dice_coeficient: 0.9031
# Epoch 12: val_mean_io_u improved from 0.80198 to 0.82111, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 430s 8s/step - loss: 0.0969 - mean_io_u: 0.8422 - dice_coeficient: 0.9031 - val_loss: 0.0997 - val_mean_io_u: 0.8211 - val_dice_coeficient: 0.9008
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0965 - mean_io_u: 0.8470 - dice_coeficient: 0.9033
# Epoch 13: val_mean_io_u improved from 0.82111 to 0.83857, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 431s 8s/step - loss: 0.0965 - mean_io_u: 0.8470 - dice_coeficient: 0.9033 - val_loss: 0.0993 - val_mean_io_u: 0.8386 - val_dice_coeficient: 0.9012
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0963 - mean_io_u: 0.8504 - dice_coeficient: 0.9038
# Epoch 14: val_mean_io_u improved from 0.83857 to 0.84564, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.0963 - mean_io_u: 0.8504 - dice_coeficient: 0.9038 - val_loss: 0.0977 - val_mean_io_u: 0.8456 - val_dice_coeficient: 0.9027
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0957 - mean_io_u: 0.8544 - dice_coeficient: 0.9042
# Epoch 15: val_mean_io_u improved from 0.84564 to 0.85211, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 429s 8s/step - loss: 0.0957 - mean_io_u: 0.8544 - dice_coeficient: 0.9042 - val_loss: 0.0985 - val_mean_io_u: 0.8521 - val_dice_coeficient: 0.9019
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0952 - mean_io_u: 0.8582 - dice_coeficient: 0.9048
# Epoch 16: val_mean_io_u improved from 0.85211 to 0.86050, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 431s 8s/step - loss: 0.0952 - mean_io_u: 0.8582 - dice_coeficient: 0.9048 - val_loss: 0.0971 - val_mean_io_u: 0.8605 - val_dice_coeficient: 0.9033
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0950 - mean_io_u: 0.8614 - dice_coeficient: 0.9051
# Epoch 17: val_mean_io_u improved from 0.86050 to 0.86519, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 429s 8s/step - loss: 0.0950 - mean_io_u: 0.8614 - dice_coeficient: 0.9051 - val_loss: 0.0968 - val_mean_io_u: 0.8652 - val_dice_coeficient: 0.9036
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0947 - mean_io_u: 0.8649 - dice_coeficient: 0.9053
# Epoch 18: val_mean_io_u improved from 0.86519 to 0.86794, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 431s 8s/step - loss: 0.0947 - mean_io_u: 0.8649 - dice_coeficient: 0.9053 - val_loss: 0.0969 - val_mean_io_u: 0.8679 - val_dice_coeficient: 0.9036
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0946 - mean_io_u: 0.8664 - dice_coeficient: 0.9053
# Epoch 19: val_mean_io_u improved from 0.86794 to 0.86851, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 430s 8s/step - loss: 0.0946 - mean_io_u: 0.8664 - dice_coeficient: 0.9053 - val_loss: 0.0964 - val_mean_io_u: 0.8685 - val_dice_coeficient: 0.9040
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0943 - mean_io_u: 0.8690 - dice_coeficient: 0.9058
# Epoch 20: val_mean_io_u improved from 0.86851 to 0.87201, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 430s 8s/step - loss: 0.0943 - mean_io_u: 0.8690 - dice_coeficient: 0.9058 - val_loss: 0.0961 - val_mean_io_u: 0.8720 - val_dice_coeficient: 0.9043
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0943 - mean_io_u: 0.8702 - dice_coeficient: 0.9058
# Epoch 21: val_mean_io_u improved from 0.87201 to 0.87371, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 430s 8s/step - loss: 0.0943 - mean_io_u: 0.8702 - dice_coeficient: 0.9058 - val_loss: 0.0961 - val_mean_io_u: 0.8737 - val_dice_coeficient: 0.9043
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0939 - mean_io_u: 0.8725 - dice_coeficient: 0.9061
# Epoch 22: val_mean_io_u improved from 0.87371 to 0.87601, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 429s 8s/step - loss: 0.0939 - mean_io_u: 0.8725 - dice_coeficient: 0.9061 - val_loss: 0.0960 - val_mean_io_u: 0.8760 - val_dice_coeficient: 0.9045
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0937 - mean_io_u: 0.8735 - dice_coeficient: 0.9061
# Epoch 23: val_mean_io_u did not improve from 0.87601
# 51/51 [==============================] - 429s 8s/step - loss: 0.0937 - mean_io_u: 0.8735 - dice_coeficient: 0.9061 - val_loss: 0.0956 - val_mean_io_u: 0.8747 - val_dice_coeficient: 0.9048
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0936 - mean_io_u: 0.8746 - dice_coeficient: 0.9062
# Epoch 24: val_mean_io_u improved from 0.87601 to 0.87663, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 431s 8s/step - loss: 0.0936 - mean_io_u: 0.8746 - dice_coeficient: 0.9062 - val_loss: 0.0956 - val_mean_io_u: 0.8766 - val_dice_coeficient: 0.9048
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0934 - mean_io_u: 0.8760 - dice_coeficient: 0.9065
# Epoch 25: val_mean_io_u improved from 0.87663 to 0.87697, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 429s 8s/step - loss: 0.0934 - mean_io_u: 0.8760 - dice_coeficient: 0.9065 - val_loss: 0.0954 - val_mean_io_u: 0.8770 - val_dice_coeficient: 0.9051
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0930 - mean_io_u: 0.8752 - dice_coeficient: 0.9071
# Epoch 26: val_mean_io_u did not improve from 0.87697
# 51/51 [==============================] - 435s 9s/step - loss: 0.0930 - mean_io_u: 0.8752 - dice_coeficient: 0.9071 - val_loss: 0.0912 - val_mean_io_u: 0.8641 - val_dice_coeficient: 0.9092
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0753 - mean_io_u: 0.8594 - dice_coeficient: 0.9248
# Epoch 27: val_mean_io_u improved from 0.87697 to 0.88259, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 433s 9s/step - loss: 0.0753 - mean_io_u: 0.8594 - dice_coeficient: 0.9248 - val_loss: 0.0754 - val_mean_io_u: 0.8826 - val_dice_coeficient: 0.9250
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0658 - mean_io_u: 0.8798 - dice_coeficient: 0.9343
# Epoch 28: val_mean_io_u improved from 0.88259 to 0.88982, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.0658 - mean_io_u: 0.8798 - dice_coeficient: 0.9343 - val_loss: 0.0661 - val_mean_io_u: 0.8898 - val_dice_coeficient: 0.9342
# Epoch 29/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0637 - mean_io_u: 0.8870 - dice_coeficient: 0.9363
# Epoch 29: val_mean_io_u improved from 0.88982 to 0.89378, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 433s 8s/step - loss: 0.0637 - mean_io_u: 0.8870 - dice_coeficient: 0.9363 - val_loss: 0.0651 - val_mean_io_u: 0.8938 - val_dice_coeficient: 0.9353
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0629 - mean_io_u: 0.8913 - dice_coeficient: 0.9370
# Epoch 30: val_mean_io_u improved from 0.89378 to 0.89542, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 437s 9s/step - loss: 0.0629 - mean_io_u: 0.8913 - dice_coeficient: 0.9370 - val_loss: 0.0637 - val_mean_io_u: 0.8954 - val_dice_coeficient: 0.9366
# Epoch 31/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0623 - mean_io_u: 0.8946 - dice_coeficient: 0.9378
# Epoch 31: val_mean_io_u improved from 0.89542 to 0.89759, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 435s 9s/step - loss: 0.0623 - mean_io_u: 0.8946 - dice_coeficient: 0.9378 - val_loss: 0.0634 - val_mean_io_u: 0.8976 - val_dice_coeficient: 0.9369
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0619 - mean_io_u: 0.8969 - dice_coeficient: 0.9381
# Epoch 32: val_mean_io_u improved from 0.89759 to 0.90025, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 433s 9s/step - loss: 0.0619 - mean_io_u: 0.8969 - dice_coeficient: 0.9381 - val_loss: 0.0630 - val_mean_io_u: 0.9003 - val_dice_coeficient: 0.9374
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0617 - mean_io_u: 0.8982 - dice_coeficient: 0.9383
# Epoch 33: val_mean_io_u did not improve from 0.90025
# 51/51 [==============================] - 435s 9s/step - loss: 0.0617 - mean_io_u: 0.8982 - dice_coeficient: 0.9383 - val_loss: 0.0631 - val_mean_io_u: 0.8997 - val_dice_coeficient: 0.9372
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0615 - mean_io_u: 0.9012 - dice_coeficient: 0.9385
# Epoch 34: val_mean_io_u improved from 0.90025 to 0.90325, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.0615 - mean_io_u: 0.9012 - dice_coeficient: 0.9385 - val_loss: 0.0624 - val_mean_io_u: 0.9033 - val_dice_coeficient: 0.9379
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0613 - mean_io_u: 0.9040 - dice_coeficient: 0.9387
# Epoch 35: val_mean_io_u improved from 0.90325 to 0.90801, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 435s 9s/step - loss: 0.0613 - mean_io_u: 0.9040 - dice_coeficient: 0.9387 - val_loss: 0.0623 - val_mean_io_u: 0.9080 - val_dice_coeficient: 0.9380
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0611 - mean_io_u: 0.9057 - dice_coeficient: 0.9389
# Epoch 36: val_mean_io_u did not improve from 0.90801
# 51/51 [==============================] - 434s 9s/step - loss: 0.0611 - mean_io_u: 0.9057 - dice_coeficient: 0.9389 - val_loss: 0.0625 - val_mean_io_u: 0.9074 - val_dice_coeficient: 0.9378
# Epoch 37/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0610 - mean_io_u: 0.9067 - dice_coeficient: 0.9390
# Epoch 37: val_mean_io_u improved from 0.90801 to 0.90998, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 436s 9s/step - loss: 0.0610 - mean_io_u: 0.9067 - dice_coeficient: 0.9390 - val_loss: 0.0624 - val_mean_io_u: 0.9100 - val_dice_coeficient: 0.9379
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0609 - mean_io_u: 0.9076 - dice_coeficient: 0.9392
# Epoch 38: val_mean_io_u did not improve from 0.90998
# 51/51 [==============================] - 434s 9s/step - loss: 0.0609 - mean_io_u: 0.9076 - dice_coeficient: 0.9392 - val_loss: 0.0623 - val_mean_io_u: 0.9085 - val_dice_coeficient: 0.9380
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0607 - mean_io_u: 0.9088 - dice_coeficient: 0.9394
# Epoch 39: val_mean_io_u improved from 0.90998 to 0.91210, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.0607 - mean_io_u: 0.9088 - dice_coeficient: 0.9394 - val_loss: 0.0620 - val_mean_io_u: 0.9121 - val_dice_coeficient: 0.9383
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0605 - mean_io_u: 0.9106 - dice_coeficient: 0.9395
# Epoch 40: val_mean_io_u did not improve from 0.91210
# 51/51 [==============================] - 432s 8s/step - loss: 0.0605 - mean_io_u: 0.9106 - dice_coeficient: 0.9395 - val_loss: 0.0619 - val_mean_io_u: 0.9101 - val_dice_coeficient: 0.9384
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0604 - mean_io_u: 0.9112 - dice_coeficient: 0.9395
# Epoch 41: val_mean_io_u improved from 0.91210 to 0.91328, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 434s 9s/step - loss: 0.0604 - mean_io_u: 0.9112 - dice_coeficient: 0.9395 - val_loss: 0.0618 - val_mean_io_u: 0.9133 - val_dice_coeficient: 0.9385
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0604 - mean_io_u: 0.9125 - dice_coeficient: 0.9397
# Epoch 42: val_mean_io_u improved from 0.91328 to 0.91358, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 435s 9s/step - loss: 0.0604 - mean_io_u: 0.9125 - dice_coeficient: 0.9397 - val_loss: 0.0616 - val_mean_io_u: 0.9136 - val_dice_coeficient: 0.9387
# Epoch 43/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0601 - mean_io_u: 0.9146 - dice_coeficient: 0.9400
# Epoch 43: val_mean_io_u improved from 0.91358 to 0.91519, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 436s 9s/step - loss: 0.0601 - mean_io_u: 0.9146 - dice_coeficient: 0.9400 - val_loss: 0.0616 - val_mean_io_u: 0.9152 - val_dice_coeficient: 0.9387
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0600 - mean_io_u: 0.9167 - dice_coeficient: 0.9400
# Epoch 44: val_mean_io_u improved from 0.91519 to 0.91865, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.0600 - mean_io_u: 0.9167 - dice_coeficient: 0.9400 - val_loss: 0.0619 - val_mean_io_u: 0.9186 - val_dice_coeficient: 0.9384
# Epoch 45/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0599 - mean_io_u: 0.9173 - dice_coeficient: 0.9401
# Epoch 45: val_mean_io_u did not improve from 0.91865
# 51/51 [==============================] - 430s 8s/step - loss: 0.0599 - mean_io_u: 0.9173 - dice_coeficient: 0.9401 - val_loss: 0.0615 - val_mean_io_u: 0.9170 - val_dice_coeficient: 0.9388
# Epoch 46/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0598 - mean_io_u: 0.9184 - dice_coeficient: 0.9401
# Epoch 46: val_mean_io_u improved from 0.91865 to 0.92189, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 433s 8s/step - loss: 0.0598 - mean_io_u: 0.9184 - dice_coeficient: 0.9401 - val_loss: 0.0615 - val_mean_io_u: 0.9219 - val_dice_coeficient: 0.9388
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0597 - mean_io_u: 0.9201 - dice_coeficient: 0.9402
# Epoch 47: val_mean_io_u improved from 0.92189 to 0.92584, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 431s 8s/step - loss: 0.0597 - mean_io_u: 0.9201 - dice_coeficient: 0.9402 - val_loss: 0.0613 - val_mean_io_u: 0.9258 - val_dice_coeficient: 0.9390
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0596 - mean_io_u: 0.9213 - dice_coeficient: 0.9403
# Epoch 48: val_mean_io_u did not improve from 0.92584
# 51/51 [==============================] - 431s 8s/step - loss: 0.0596 - mean_io_u: 0.9213 - dice_coeficient: 0.9403 - val_loss: 0.0613 - val_mean_io_u: 0.9232 - val_dice_coeficient: 0.9390
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0595 - mean_io_u: 0.9211 - dice_coeficient: 0.9404
# Epoch 49: val_mean_io_u improved from 0.92584 to 0.92799, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.0595 - mean_io_u: 0.9211 - dice_coeficient: 0.9404 - val_loss: 0.0616 - val_mean_io_u: 0.9280 - val_dice_coeficient: 0.9387
# Epoch 50/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0594 - mean_io_u: 0.9231 - dice_coeficient: 0.9405
# Epoch 50: val_mean_io_u did not improve from 0.92799
# 51/51 [==============================] - 432s 8s/step - loss: 0.0594 - mean_io_u: 0.9231 - dice_coeficient: 0.9405 - val_loss: 0.0613 - val_mean_io_u: 0.9195 - val_dice_coeficient: 0.9390
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0593 - mean_io_u: 0.9238 - dice_coeficient: 0.9408
# Epoch 51: val_mean_io_u did not improve from 0.92799
# 51/51 [==============================] - 431s 8s/step - loss: 0.0593 - mean_io_u: 0.9238 - dice_coeficient: 0.9408 - val_loss: 0.0610 - val_mean_io_u: 0.9267 - val_dice_coeficient: 0.9393
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0593 - mean_io_u: 0.9241 - dice_coeficient: 0.9406
# Epoch 52: val_mean_io_u improved from 0.92799 to 0.92909, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.0593 - mean_io_u: 0.9241 - dice_coeficient: 0.9406 - val_loss: 0.0608 - val_mean_io_u: 0.9291 - val_dice_coeficient: 0.9395
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0593 - mean_io_u: 0.9248 - dice_coeficient: 0.9407
# Epoch 53: val_mean_io_u did not improve from 0.92909
# 51/51 [==============================] - 432s 8s/step - loss: 0.0593 - mean_io_u: 0.9248 - dice_coeficient: 0.9407 - val_loss: 0.0609 - val_mean_io_u: 0.9278 - val_dice_coeficient: 0.9393
# Epoch 54/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0592 - mean_io_u: 0.9253 - dice_coeficient: 0.9408
# Epoch 54: val_mean_io_u did not improve from 0.92909
# 51/51 [==============================] - 432s 8s/step - loss: 0.0592 - mean_io_u: 0.9253 - dice_coeficient: 0.9408 - val_loss: 0.0609 - val_mean_io_u: 0.9264 - val_dice_coeficient: 0.9394
# Epoch 55/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0591 - mean_io_u: 0.9272 - dice_coeficient: 0.9409
# Epoch 55: val_mean_io_u improved from 0.92909 to 0.92971, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 434s 9s/step - loss: 0.0591 - mean_io_u: 0.9272 - dice_coeficient: 0.9409 - val_loss: 0.0612 - val_mean_io_u: 0.9297 - val_dice_coeficient: 0.9391
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0593 - mean_io_u: 0.9265 - dice_coeficient: 0.9407
# Epoch 56: val_mean_io_u did not improve from 0.92971
# 51/51 [==============================] - 433s 8s/step - loss: 0.0593 - mean_io_u: 0.9265 - dice_coeficient: 0.9407 - val_loss: 0.0608 - val_mean_io_u: 0.9284 - val_dice_coeficient: 0.9395
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0590 - mean_io_u: 0.9278 - dice_coeficient: 0.9410
# Epoch 57: val_mean_io_u did not improve from 0.92971
# 51/51 [==============================] - 432s 8s/step - loss: 0.0590 - mean_io_u: 0.9278 - dice_coeficient: 0.9410 - val_loss: 0.0608 - val_mean_io_u: 0.9297 - val_dice_coeficient: 0.9395
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0590 - mean_io_u: 0.9273 - dice_coeficient: 0.9409
# Epoch 58: val_mean_io_u did not improve from 0.92971
# 51/51 [==============================] - 432s 8s/step - loss: 0.0590 - mean_io_u: 0.9273 - dice_coeficient: 0.9409 - val_loss: 0.0606 - val_mean_io_u: 0.9290 - val_dice_coeficient: 0.9397
# Epoch 59/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0589 - mean_io_u: 0.9261 - dice_coeficient: 0.9411
# Epoch 59: val_mean_io_u did not improve from 0.92971
# 51/51 [==============================] - 432s 8s/step - loss: 0.0589 - mean_io_u: 0.9261 - dice_coeficient: 0.9411 - val_loss: 0.0608 - val_mean_io_u: 0.9243 - val_dice_coeficient: 0.9395
# Epoch 60/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0588 - mean_io_u: 0.9212 - dice_coeficient: 0.9412
# Epoch 60: val_mean_io_u did not improve from 0.92971
# 51/51 [==============================] - 432s 8s/step - loss: 0.0588 - mean_io_u: 0.9212 - dice_coeficient: 0.9412 - val_loss: 0.0608 - val_mean_io_u: 0.9175 - val_dice_coeficient: 0.9395
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0589 - mean_io_u: 0.9175 - dice_coeficient: 0.9410
# Epoch 61: val_mean_io_u did not improve from 0.92971
# 51/51 [==============================] - 432s 8s/step - loss: 0.0589 - mean_io_u: 0.9175 - dice_coeficient: 0.9410 - val_loss: 0.0607 - val_mean_io_u: 0.9180 - val_dice_coeficient: 0.9396
# Epoch 62/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0507 - mean_io_u: 0.9172 - dice_coeficient: 0.9494
# Epoch 62: val_mean_io_u did not improve from 0.92971
# 51/51 [==============================] - 432s 8s/step - loss: 0.0507 - mean_io_u: 0.9172 - dice_coeficient: 0.9494 - val_loss: 0.0461 - val_mean_io_u: 0.9282 - val_dice_coeficient: 0.9541
# Epoch 63/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0450 - mean_io_u: 0.9284 - dice_coeficient: 0.9550
# Epoch 63: val_mean_io_u improved from 0.92971 to 0.93334, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 436s 9s/step - loss: 0.0450 - mean_io_u: 0.9284 - dice_coeficient: 0.9550 - val_loss: 0.0447 - val_mean_io_u: 0.9333 - val_dice_coeficient: 0.9555
# Epoch 64/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0442 - mean_io_u: 0.9321 - dice_coeficient: 0.9557
# Epoch 64: val_mean_io_u improved from 0.93334 to 0.93496, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 433s 8s/step - loss: 0.0442 - mean_io_u: 0.9321 - dice_coeficient: 0.9557 - val_loss: 0.0443 - val_mean_io_u: 0.9350 - val_dice_coeficient: 0.9558
# Epoch 65/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0439 - mean_io_u: 0.9337 - dice_coeficient: 0.9561
# Epoch 65: val_mean_io_u did not improve from 0.93496
# 51/51 [==============================] - 432s 8s/step - loss: 0.0439 - mean_io_u: 0.9337 - dice_coeficient: 0.9561 - val_loss: 0.0444 - val_mean_io_u: 0.9335 - val_dice_coeficient: 0.9557
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0437 - mean_io_u: 0.9373 - dice_coeficient: 0.9563
# Epoch 66: val_mean_io_u improved from 0.93496 to 0.93610, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.0437 - mean_io_u: 0.9373 - dice_coeficient: 0.9563 - val_loss: 0.0443 - val_mean_io_u: 0.9361 - val_dice_coeficient: 0.9558
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0436 - mean_io_u: 0.9395 - dice_coeficient: 0.9564
# Epoch 67: val_mean_io_u improved from 0.93610 to 0.94327, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 434s 9s/step - loss: 0.0436 - mean_io_u: 0.9395 - dice_coeficient: 0.9564 - val_loss: 0.0438 - val_mean_io_u: 0.9433 - val_dice_coeficient: 0.9564
# Epoch 68/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0434 - mean_io_u: 0.9403 - dice_coeficient: 0.9566
# Epoch 68: val_mean_io_u did not improve from 0.94327
# 51/51 [==============================] - 436s 9s/step - loss: 0.0434 - mean_io_u: 0.9403 - dice_coeficient: 0.9566 - val_loss: 0.0439 - val_mean_io_u: 0.9431 - val_dice_coeficient: 0.9562
# Epoch 69/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0435 - mean_io_u: 0.9425 - dice_coeficient: 0.9564
# Epoch 69: val_mean_io_u improved from 0.94327 to 0.94638, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.0435 - mean_io_u: 0.9425 - dice_coeficient: 0.9564 - val_loss: 0.0439 - val_mean_io_u: 0.9464 - val_dice_coeficient: 0.9563
# Epoch 70/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0433 - mean_io_u: 0.9429 - dice_coeficient: 0.9567
# Epoch 70: val_mean_io_u did not improve from 0.94638
# 51/51 [==============================] - 427s 8s/step - loss: 0.0433 - mean_io_u: 0.9429 - dice_coeficient: 0.9567 - val_loss: 0.0437 - val_mean_io_u: 0.9460 - val_dice_coeficient: 0.9564
# Epoch 71/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0432 - mean_io_u: 0.9444 - dice_coeficient: 0.9568
# Epoch 71: val_mean_io_u did not improve from 0.94638
# 51/51 [==============================] - 429s 8s/step - loss: 0.0432 - mean_io_u: 0.9444 - dice_coeficient: 0.9568 - val_loss: 0.0436 - val_mean_io_u: 0.9458 - val_dice_coeficient: 0.9565
# Epoch 72/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0431 - mean_io_u: 0.9449 - dice_coeficient: 0.9568
# Epoch 72: val_mean_io_u did not improve from 0.94638
# 51/51 [==============================] - 429s 8s/step - loss: 0.0431 - mean_io_u: 0.9449 - dice_coeficient: 0.9568 - val_loss: 0.0439 - val_mean_io_u: 0.9453 - val_dice_coeficient: 0.9562
# Epoch 73/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0432 - mean_io_u: 0.9449 - dice_coeficient: 0.9568
# Epoch 73: val_mean_io_u improved from 0.94638 to 0.94757, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.0432 - mean_io_u: 0.9449 - dice_coeficient: 0.9568 - val_loss: 0.0437 - val_mean_io_u: 0.9476 - val_dice_coeficient: 0.9565
# Epoch 74/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0430 - mean_io_u: 0.9469 - dice_coeficient: 0.9569
# Epoch 74: val_mean_io_u improved from 0.94757 to 0.94919, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 429s 8s/step - loss: 0.0430 - mean_io_u: 0.9469 - dice_coeficient: 0.9569 - val_loss: 0.0437 - val_mean_io_u: 0.9492 - val_dice_coeficient: 0.9564
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0430 - mean_io_u: 0.9470 - dice_coeficient: 0.9570
# Epoch 75: val_mean_io_u did not improve from 0.94919
# 51/51 [==============================] - 427s 8s/step - loss: 0.0430 - mean_io_u: 0.9470 - dice_coeficient: 0.9570 - val_loss: 0.0440 - val_mean_io_u: 0.9483 - val_dice_coeficient: 0.9562
# Epoch 76/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0430 - mean_io_u: 0.9477 - dice_coeficient: 0.9570
# Epoch 76: val_mean_io_u did not improve from 0.94919
# 51/51 [==============================] - 428s 8s/step - loss: 0.0430 - mean_io_u: 0.9477 - dice_coeficient: 0.9570 - val_loss: 0.0438 - val_mean_io_u: 0.9488 - val_dice_coeficient: 0.9564
# Epoch 77/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0429 - mean_io_u: 0.9476 - dice_coeficient: 0.9570
# Epoch 77: val_mean_io_u did not improve from 0.94919
# 51/51 [==============================] - 427s 8s/step - loss: 0.0429 - mean_io_u: 0.9476 - dice_coeficient: 0.9570 - val_loss: 0.0436 - val_mean_io_u: 0.9482 - val_dice_coeficient: 0.9566
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0428 - mean_io_u: 0.9479 - dice_coeficient: 0.9573
# Epoch 78: val_mean_io_u did not improve from 0.94919
# 51/51 [==============================] - 426s 8s/step - loss: 0.0428 - mean_io_u: 0.9479 - dice_coeficient: 0.9573 - val_loss: 0.0433 - val_mean_io_u: 0.9488 - val_dice_coeficient: 0.9568
# Epoch 79/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0426 - mean_io_u: 0.9486 - dice_coeficient: 0.9574
# Epoch 79: val_mean_io_u improved from 0.94919 to 0.94922, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 426s 8s/step - loss: 0.0426 - mean_io_u: 0.9486 - dice_coeficient: 0.9574 - val_loss: 0.0433 - val_mean_io_u: 0.9492 - val_dice_coeficient: 0.9568
# Epoch 80/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0426 - mean_io_u: 0.9489 - dice_coeficient: 0.9574
# Epoch 80: val_mean_io_u improved from 0.94922 to 0.94956, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 430s 8s/step - loss: 0.0426 - mean_io_u: 0.9489 - dice_coeficient: 0.9574 - val_loss: 0.0433 - val_mean_io_u: 0.9496 - val_dice_coeficient: 0.9568
# Epoch 81/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0426 - mean_io_u: 0.9485 - dice_coeficient: 0.9574
# Epoch 81: val_mean_io_u did not improve from 0.94956
# 51/51 [==============================] - 428s 8s/step - loss: 0.0426 - mean_io_u: 0.9485 - dice_coeficient: 0.9574 - val_loss: 0.0438 - val_mean_io_u: 0.9491 - val_dice_coeficient: 0.9564
# Epoch 82/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0426 - mean_io_u: 0.9490 - dice_coeficient: 0.9574
# Epoch 82: val_mean_io_u did not improve from 0.94956
# 51/51 [==============================] - 429s 8s/step - loss: 0.0426 - mean_io_u: 0.9490 - dice_coeficient: 0.9574 - val_loss: 0.0436 - val_mean_io_u: 0.9493 - val_dice_coeficient: 0.9565
# Epoch 83/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0425 - mean_io_u: 0.9497 - dice_coeficient: 0.9575
# Epoch 83: val_mean_io_u did not improve from 0.94956
# 51/51 [==============================] - 428s 8s/step - loss: 0.0425 - mean_io_u: 0.9497 - dice_coeficient: 0.9575 - val_loss: 0.0435 - val_mean_io_u: 0.9492 - val_dice_coeficient: 0.9567
# Epoch 84/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0424 - mean_io_u: 0.9500 - dice_coeficient: 0.9576
# Epoch 84: val_mean_io_u improved from 0.94956 to 0.95090, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 429s 8s/step - loss: 0.0424 - mean_io_u: 0.9500 - dice_coeficient: 0.9576 - val_loss: 0.0432 - val_mean_io_u: 0.9509 - val_dice_coeficient: 0.9570
# Epoch 85/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0427 - mean_io_u: 0.9497 - dice_coeficient: 0.9573
# Epoch 85: val_mean_io_u improved from 0.95090 to 0.95112, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 427s 8s/step - loss: 0.0427 - mean_io_u: 0.9497 - dice_coeficient: 0.9573 - val_loss: 0.0433 - val_mean_io_u: 0.9511 - val_dice_coeficient: 0.9568
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0425 - mean_io_u: 0.9506 - dice_coeficient: 0.9575
# Epoch 86: val_mean_io_u did not improve from 0.95112
# 51/51 [==============================] - 433s 9s/step - loss: 0.0425 - mean_io_u: 0.9506 - dice_coeficient: 0.9575 - val_loss: 0.0441 - val_mean_io_u: 0.9498 - val_dice_coeficient: 0.9560
# Epoch 87/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0425 - mean_io_u: 0.9507 - dice_coeficient: 0.9576
# Epoch 87: val_mean_io_u did not improve from 0.95112
# 51/51 [==============================] - 431s 8s/step - loss: 0.0425 - mean_io_u: 0.9507 - dice_coeficient: 0.9576 - val_loss: 0.0432 - val_mean_io_u: 0.9511 - val_dice_coeficient: 0.9570
# Epoch 88/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0424 - mean_io_u: 0.9506 - dice_coeficient: 0.9576
# Epoch 88: val_mean_io_u improved from 0.95112 to 0.95130, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 433s 9s/step - loss: 0.0424 - mean_io_u: 0.9506 - dice_coeficient: 0.9576 - val_loss: 0.0432 - val_mean_io_u: 0.9513 - val_dice_coeficient: 0.9569
# Epoch 89/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0424 - mean_io_u: 0.9512 - dice_coeficient: 0.9577
# Epoch 89: val_mean_io_u improved from 0.95130 to 0.95180, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 430s 8s/step - loss: 0.0424 - mean_io_u: 0.9512 - dice_coeficient: 0.9577 - val_loss: 0.0431 - val_mean_io_u: 0.9518 - val_dice_coeficient: 0.9570
# Epoch 90/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0423 - mean_io_u: 0.9512 - dice_coeficient: 0.9577
# Epoch 90: val_mean_io_u did not improve from 0.95180
# 51/51 [==============================] - 430s 8s/step - loss: 0.0423 - mean_io_u: 0.9512 - dice_coeficient: 0.9577 - val_loss: 0.0430 - val_mean_io_u: 0.9517 - val_dice_coeficient: 0.9571
# Epoch 91/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0423 - mean_io_u: 0.9515 - dice_coeficient: 0.9578
# Epoch 91: val_mean_io_u did not improve from 0.95180
# 51/51 [==============================] - 438s 9s/step - loss: 0.0423 - mean_io_u: 0.9515 - dice_coeficient: 0.9578 - val_loss: 0.0431 - val_mean_io_u: 0.9512 - val_dice_coeficient: 0.9570
# Epoch 92/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0422 - mean_io_u: 0.9517 - dice_coeficient: 0.9579
# Epoch 92: val_mean_io_u improved from 0.95180 to 0.95211, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 433s 8s/step - loss: 0.0422 - mean_io_u: 0.9517 - dice_coeficient: 0.9579 - val_loss: 0.0430 - val_mean_io_u: 0.9521 - val_dice_coeficient: 0.9571
# Epoch 93/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0422 - mean_io_u: 0.9519 - dice_coeficient: 0.9578
# Epoch 93: val_mean_io_u did not improve from 0.95211
# 51/51 [==============================] - 434s 9s/step - loss: 0.0422 - mean_io_u: 0.9519 - dice_coeficient: 0.9578 - val_loss: 0.0433 - val_mean_io_u: 0.9518 - val_dice_coeficient: 0.9568
# Epoch 94/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0422 - mean_io_u: 0.9520 - dice_coeficient: 0.9577
# Epoch 94: val_mean_io_u did not improve from 0.95211
# 51/51 [==============================] - 432s 8s/step - loss: 0.0422 - mean_io_u: 0.9520 - dice_coeficient: 0.9577 - val_loss: 0.0431 - val_mean_io_u: 0.9518 - val_dice_coeficient: 0.9570
# Epoch 95/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0422 - mean_io_u: 0.9522 - dice_coeficient: 0.9579
# Epoch 95: val_mean_io_u improved from 0.95211 to 0.95225, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 434s 9s/step - loss: 0.0422 - mean_io_u: 0.9522 - dice_coeficient: 0.9579 - val_loss: 0.0429 - val_mean_io_u: 0.9523 - val_dice_coeficient: 0.9573
# Epoch 96/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0421 - mean_io_u: 0.9523 - dice_coeficient: 0.9578
# Epoch 96: val_mean_io_u did not improve from 0.95225
# 51/51 [==============================] - 442s 9s/step - loss: 0.0421 - mean_io_u: 0.9523 - dice_coeficient: 0.9578 - val_loss: 0.0432 - val_mean_io_u: 0.9517 - val_dice_coeficient: 0.9570
# Epoch 97/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0420 - mean_io_u: 0.9528 - dice_coeficient: 0.9580
# Epoch 97: val_mean_io_u improved from 0.95225 to 0.95303, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 438s 9s/step - loss: 0.0420 - mean_io_u: 0.9528 - dice_coeficient: 0.9580 - val_loss: 0.0430 - val_mean_io_u: 0.9530 - val_dice_coeficient: 0.9572
# Epoch 98/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0419 - mean_io_u: 0.9532 - dice_coeficient: 0.9580
# Epoch 98: val_mean_io_u improved from 0.95303 to 0.95313, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 436s 9s/step - loss: 0.0419 - mean_io_u: 0.9532 - dice_coeficient: 0.9580 - val_loss: 0.0429 - val_mean_io_u: 0.9531 - val_dice_coeficient: 0.9573
# Epoch 99/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0419 - mean_io_u: 0.9530 - dice_coeficient: 0.9580
# Epoch 99: val_mean_io_u did not improve from 0.95313
# 51/51 [==============================] - 438s 9s/step - loss: 0.0419 - mean_io_u: 0.9530 - dice_coeficient: 0.9580 - val_loss: 0.0431 - val_mean_io_u: 0.9529 - val_dice_coeficient: 0.9571
# Epoch 100/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0419 - mean_io_u: 0.9532 - dice_coeficient: 0.9581
# Epoch 100: val_mean_io_u improved from 0.95313 to 0.95323, saving model to ../models\u-net-BN_tversky.hdf5
# 51/51 [==============================] - 435s 9s/step - loss: 0.0419 - mean_io_u: 0.9532 - dice_coeficient: 0.9581 - val_loss: 0.0430 - val_mean_io_u: 0.9532 - val_dice_coeficient: 0.9571

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='lower right')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/u-net_100epochs.hdf5')

# %%
pred = unet_model.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 21s 399ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1), cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx], cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
# --
# **TFG - Adrián Contreras Castillo**
# --
