# %% [markdown]
# # Deep Learning: Laparoscopic segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import random
import cv2
import tensorflow as tf
import keras.backend as K
from skimage import exposure
from skimage.color import rgb2gray
from sklearn.model_selection import train_test_split
from glob import glob
import pickle
import segmentation_models as sm
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: False

# %%
SEED = 17
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)
CLASS_WEIGHTS = [2.45780159e-01, 2.24610010e-01, 2.24005501e-01, 1.87119512e-02,
 1.46965911e-01, 2.54698498e-02, 2.35562466e-02, 4.28713053e-03,
 3.93593665e-04, 1.38500705e-02, 6.78984614e-02, 1.01436955e-04,
 4.36967906e-03]

# %%
# https://gist.github.com/IdeaKing/11cf5e146d23c5bb219ba3508cca89ec
def resize_with_pad(image: np.array, 
                    new_shape, 
                    padding_color = (0, 0, 0)) -> np.array:
    """Maintains aspect ratio and resizes with padding.
    Params:
        image: Image to be resized.
        new_shape: Expected (width, height) of new image.
        padding_color: Tuple in BGR of padding color
    Returns:
        image: Resized image with padding
    """
    original_shape = (image.shape[1], image.shape[0])
    ratio = float(max(new_shape))/max(original_shape)
    new_size = tuple([int(x*ratio) for x in original_shape])
    image = cv2.resize(image, new_size, interpolation=cv2.INTER_NEAREST)
    delta_w = new_shape[0] - new_size[0]
    delta_h = new_shape[1] - new_size[1]
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)
    image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT, value=padding_color)
    return image

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 120:-120,:]
    img = resize_with_pad(img, (HEIGHT, WIDTH))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 120:-120,:]
    mask = resize_with_pad(mask, (HEIGHT, WIDTH), (50, 50, 50))
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx], cmap='afmhot')
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
# dump_data(X, y)
# X, y = load_data()
np.unique(y_encoded[idx])
# Out:
# array([ 0,  2,  3,  4, 10], dtype=uint8)

# %%
plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1), cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## U-Net

# %%
def double_conv_block(x, n_filters):

   # Conv2D then ReLU activation
   x = tf.keras.layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
   # Conv2D then ReLU activation
   x = tf.keras.layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)

   return x

def downsample_block(x, n_filters):
   f = double_conv_block(x, n_filters)
   p = tf.keras.layers.MaxPool2D(2)(f)
   p = tf.keras.layers.Dropout(0.2)(p)

   return f, p

def upsample_block(x, conv_features, n_filters):
   # upsample
   x = tf.keras.layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
   # concatenate
   x = tf.keras.layers.concatenate([x, conv_features])
   # dropout
   x = tf.keras.layers.Dropout(0.2)(x)
   # Conv2D twice with ReLU activation
   x = double_conv_block(x, n_filters)

   return x

def build_unet_model(n_filters=64, n_classes=2):
   # inputs
   inputs = tf.keras.layers.Input(shape=(HEIGHT,WIDTH,3))

   # encoder: contracting path - downsample
   # 1 - downsample
   f1, p1 = downsample_block(inputs, n_filters)
   # 2 - downsample
   f2, p2 = downsample_block(p1, n_filters*2)
   # 3 - downsample
   f3, p3 = downsample_block(p2, n_filters*4)
   # 4 - downsample
   f4, p4 = downsample_block(p3, n_filters*8)

   # 5 - bottleneck
   bottleneck = double_conv_block(p4, n_filters*16)

   # decoder: expanding path - upsample
   # 6 - upsample
   u6 = upsample_block(bottleneck, f4, n_filters*8)
   # 7 - upsample
   u7 = upsample_block(u6, f3, n_filters*4)
   # 8 - upsample
   u8 = upsample_block(u7, f2, n_filters*2)
   # 9 - upsample
   u9 = upsample_block(u8, f1, n_filters)

   # outputs
   
   activation = 'sigmoid' if n_classes == 2 else 'softmax'
   outputs = tf.keras.layers.Conv2D(n_classes, 1, padding="same", activation=activation)(u9)

   # unet model with Keras Functional API
   unet_model = tf.keras.Model(inputs, outputs, name="U-Net")

   return unet_model

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

def dice_loss(y_true, y_pred):
    return 1 - dice_coeficient(y_true, y_pred)

def tversky(y_true, y_pred, smooth=1e-6, alpha=0.75):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)
    TP = tf.keras.backend.sum(T * P)
    FN = tf.keras.backend.sum(T * (1 - P))
    FP = tf.keras.backend.sum((1 - T) * P)
    return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true, y_pred)


def focal_tversky_loss(y_true, y_pred, gamma=0.75):
    tv = tversky(y_true, y_pred)
    return tf.keras.backend.pow((1 - tv), gamma)

def generalized_dice_coeff(y_true, y_pred, smooth=1e-9):
    Ncl = y_pred.shape[-1]
    w = np.zeros((Ncl,))
    w = K.sum(y_true, (0,1,2))
    w = 1 / (w ** 2 + smooth)

    y_pred = tf.nn.softmax(y_pred)

    # Compute gen dice coef:
    numerator = y_true * y_pred
    numerator = w * K.sum(numerator, (0,1,2))
    numerator = K.sum(numerator)

    denominator = y_true + y_pred
    denominator = w * K.sum(denominator, (0,1,2))
    denominator = K.sum(denominator)

    return 2. * (numerator + smooth) / (denominator + smooth)


def generalized_dice_loss(y_true, y_pred):
    return 1. - generalized_dice_coeff(y_true, y_pred)

# %%
unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.load_weights('../models/u-net_39-0.22_tversky_loss.hdf5')
unet_model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4), 
    loss=sm.losses.DiceLoss(class_weights=CLASS_WEIGHTS),
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)

unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 64, 64, 32)   896         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 32)   9248        ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 32)   0           ['conv2d_1[0][0]']
#
#  dropout (Dropout)              (None, 32, 32, 32)   0           ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 64)   18496       ['dropout[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   36928       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)  0           ['conv2d_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 16, 16, 64)   0           ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 128)  73856       ['dropout_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 128)   0           ['conv2d_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 8, 8, 128)    0           ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 8, 8, 256)    295168      ['dropout_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 256)    590080      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 256)   0           ['conv2d_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 4, 4, 256)    0           ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 4, 4, 512)    1180160     ['dropout_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 4, 4, 512)    2359808     ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 8, 8, 256)   1179904     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 8, 8, 512)    0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 8, 8, 512)    0           ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 8, 8, 256)    1179904     ['dropout_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 256)    590080      ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 16, 16, 128)  295040     ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 16, 16, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 16, 16, 256)  0           ['concatenate_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 128)  295040      ['dropout_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 128)  147584      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 32, 32, 64)  73792       ['conv2d_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 32, 32, 128)  0           ['concatenate_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 64)   73792       ['dropout_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 64)   36928       ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 64, 64, 32)  18464       ['conv2d_15[0][0]']
#  spose)
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_3[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  dropout_7 (Dropout)            (None, 64, 64, 64)   0           ['concatenate_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 32)   18464       ['dropout_7[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 32)   9248        ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 13)   429         ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 8,630,893
# Trainable params: 8,630,893
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/u-net_diceLoss.hdf5',
    verbose=1,
    monitor='val_mean_io_u',
    save_best_only=True,
    save_weights_only=True,
    mode='max'
)

print('\n\t TRAINING\n')

model_history = unet_model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9856 - mean_io_u: 0.4806 - dice_coeficient: 0.1873
# Epoch 1: val_mean_io_u improved from -inf to 0.60125, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 414s 8s/step - loss: 0.9856 - mean_io_u: 0.4806 - dice_coeficient: 0.1873 - val_loss: 0.9669 - val_mean_io_u: 0.6012 - val_dice_coeficient: 0.4926
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9640 - mean_io_u: 0.6452 - dice_coeficient: 0.5367
# Epoch 2: val_mean_io_u improved from 0.60125 to 0.66911, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 439s 9s/step - loss: 0.9640 - mean_io_u: 0.6452 - dice_coeficient: 0.5367 - val_loss: 0.9618 - val_mean_io_u: 0.6691 - val_dice_coeficient: 0.5713
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9608 - mean_io_u: 0.6611 - dice_coeficient: 0.5691
# Epoch 3: val_mean_io_u did not improve from 0.66911
# 51/51 [==============================] - 430s 8s/step - loss: 0.9608 - mean_io_u: 0.6611 - dice_coeficient: 0.5691 - val_loss: 0.9602 - val_mean_io_u: 0.6416 - val_dice_coeficient: 0.5765
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9593 - mean_io_u: 0.6373 - dice_coeficient: 0.5838
# Epoch 4: val_mean_io_u did not improve from 0.66911
# 51/51 [==============================] - 420s 8s/step - loss: 0.9593 - mean_io_u: 0.6373 - dice_coeficient: 0.5838 - val_loss: 0.9589 - val_mean_io_u: 0.5834 - val_dice_coeficient: 0.5870
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9562 - mean_io_u: 0.6428 - dice_coeficient: 0.6070
# Epoch 5: val_mean_io_u did not improve from 0.66911
# 51/51 [==============================] - 438s 9s/step - loss: 0.9562 - mean_io_u: 0.6428 - dice_coeficient: 0.6070 - val_loss: 0.9534 - val_mean_io_u: 0.6422 - val_dice_coeficient: 0.6399
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9523 - mean_io_u: 0.6657 - dice_coeficient: 0.6456
# Epoch 6: val_mean_io_u did not improve from 0.66911
# 51/51 [==============================] - 438s 9s/step - loss: 0.9523 - mean_io_u: 0.6657 - dice_coeficient: 0.6456 - val_loss: 0.9517 - val_mean_io_u: 0.6574 - val_dice_coeficient: 0.6551
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9511 - mean_io_u: 0.6782 - dice_coeficient: 0.6598
# Epoch 7: val_mean_io_u improved from 0.66911 to 0.68667, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 439s 9s/step - loss: 0.9511 - mean_io_u: 0.6782 - dice_coeficient: 0.6598 - val_loss: 0.9478 - val_mean_io_u: 0.6867 - val_dice_coeficient: 0.7071
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9453 - mean_io_u: 0.7357 - dice_coeficient: 0.7683
# Epoch 8: val_mean_io_u improved from 0.68667 to 0.74426, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 440s 9s/step - loss: 0.9453 - mean_io_u: 0.7357 - dice_coeficient: 0.7683 - val_loss: 0.9449 - val_mean_io_u: 0.7443 - val_dice_coeficient: 0.7933
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9436 - mean_io_u: 0.7677 - dice_coeficient: 0.8057
# Epoch 9: val_mean_io_u improved from 0.74426 to 0.76634, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 412s 8s/step - loss: 0.9436 - mean_io_u: 0.7677 - dice_coeficient: 0.8057 - val_loss: 0.9431 - val_mean_io_u: 0.7663 - val_dice_coeficient: 0.8136
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9431 - mean_io_u: 0.7774 - dice_coeficient: 0.8123
# Epoch 10: val_mean_io_u did not improve from 0.76634
# 51/51 [==============================] - 442s 9s/step - loss: 0.9431 - mean_io_u: 0.7774 - dice_coeficient: 0.8123 - val_loss: 0.9431 - val_mean_io_u: 0.7639 - val_dice_coeficient: 0.8132
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9425 - mean_io_u: 0.7648 - dice_coeficient: 0.8096
# Epoch 11: val_mean_io_u did not improve from 0.76634
# 51/51 [==============================] - 436s 9s/step - loss: 0.9425 - mean_io_u: 0.7648 - dice_coeficient: 0.8096 - val_loss: 0.9408 - val_mean_io_u: 0.7177 - val_dice_coeficient: 0.7971
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9404 - mean_io_u: 0.7639 - dice_coeficient: 0.8026
# Epoch 12: val_mean_io_u did not improve from 0.76634
# 51/51 [==============================] - 436s 9s/step - loss: 0.9404 - mean_io_u: 0.7639 - dice_coeficient: 0.8026 - val_loss: 0.9397 - val_mean_io_u: 0.7641 - val_dice_coeficient: 0.8043
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9396 - mean_io_u: 0.7851 - dice_coeficient: 0.8103
# Epoch 13: val_mean_io_u improved from 0.76634 to 0.77989, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 437s 9s/step - loss: 0.9396 - mean_io_u: 0.7851 - dice_coeficient: 0.8103 - val_loss: 0.9392 - val_mean_io_u: 0.7799 - val_dice_coeficient: 0.8110
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9392 - mean_io_u: 0.7942 - dice_coeficient: 0.8148
# Epoch 14: val_mean_io_u did not improve from 0.77989
# 51/51 [==============================] - 437s 9s/step - loss: 0.9392 - mean_io_u: 0.7942 - dice_coeficient: 0.8148 - val_loss: 0.9391 - val_mean_io_u: 0.7773 - val_dice_coeficient: 0.8099
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9389 - mean_io_u: 0.7985 - dice_coeficient: 0.8178
# Epoch 15: val_mean_io_u improved from 0.77989 to 0.78940, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 435s 9s/step - loss: 0.9389 - mean_io_u: 0.7985 - dice_coeficient: 0.8178 - val_loss: 0.9385 - val_mean_io_u: 0.7894 - val_dice_coeficient: 0.8188
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9387 - mean_io_u: 0.8023 - dice_coeficient: 0.8204
# Epoch 16: val_mean_io_u improved from 0.78940 to 0.79259, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 441s 9s/step - loss: 0.9387 - mean_io_u: 0.8023 - dice_coeficient: 0.8204 - val_loss: 0.9383 - val_mean_io_u: 0.7926 - val_dice_coeficient: 0.8211
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9385 - mean_io_u: 0.8058 - dice_coeficient: 0.8228
# Epoch 17: val_mean_io_u improved from 0.79259 to 0.79327, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 437s 9s/step - loss: 0.9385 - mean_io_u: 0.8058 - dice_coeficient: 0.8228 - val_loss: 0.9383 - val_mean_io_u: 0.7933 - val_dice_coeficient: 0.8204
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9383 - mean_io_u: 0.8085 - dice_coeficient: 0.8244
# Epoch 18: val_mean_io_u improved from 0.79327 to 0.79775, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 439s 9s/step - loss: 0.9383 - mean_io_u: 0.8085 - dice_coeficient: 0.8244 - val_loss: 0.9381 - val_mean_io_u: 0.7978 - val_dice_coeficient: 0.8234
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9382 - mean_io_u: 0.8105 - dice_coeficient: 0.8258
# Epoch 19: val_mean_io_u did not improve from 0.79775
# 51/51 [==============================] - 436s 9s/step - loss: 0.9382 - mean_io_u: 0.8105 - dice_coeficient: 0.8258 - val_loss: 0.9380 - val_mean_io_u: 0.7963 - val_dice_coeficient: 0.8227
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9381 - mean_io_u: 0.8125 - dice_coeficient: 0.8273
# Epoch 20: val_mean_io_u improved from 0.79775 to 0.80292, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 435s 9s/step - loss: 0.9381 - mean_io_u: 0.8125 - dice_coeficient: 0.8273 - val_loss: 0.9378 - val_mean_io_u: 0.8029 - val_dice_coeficient: 0.8279
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9380 - mean_io_u: 0.8139 - dice_coeficient: 0.8288
# Epoch 21: val_mean_io_u improved from 0.80292 to 0.80563, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 430s 8s/step - loss: 0.9380 - mean_io_u: 0.8139 - dice_coeficient: 0.8288 - val_loss: 0.9378 - val_mean_io_u: 0.8056 - val_dice_coeficient: 0.8289
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9379 - mean_io_u: 0.8152 - dice_coeficient: 0.8301
# Epoch 22: val_mean_io_u improved from 0.80563 to 0.81069, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 392s 8s/step - loss: 0.9379 - mean_io_u: 0.8152 - dice_coeficient: 0.8301 - val_loss: 0.9377 - val_mean_io_u: 0.8107 - val_dice_coeficient: 0.8314
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9378 - mean_io_u: 0.8172 - dice_coeficient: 0.8312
# Epoch 23: val_mean_io_u did not improve from 0.81069
# 51/51 [==============================] - 415s 8s/step - loss: 0.9378 - mean_io_u: 0.8172 - dice_coeficient: 0.8312 - val_loss: 0.9376 - val_mean_io_u: 0.8094 - val_dice_coeficient: 0.8309
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9377 - mean_io_u: 0.8177 - dice_coeficient: 0.8320
# Epoch 24: val_mean_io_u improved from 0.81069 to 0.81495, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 436s 9s/step - loss: 0.9377 - mean_io_u: 0.8177 - dice_coeficient: 0.8320 - val_loss: 0.9374 - val_mean_io_u: 0.8149 - val_dice_coeficient: 0.8353
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9376 - mean_io_u: 0.8195 - dice_coeficient: 0.8329
# Epoch 25: val_mean_io_u did not improve from 0.81495
# 51/51 [==============================] - 435s 9s/step - loss: 0.9376 - mean_io_u: 0.8195 - dice_coeficient: 0.8329 - val_loss: 0.9375 - val_mean_io_u: 0.8099 - val_dice_coeficient: 0.8320
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9376 - mean_io_u: 0.8198 - dice_coeficient: 0.8338
# Epoch 26: val_mean_io_u did not improve from 0.81495
# 51/51 [==============================] - 434s 9s/step - loss: 0.9376 - mean_io_u: 0.8198 - dice_coeficient: 0.8338 - val_loss: 0.9373 - val_mean_io_u: 0.8148 - val_dice_coeficient: 0.8347
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9375 - mean_io_u: 0.8208 - dice_coeficient: 0.8346
# Epoch 27: val_mean_io_u improved from 0.81495 to 0.81509, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 436s 9s/step - loss: 0.9375 - mean_io_u: 0.8208 - dice_coeficient: 0.8346 - val_loss: 0.9373 - val_mean_io_u: 0.8151 - val_dice_coeficient: 0.8349
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9375 - mean_io_u: 0.8215 - dice_coeficient: 0.8352
# Epoch 28: val_mean_io_u improved from 0.81509 to 0.81747, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 437s 9s/step - loss: 0.9375 - mean_io_u: 0.8215 - dice_coeficient: 0.8352 - val_loss: 0.9372 - val_mean_io_u: 0.8175 - val_dice_coeficient: 0.8368
# Epoch 29/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9374 - mean_io_u: 0.8219 - dice_coeficient: 0.8357
# Epoch 29: val_mean_io_u did not improve from 0.81747
# 51/51 [==============================] - 433s 8s/step - loss: 0.9374 - mean_io_u: 0.8219 - dice_coeficient: 0.8357 - val_loss: 0.9372 - val_mean_io_u: 0.8173 - val_dice_coeficient: 0.8366
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9374 - mean_io_u: 0.8227 - dice_coeficient: 0.8362
# Epoch 30: val_mean_io_u did not improve from 0.81747
# 51/51 [==============================] - 435s 9s/step - loss: 0.9374 - mean_io_u: 0.8227 - dice_coeficient: 0.8362 - val_loss: 0.9372 - val_mean_io_u: 0.8136 - val_dice_coeficient: 0.8347
# Epoch 31/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9373 - mean_io_u: 0.8227 - dice_coeficient: 0.8368
# Epoch 31: val_mean_io_u improved from 0.81747 to 0.82025, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 437s 9s/step - loss: 0.9373 - mean_io_u: 0.8227 - dice_coeficient: 0.8368 - val_loss: 0.9371 - val_mean_io_u: 0.8202 - val_dice_coeficient: 0.8391
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9373 - mean_io_u: 0.8235 - dice_coeficient: 0.8371
# Epoch 32: val_mean_io_u improved from 0.82025 to 0.82165, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 439s 9s/step - loss: 0.9373 - mean_io_u: 0.8235 - dice_coeficient: 0.8371 - val_loss: 0.9371 - val_mean_io_u: 0.8217 - val_dice_coeficient: 0.8391
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9372 - mean_io_u: 0.8235 - dice_coeficient: 0.8379
# Epoch 33: val_mean_io_u did not improve from 0.82165
# 51/51 [==============================] - 434s 9s/step - loss: 0.9372 - mean_io_u: 0.8235 - dice_coeficient: 0.8379 - val_loss: 0.9371 - val_mean_io_u: 0.8172 - val_dice_coeficient: 0.8378
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9372 - mean_io_u: 0.8240 - dice_coeficient: 0.8382
# Epoch 34: val_mean_io_u did not improve from 0.82165
# 51/51 [==============================] - 437s 9s/step - loss: 0.9372 - mean_io_u: 0.8240 - dice_coeficient: 0.8382 - val_loss: 0.9370 - val_mean_io_u: 0.8215 - val_dice_coeficient: 0.8405
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9372 - mean_io_u: 0.8245 - dice_coeficient: 0.8385
# Epoch 35: val_mean_io_u improved from 0.82165 to 0.82167, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 435s 9s/step - loss: 0.9372 - mean_io_u: 0.8245 - dice_coeficient: 0.8385 - val_loss: 0.9370 - val_mean_io_u: 0.8217 - val_dice_coeficient: 0.8402
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9371 - mean_io_u: 0.8246 - dice_coeficient: 0.8389
# Epoch 36: val_mean_io_u did not improve from 0.82167
# 51/51 [==============================] - 436s 9s/step - loss: 0.9371 - mean_io_u: 0.8246 - dice_coeficient: 0.8389 - val_loss: 0.9370 - val_mean_io_u: 0.8189 - val_dice_coeficient: 0.8393
# Epoch 37/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9371 - mean_io_u: 0.8244 - dice_coeficient: 0.8392
# Epoch 37: val_mean_io_u did not improve from 0.82167
# 51/51 [==============================] - 437s 9s/step - loss: 0.9371 - mean_io_u: 0.8244 - dice_coeficient: 0.8392 - val_loss: 0.9369 - val_mean_io_u: 0.8196 - val_dice_coeficient: 0.8402
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9371 - mean_io_u: 0.8246 - dice_coeficient: 0.8396
# Epoch 38: val_mean_io_u improved from 0.82167 to 0.82237, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 437s 9s/step - loss: 0.9371 - mean_io_u: 0.8246 - dice_coeficient: 0.8396 - val_loss: 0.9369 - val_mean_io_u: 0.8224 - val_dice_coeficient: 0.8417
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9370 - mean_io_u: 0.8247 - dice_coeficient: 0.8400
# Epoch 39: val_mean_io_u did not improve from 0.82237
# 51/51 [==============================] - 440s 9s/step - loss: 0.9370 - mean_io_u: 0.8247 - dice_coeficient: 0.8400 - val_loss: 0.9369 - val_mean_io_u: 0.8212 - val_dice_coeficient: 0.8416
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9370 - mean_io_u: 0.8252 - dice_coeficient: 0.8403
# Epoch 40: val_mean_io_u did not improve from 0.82237
# 51/51 [==============================] - 435s 9s/step - loss: 0.9370 - mean_io_u: 0.8252 - dice_coeficient: 0.8403 - val_loss: 0.9369 - val_mean_io_u: 0.8200 - val_dice_coeficient: 0.8403
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9370 - mean_io_u: 0.8253 - dice_coeficient: 0.8405
# Epoch 41: val_mean_io_u did not improve from 0.82237
# 51/51 [==============================] - 444s 9s/step - loss: 0.9370 - mean_io_u: 0.8253 - dice_coeficient: 0.8405 - val_loss: 0.9368 - val_mean_io_u: 0.8217 - val_dice_coeficient: 0.8417
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9370 - mean_io_u: 0.8257 - dice_coeficient: 0.8409
# Epoch 42: val_mean_io_u did not improve from 0.82237
# 51/51 [==============================] - 436s 9s/step - loss: 0.9370 - mean_io_u: 0.8257 - dice_coeficient: 0.8409 - val_loss: 0.9368 - val_mean_io_u: 0.8222 - val_dice_coeficient: 0.8417
# Epoch 43/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9369 - mean_io_u: 0.8262 - dice_coeficient: 0.8413
# Epoch 43: val_mean_io_u did not improve from 0.82237
# 51/51 [==============================] - 440s 9s/step - loss: 0.9369 - mean_io_u: 0.8262 - dice_coeficient: 0.8413 - val_loss: 0.9368 - val_mean_io_u: 0.8205 - val_dice_coeficient: 0.8416
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9369 - mean_io_u: 0.8264 - dice_coeficient: 0.8415
# Epoch 44: val_mean_io_u improved from 0.82237 to 0.82339, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 438s 9s/step - loss: 0.9369 - mean_io_u: 0.8264 - dice_coeficient: 0.8415 - val_loss: 0.9367 - val_mean_io_u: 0.8234 - val_dice_coeficient: 0.8426
# Epoch 45/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9369 - mean_io_u: 0.8267 - dice_coeficient: 0.8415
# Epoch 45: val_mean_io_u improved from 0.82339 to 0.82549, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 434s 9s/step - loss: 0.9369 - mean_io_u: 0.8267 - dice_coeficient: 0.8415 - val_loss: 0.9367 - val_mean_io_u: 0.8255 - val_dice_coeficient: 0.8438
# Epoch 46/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9369 - mean_io_u: 0.8274 - dice_coeficient: 0.8418
# Epoch 46: val_mean_io_u did not improve from 0.82549
# 51/51 [==============================] - 435s 9s/step - loss: 0.9369 - mean_io_u: 0.8274 - dice_coeficient: 0.8418 - val_loss: 0.9367 - val_mean_io_u: 0.8238 - val_dice_coeficient: 0.8433
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9369 - mean_io_u: 0.8276 - dice_coeficient: 0.8418
# Epoch 47: val_mean_io_u did not improve from 0.82549
# 51/51 [==============================] - 437s 9s/step - loss: 0.9369 - mean_io_u: 0.8276 - dice_coeficient: 0.8418 - val_loss: 0.9367 - val_mean_io_u: 0.8237 - val_dice_coeficient: 0.8430
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9368 - mean_io_u: 0.8286 - dice_coeficient: 0.8422
# Epoch 48: val_mean_io_u did not improve from 0.82549
# 51/51 [==============================] - 436s 9s/step - loss: 0.9368 - mean_io_u: 0.8286 - dice_coeficient: 0.8422 - val_loss: 0.9366 - val_mean_io_u: 0.8252 - val_dice_coeficient: 0.8437
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9368 - mean_io_u: 0.8289 - dice_coeficient: 0.8423
# Epoch 49: val_mean_io_u did not improve from 0.82549
# 51/51 [==============================] - 443s 9s/step - loss: 0.9368 - mean_io_u: 0.8289 - dice_coeficient: 0.8423 - val_loss: 0.9367 - val_mean_io_u: 0.8245 - val_dice_coeficient: 0.8434
# Epoch 50/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9368 - mean_io_u: 0.8290 - dice_coeficient: 0.8427
# Epoch 50: val_mean_io_u improved from 0.82549 to 0.82553, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 437s 9s/step - loss: 0.9368 - mean_io_u: 0.8290 - dice_coeficient: 0.8427 - val_loss: 0.9367 - val_mean_io_u: 0.8255 - val_dice_coeficient: 0.8432
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9368 - mean_io_u: 0.8297 - dice_coeficient: 0.8429
# Epoch 51: val_mean_io_u improved from 0.82553 to 0.82794, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 435s 9s/step - loss: 0.9368 - mean_io_u: 0.8297 - dice_coeficient: 0.8429 - val_loss: 0.9367 - val_mean_io_u: 0.8279 - val_dice_coeficient: 0.8435
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9368 - mean_io_u: 0.8302 - dice_coeficient: 0.8429
# Epoch 52: val_mean_io_u did not improve from 0.82794
# 51/51 [==============================] - 441s 9s/step - loss: 0.9368 - mean_io_u: 0.8302 - dice_coeficient: 0.8429 - val_loss: 0.9367 - val_mean_io_u: 0.8247 - val_dice_coeficient: 0.8427
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9368 - mean_io_u: 0.8303 - dice_coeficient: 0.8432
# Epoch 53: val_mean_io_u did not improve from 0.82794
# 51/51 [==============================] - 436s 9s/step - loss: 0.9368 - mean_io_u: 0.8303 - dice_coeficient: 0.8432 - val_loss: 0.9366 - val_mean_io_u: 0.8251 - val_dice_coeficient: 0.8434
# Epoch 54/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9367 - mean_io_u: 0.8308 - dice_coeficient: 0.8435
# Epoch 54: val_mean_io_u improved from 0.82794 to 0.83001, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 438s 9s/step - loss: 0.9367 - mean_io_u: 0.8308 - dice_coeficient: 0.8435 - val_loss: 0.9366 - val_mean_io_u: 0.8300 - val_dice_coeficient: 0.8447
# Epoch 55/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9367 - mean_io_u: 0.8315 - dice_coeficient: 0.8435
# Epoch 55: val_mean_io_u did not improve from 0.83001
# 51/51 [==============================] - 440s 9s/step - loss: 0.9367 - mean_io_u: 0.8315 - dice_coeficient: 0.8435 - val_loss: 0.9366 - val_mean_io_u: 0.8293 - val_dice_coeficient: 0.8445
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9367 - mean_io_u: 0.8319 - dice_coeficient: 0.8439
# Epoch 56: val_mean_io_u did not improve from 0.83001
# 51/51 [==============================] - 437s 9s/step - loss: 0.9367 - mean_io_u: 0.8319 - dice_coeficient: 0.8439 - val_loss: 0.9366 - val_mean_io_u: 0.8290 - val_dice_coeficient: 0.8444
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9367 - mean_io_u: 0.8316 - dice_coeficient: 0.8439
# Epoch 57: val_mean_io_u did not improve from 0.83001
# 51/51 [==============================] - 440s 9s/step - loss: 0.9367 - mean_io_u: 0.8316 - dice_coeficient: 0.8439 - val_loss: 0.9366 - val_mean_io_u: 0.8280 - val_dice_coeficient: 0.8441
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9367 - mean_io_u: 0.8320 - dice_coeficient: 0.8441
# Epoch 58: val_mean_io_u improved from 0.83001 to 0.83019, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 437s 9s/step - loss: 0.9367 - mean_io_u: 0.8320 - dice_coeficient: 0.8441 - val_loss: 0.9365 - val_mean_io_u: 0.8302 - val_dice_coeficient: 0.8449
# Epoch 59/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9367 - mean_io_u: 0.8321 - dice_coeficient: 0.8442
# Epoch 59: val_mean_io_u improved from 0.83019 to 0.83149, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 435s 9s/step - loss: 0.9367 - mean_io_u: 0.8321 - dice_coeficient: 0.8442 - val_loss: 0.9365 - val_mean_io_u: 0.8315 - val_dice_coeficient: 0.8457
# Epoch 60/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9366 - mean_io_u: 0.8324 - dice_coeficient: 0.8445
# Epoch 60: val_mean_io_u did not improve from 0.83149
# 51/51 [==============================] - 440s 9s/step - loss: 0.9366 - mean_io_u: 0.8324 - dice_coeficient: 0.8445 - val_loss: 0.9365 - val_mean_io_u: 0.8294 - val_dice_coeficient: 0.8447
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9366 - mean_io_u: 0.8325 - dice_coeficient: 0.8442
# Epoch 61: val_mean_io_u did not improve from 0.83149
# 51/51 [==============================] - 444s 9s/step - loss: 0.9366 - mean_io_u: 0.8325 - dice_coeficient: 0.8442 - val_loss: 0.9365 - val_mean_io_u: 0.8308 - val_dice_coeficient: 0.8447
# Epoch 62/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9366 - mean_io_u: 0.8327 - dice_coeficient: 0.8445
# Epoch 62: val_mean_io_u did not improve from 0.83149
# 51/51 [==============================] - 443s 9s/step - loss: 0.9366 - mean_io_u: 0.8327 - dice_coeficient: 0.8445 - val_loss: 0.9365 - val_mean_io_u: 0.8286 - val_dice_coeficient: 0.8443
# Epoch 63/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9366 - mean_io_u: 0.8324 - dice_coeficient: 0.8445
# Epoch 63: val_mean_io_u did not improve from 0.83149
# 51/51 [==============================] - 435s 9s/step - loss: 0.9366 - mean_io_u: 0.8324 - dice_coeficient: 0.8445 - val_loss: 0.9365 - val_mean_io_u: 0.8277 - val_dice_coeficient: 0.8443
# Epoch 64/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9366 - mean_io_u: 0.8327 - dice_coeficient: 0.8447
# Epoch 64: val_mean_io_u improved from 0.83149 to 0.83439, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 437s 9s/step - loss: 0.9366 - mean_io_u: 0.8327 - dice_coeficient: 0.8447 - val_loss: 0.9365 - val_mean_io_u: 0.8344 - val_dice_coeficient: 0.8469
# Epoch 65/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9366 - mean_io_u: 0.8326 - dice_coeficient: 0.8449
# Epoch 65: val_mean_io_u did not improve from 0.83439
# 51/51 [==============================] - 439s 9s/step - loss: 0.9366 - mean_io_u: 0.8326 - dice_coeficient: 0.8449 - val_loss: 0.9365 - val_mean_io_u: 0.8283 - val_dice_coeficient: 0.8448
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9365 - mean_io_u: 0.8318 - dice_coeficient: 0.8450
# Epoch 66: val_mean_io_u did not improve from 0.83439
# 51/51 [==============================] - 435s 9s/step - loss: 0.9365 - mean_io_u: 0.8318 - dice_coeficient: 0.8450 - val_loss: 0.9363 - val_mean_io_u: 0.8302 - val_dice_coeficient: 0.8457
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9358 - mean_io_u: 0.8446 - dice_coeficient: 0.8520
# Epoch 67: val_mean_io_u improved from 0.83439 to 0.84908, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 437s 9s/step - loss: 0.9358 - mean_io_u: 0.8446 - dice_coeficient: 0.8520 - val_loss: 0.9352 - val_mean_io_u: 0.8491 - val_dice_coeficient: 0.8590
# Epoch 68/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9352 - mean_io_u: 0.8492 - dice_coeficient: 0.8597
# Epoch 68: val_mean_io_u did not improve from 0.84908
# 51/51 [==============================] - 436s 9s/step - loss: 0.9352 - mean_io_u: 0.8492 - dice_coeficient: 0.8597 - val_loss: 0.9350 - val_mean_io_u: 0.8471 - val_dice_coeficient: 0.8606
# Epoch 69/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9351 - mean_io_u: 0.8491 - dice_coeficient: 0.8611
# Epoch 69: val_mean_io_u did not improve from 0.84908
# 51/51 [==============================] - 433s 9s/step - loss: 0.9351 - mean_io_u: 0.8491 - dice_coeficient: 0.8611 - val_loss: 0.9349 - val_mean_io_u: 0.8459 - val_dice_coeficient: 0.8610
# Epoch 70/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9350 - mean_io_u: 0.8490 - dice_coeficient: 0.8622
# Epoch 70: val_mean_io_u did not improve from 0.84908
# 51/51 [==============================] - 436s 9s/step - loss: 0.9350 - mean_io_u: 0.8490 - dice_coeficient: 0.8622 - val_loss: 0.9348 - val_mean_io_u: 0.8478 - val_dice_coeficient: 0.8627
# Epoch 71/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9349 - mean_io_u: 0.8489 - dice_coeficient: 0.8629
# Epoch 71: val_mean_io_u did not improve from 0.84908
# 51/51 [==============================] - 437s 9s/step - loss: 0.9349 - mean_io_u: 0.8489 - dice_coeficient: 0.8629 - val_loss: 0.9348 - val_mean_io_u: 0.8479 - val_dice_coeficient: 0.8629
# Epoch 72/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9349 - mean_io_u: 0.8492 - dice_coeficient: 0.8630
# Epoch 72: val_mean_io_u did not improve from 0.84908
# 51/51 [==============================] - 437s 9s/step - loss: 0.9349 - mean_io_u: 0.8492 - dice_coeficient: 0.8630 - val_loss: 0.9347 - val_mean_io_u: 0.8484 - val_dice_coeficient: 0.8635
# Epoch 73/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9349 - mean_io_u: 0.8495 - dice_coeficient: 0.8637
# Epoch 73: val_mean_io_u did not improve from 0.84908
# 51/51 [==============================] - 434s 9s/step - loss: 0.9349 - mean_io_u: 0.8495 - dice_coeficient: 0.8637 - val_loss: 0.9347 - val_mean_io_u: 0.8486 - val_dice_coeficient: 0.8640
# Epoch 74/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9348 - mean_io_u: 0.8498 - dice_coeficient: 0.8640
# Epoch 74: val_mean_io_u did not improve from 0.84908
# 51/51 [==============================] - 435s 9s/step - loss: 0.9348 - mean_io_u: 0.8498 - dice_coeficient: 0.8640 - val_loss: 0.9347 - val_mean_io_u: 0.8477 - val_dice_coeficient: 0.8634
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9348 - mean_io_u: 0.8502 - dice_coeficient: 0.8644
# Epoch 75: val_mean_io_u improved from 0.84908 to 0.84977, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.9348 - mean_io_u: 0.8502 - dice_coeficient: 0.8644 - val_loss: 0.9347 - val_mean_io_u: 0.8498 - val_dice_coeficient: 0.8646
# Epoch 76/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9348 - mean_io_u: 0.8506 - dice_coeficient: 0.8645
# Epoch 76: val_mean_io_u did not improve from 0.84977
# 51/51 [==============================] - 438s 9s/step - loss: 0.9348 - mean_io_u: 0.8506 - dice_coeficient: 0.8645 - val_loss: 0.9347 - val_mean_io_u: 0.8488 - val_dice_coeficient: 0.8644
# Epoch 77/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9348 - mean_io_u: 0.8510 - dice_coeficient: 0.8649
# Epoch 77: val_mean_io_u did not improve from 0.84977
# 51/51 [==============================] - 433s 9s/step - loss: 0.9348 - mean_io_u: 0.8510 - dice_coeficient: 0.8649 - val_loss: 0.9347 - val_mean_io_u: 0.8465 - val_dice_coeficient: 0.8631
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9347 - mean_io_u: 0.8508 - dice_coeficient: 0.8652
# Epoch 78: val_mean_io_u did not improve from 0.84977
# 51/51 [==============================] - 436s 9s/step - loss: 0.9347 - mean_io_u: 0.8508 - dice_coeficient: 0.8652 - val_loss: 0.9346 - val_mean_io_u: 0.8490 - val_dice_coeficient: 0.8646
# Epoch 79/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9347 - mean_io_u: 0.8515 - dice_coeficient: 0.8654
# Epoch 79: val_mean_io_u did not improve from 0.84977
# 51/51 [==============================] - 434s 9s/step - loss: 0.9347 - mean_io_u: 0.8515 - dice_coeficient: 0.8654 - val_loss: 0.9346 - val_mean_io_u: 0.8498 - val_dice_coeficient: 0.8654
# Epoch 80/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9347 - mean_io_u: 0.8519 - dice_coeficient: 0.8659
# Epoch 80: val_mean_io_u improved from 0.84977 to 0.85038, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 434s 9s/step - loss: 0.9347 - mean_io_u: 0.8519 - dice_coeficient: 0.8659 - val_loss: 0.9346 - val_mean_io_u: 0.8504 - val_dice_coeficient: 0.8652
# Epoch 81/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9347 - mean_io_u: 0.8520 - dice_coeficient: 0.8659
# Epoch 81: val_mean_io_u improved from 0.85038 to 0.85107, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 434s 9s/step - loss: 0.9347 - mean_io_u: 0.8520 - dice_coeficient: 0.8659 - val_loss: 0.9346 - val_mean_io_u: 0.8511 - val_dice_coeficient: 0.8660
# Epoch 82/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9347 - mean_io_u: 0.8521 - dice_coeficient: 0.8662
# Epoch 82: val_mean_io_u improved from 0.85107 to 0.85139, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 435s 9s/step - loss: 0.9347 - mean_io_u: 0.8521 - dice_coeficient: 0.8662 - val_loss: 0.9346 - val_mean_io_u: 0.8514 - val_dice_coeficient: 0.8661
# Epoch 83/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9347 - mean_io_u: 0.8525 - dice_coeficient: 0.8663
# Epoch 83: val_mean_io_u improved from 0.85139 to 0.85148, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 436s 9s/step - loss: 0.9347 - mean_io_u: 0.8525 - dice_coeficient: 0.8663 - val_loss: 0.9345 - val_mean_io_u: 0.8515 - val_dice_coeficient: 0.8663
# Epoch 84/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9346 - mean_io_u: 0.8528 - dice_coeficient: 0.8665
# Epoch 84: val_mean_io_u improved from 0.85148 to 0.85226, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 446s 9s/step - loss: 0.9346 - mean_io_u: 0.8528 - dice_coeficient: 0.8665 - val_loss: 0.9345 - val_mean_io_u: 0.8523 - val_dice_coeficient: 0.8664
# Epoch 85/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9346 - mean_io_u: 0.8533 - dice_coeficient: 0.8667
# Epoch 85: val_mean_io_u improved from 0.85226 to 0.85302, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 437s 9s/step - loss: 0.9346 - mean_io_u: 0.8533 - dice_coeficient: 0.8667 - val_loss: 0.9345 - val_mean_io_u: 0.8530 - val_dice_coeficient: 0.8669
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9346 - mean_io_u: 0.8535 - dice_coeficient: 0.8668
# Epoch 86: val_mean_io_u did not improve from 0.85302
# 51/51 [==============================] - 435s 9s/step - loss: 0.9346 - mean_io_u: 0.8535 - dice_coeficient: 0.8668 - val_loss: 0.9345 - val_mean_io_u: 0.8507 - val_dice_coeficient: 0.8662
# Epoch 87/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9346 - mean_io_u: 0.8539 - dice_coeficient: 0.8671
# Epoch 87: val_mean_io_u did not improve from 0.85302
# 51/51 [==============================] - 434s 9s/step - loss: 0.9346 - mean_io_u: 0.8539 - dice_coeficient: 0.8671 - val_loss: 0.9345 - val_mean_io_u: 0.8524 - val_dice_coeficient: 0.8662
# Epoch 88/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9346 - mean_io_u: 0.8540 - dice_coeficient: 0.8671
# Epoch 88: val_mean_io_u improved from 0.85302 to 0.85370, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 435s 9s/step - loss: 0.9346 - mean_io_u: 0.8540 - dice_coeficient: 0.8671 - val_loss: 0.9345 - val_mean_io_u: 0.8537 - val_dice_coeficient: 0.8672
# Epoch 89/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9346 - mean_io_u: 0.8543 - dice_coeficient: 0.8674
# Epoch 89: val_mean_io_u improved from 0.85370 to 0.85430, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 433s 8s/step - loss: 0.9346 - mean_io_u: 0.8543 - dice_coeficient: 0.8674 - val_loss: 0.9345 - val_mean_io_u: 0.8543 - val_dice_coeficient: 0.8677
# Epoch 90/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9346 - mean_io_u: 0.8545 - dice_coeficient: 0.8675
# Epoch 90: val_mean_io_u improved from 0.85430 to 0.85465, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 438s 9s/step - loss: 0.9346 - mean_io_u: 0.8545 - dice_coeficient: 0.8675 - val_loss: 0.9345 - val_mean_io_u: 0.8547 - val_dice_coeficient: 0.8674
# Epoch 91/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9345 - mean_io_u: 0.8549 - dice_coeficient: 0.8677
# Epoch 91: val_mean_io_u did not improve from 0.85465
# 51/51 [==============================] - 434s 9s/step - loss: 0.9345 - mean_io_u: 0.8549 - dice_coeficient: 0.8677 - val_loss: 0.9345 - val_mean_io_u: 0.8531 - val_dice_coeficient: 0.8669
# Epoch 92/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9345 - mean_io_u: 0.8549 - dice_coeficient: 0.8681
# Epoch 92: val_mean_io_u improved from 0.85465 to 0.85514, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 436s 9s/step - loss: 0.9345 - mean_io_u: 0.8549 - dice_coeficient: 0.8681 - val_loss: 0.9344 - val_mean_io_u: 0.8551 - val_dice_coeficient: 0.8679
# Epoch 93/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9345 - mean_io_u: 0.8553 - dice_coeficient: 0.8680
# Epoch 93: val_mean_io_u did not improve from 0.85514
# 51/51 [==============================] - 432s 8s/step - loss: 0.9345 - mean_io_u: 0.8553 - dice_coeficient: 0.8680 - val_loss: 0.9344 - val_mean_io_u: 0.8519 - val_dice_coeficient: 0.8669
# Epoch 94/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9345 - mean_io_u: 0.8553 - dice_coeficient: 0.8681
# Epoch 94: val_mean_io_u did not improve from 0.85514
# 51/51 [==============================] - 436s 9s/step - loss: 0.9345 - mean_io_u: 0.8553 - dice_coeficient: 0.8681 - val_loss: 0.9344 - val_mean_io_u: 0.8542 - val_dice_coeficient: 0.8675
# Epoch 95/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9345 - mean_io_u: 0.8556 - dice_coeficient: 0.8682
# Epoch 95: val_mean_io_u did not improve from 0.85514
# 51/51 [==============================] - 435s 9s/step - loss: 0.9345 - mean_io_u: 0.8556 - dice_coeficient: 0.8682 - val_loss: 0.9344 - val_mean_io_u: 0.8540 - val_dice_coeficient: 0.8676
# Epoch 96/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9345 - mean_io_u: 0.8558 - dice_coeficient: 0.8683
# Epoch 96: val_mean_io_u did not improve from 0.85514
# 51/51 [==============================] - 439s 9s/step - loss: 0.9345 - mean_io_u: 0.8558 - dice_coeficient: 0.8683 - val_loss: 0.9344 - val_mean_io_u: 0.8546 - val_dice_coeficient: 0.8678
# Epoch 97/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9345 - mean_io_u: 0.8559 - dice_coeficient: 0.8686
# Epoch 97: val_mean_io_u did not improve from 0.85514
# 51/51 [==============================] - 436s 9s/step - loss: 0.9345 - mean_io_u: 0.8559 - dice_coeficient: 0.8686 - val_loss: 0.9344 - val_mean_io_u: 0.8547 - val_dice_coeficient: 0.8679
# Epoch 98/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9345 - mean_io_u: 0.8566 - dice_coeficient: 0.8681
# Epoch 98: val_mean_io_u improved from 0.85514 to 0.85573, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 436s 9s/step - loss: 0.9345 - mean_io_u: 0.8566 - dice_coeficient: 0.8681 - val_loss: 0.9344 - val_mean_io_u: 0.8557 - val_dice_coeficient: 0.8680
# Epoch 99/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9345 - mean_io_u: 0.8563 - dice_coeficient: 0.8684
# Epoch 99: val_mean_io_u did not improve from 0.85573
# 51/51 [==============================] - 436s 9s/step - loss: 0.9345 - mean_io_u: 0.8563 - dice_coeficient: 0.8684 - val_loss: 0.9344 - val_mean_io_u: 0.8542 - val_dice_coeficient: 0.8677
# Epoch 100/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9345 - mean_io_u: 0.8569 - dice_coeficient: 0.8687
# Epoch 100: val_mean_io_u did not improve from 0.85573
# 51/51 [==============================] - 436s 9s/step - loss: 0.9345 - mean_io_u: 0.8569 - dice_coeficient: 0.8687 - val_loss: 0.9344 - val_mean_io_u: 0.8551 - val_dice_coeficient: 0.8677

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='lower right')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/u-net_100epochs.hdf5')

# %%
pred = unet_model.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 21s 409ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1), cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx], cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
# --
# **TFG - Adrián Contreras Castillo**
# --
