# %% [markdown]
# # Deep Learning: Laparoscopic segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import cv2
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
from glob import glob
import segmentation_models as sm
from keras_vision_transformer import swin_layers
from keras_vision_transformer import transformer_layers
from keras_vision_transformer import utils
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: False

# %%
SEED = 17
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)

# %%
# https://gist.github.com/IdeaKing/11cf5e146d23c5bb219ba3508cca89ec
def resize_with_pad(image: np.array, 
                    new_shape, 
                    padding_color = (0, 0, 0)) -> np.array:
    """Maintains aspect ratio and resizes with padding.
    Params:
        image: Image to be resized.
        new_shape: Expected (width, height) of new image.
        padding_color: Tuple in BGR of padding color
    Returns:
        image: Resized image with padding
    """
    original_shape = (image.shape[1], image.shape[0])
    ratio = float(max(new_shape))/max(original_shape)
    new_size = tuple([int(x*ratio) for x in original_shape])
    image = cv2.resize(image, new_size, interpolation=cv2.INTER_NEAREST)
    delta_w = new_shape[0] - new_size[0]
    delta_h = new_shape[1] - new_size[1]
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)
    image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT, value=padding_color)
    return image

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 120:-120,:]
    img = resize_with_pad(img, (HEIGHT, WIDTH))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 120:-120,:]
    mask = resize_with_pad(mask, (HEIGHT, WIDTH), (50, 50, 50))
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx], cmap='afmhot')
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1), cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 
import gc
del X
del y
gc.collect()
# Out:
# 7929

# %% [markdown]
# ## Swin-U-Net

# %% [markdown]
# ### Losses

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

def dice_loss(y_true, y_pred):
    return 1 - dice_coeficient(y_true, y_pred)

def tversky(y_true, y_pred, smooth=1e-6, alpha=0.75):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)
    TP = tf.keras.backend.sum(T * P)
    FN = tf.keras.backend.sum(T * (1 - P))
    FP = tf.keras.backend.sum((1 - T) * P)
    return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true, y_pred)


# def focal_tversky_loss(y_true, y_pred, gamma=0.75):
#     tv = tversky(y_true, y_pred)
#     return tf.keras.backend.pow((1 - tv), gamma)

# %% [markdown]
# ### Swin transformer stack

# %%
def swin_transformer_stack(X, stack_num, embed_dim, num_patch, num_heads, window_size, num_mlp, shift_window=True, name=''):
    '''
    Stacked Swin Transformers that share the same token size.
    
    Alternated Window-MSA and Swin-MSA will be configured if `shift_window=True`, Window-MSA only otherwise.
    *Dropout is turned off.
    '''
    # Turn-off dropouts
    mlp_drop_rate = 0 # Droupout after each MLP layer
    attn_drop_rate = 0 # Dropout after Swin-Attention
    proj_drop_rate = 0 # Dropout at the end of each Swin-Attention block, i.e., after linear projections
    drop_path_rate = 0 # Drop-path within skip-connections
    
    qkv_bias = True # Convert embedded patches to query, key, and values with a learnable additive value
    qk_scale = None # None: Re-scale query based on embed dimensions per attention head # Float for user specified scaling factor
    
    if shift_window:
        shift_size = window_size // 2
    else:
        shift_size = 0
    
    for i in range(stack_num):
    
        if i % 2 == 0:
            shift_size_temp = 0
        else:
            shift_size_temp = shift_size

        X = swin_layers.SwinTransformerBlock(dim=embed_dim, 
                                             num_patch=num_patch, 
                                             num_heads=num_heads, 
                                             window_size=window_size, 
                                             shift_size=shift_size_temp, 
                                             num_mlp=num_mlp, 
                                             qkv_bias=qkv_bias, 
                                             qk_scale=qk_scale,
                                             mlp_drop=mlp_drop_rate, 
                                             attn_drop=attn_drop_rate, 
                                             proj_drop=proj_drop_rate, 
                                             drop_path_prob=drop_path_rate, 
                                             name='name{}'.format(i))(X)
    return X


def swin_unet_2d_base(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet'):
    '''
    The base of Swin-UNET.
    
    The general structure:
    
    1. Input image --> a sequence of patches --> tokenize these patches
    2. Downsampling: swin-transformer --> patch merging (pooling)
    3. Upsampling: concatenate --> swin-transfprmer --> patch expanding (unpooling)
    4. Model head
    
    '''
    # Compute number be patches to be embeded
    input_size = input_tensor.shape.as_list()[1:]
    num_patch_x = input_size[0]//patch_size[0]
    num_patch_y = input_size[1]//patch_size[1]
    
    # Number of Embedded dimensions
    embed_dim = filter_num_begin
    
    depth_ = depth
    
    X_skip = []

    X = input_tensor
    
    # Patch extraction
    X = transformer_layers.patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = transformer_layers.patch_embedding(num_patch_x*num_patch_y, embed_dim)(X)
    
    # The first Swin Transformer stack
    X = swin_transformer_stack(X, 
                               stack_num=stack_num_down, 
                               embed_dim=embed_dim, 
                               num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], 
                               window_size=window_size[0], 
                               num_mlp=num_mlp, 
                               shift_window=shift_window, 
                               name='{}_swin_down0'.format(name))
    X_skip.append(X)
    
    # Downsampling blocks
    for i in range(depth_-1):
        
        # Patch merging
        X = transformer_layers.patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)
        
        # update token shape info
        embed_dim = embed_dim*2
        num_patch_x = num_patch_x//2
        num_patch_y = num_patch_y//2
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_down, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i+1], 
                                   window_size=window_size[i+1], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_down{}'.format(name, i+1))
        
        # Store tensors for concat
        X_skip.append(X)
        
    # reverse indexing encoded tensors and hyperparams
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]
    
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    
    depth_decode = len(X_decode)
    
    for i in range(depth_decode):
        
        # Patch expanding
        X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                               embed_dim=embed_dim, 
                                               upsample_rate=2, 
                                               return_vector=True)(X)
        

        # update token shape info
        embed_dim = embed_dim//2
        num_patch_x = num_patch_x*2
        num_patch_y = num_patch_y*2
        
        # Concatenation and linear projection
        X = tf.keras.layers.concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = tf.keras.layers.Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_up, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], 
                                   window_size=window_size[i], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_up{}'.format(name, i))
        
    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- "patch_size[0]" is used; it assumes patch_size = (size, size)
    
    X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                           embed_dim=embed_dim, 
                                           upsample_rate=patch_size[0], 
                                           return_vector=False)(X)
    
    return X

# %% [markdown]
# ### Hyperparameters

# %%
filter_num_begin = 128     # number of channels in the first downsampling block; it is also the number of embedded dimensions
depth = 4                  # the depth of SwinUNET; depth=4 means three down/upsampling levels and a bottom level 
stack_num_down = 2         # number of Swin Transformers per downsampling level
stack_num_up = 2           # number of Swin Transformers per upsampling level
patch_size = (4, 4)        # Extract 4-by-4 patches from the input image. Height and width of the patch must be equal.
num_heads = [4, 8, 8, 8]   # number of attention heads per down/upsampling level
window_size = [4, 2, 2, 2] # the size of attention window per down/upsampling level
num_mlp = 512              # number of MLP nodes within the Transformer
shift_window=True          # Apply window shifting, i.e., Swin-MSA

# %% [markdown]
# ### Model configuration

# %%
# Input section
IN = tf.keras.layers.Input((WIDTH, HEIGHT, 3))

# Base architecture
X = swin_unet_2d_base(IN, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, 
                      shift_window=shift_window, name='swin_unet')



# Output section
n_labels = 13
OUT = tf.keras.layers.Conv2D(n_labels, kernel_size=1, use_bias=False, activation='softmax')(X)

# Model configuration
swin_transformer = tf.keras.models.Model(inputs=[IN,], outputs=[OUT,])
# Optimization
# <---- !!! gradient clipping is important
swin_transformer.compile(
    optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=5e-4, clipvalue=0.5, decay=1e-6), 
    loss=tversky_loss,
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)
swin_transformer.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  patch_extract_1 (patch_extract  (None, 256, 48)     0           ['input_2[0][0]']
#  )
#
#  patch_embedding_1 (patch_embed  (None, 256, 128)    39040       ['patch_extract_1[0][0]']
#  ding)
#
#  swin_transformer_block_14 (Swi  (None, 256, 128)    198724      ['patch_embedding_1[0][0]']
#  nTransformerBlock)
#
#  swin_transformer_block_15 (Swi  (None, 256, 128)    202820      ['swin_transformer_block_14[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_merging_3 (patch_merging  (None, 64, 256)     131072      ['swin_transformer_block_15[0][0]
#  )                                                               ']
#
#  swin_transformer_block_16 (Swi  (None, 64, 256)     527192      ['patch_merging_3[0][0]']
#  nTransformerBlock)
#
#  swin_transformer_block_17 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_16[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_merging_4 (patch_merging  (None, 16, 512)     524288      ['swin_transformer_block_17[0][0]
#  )                                                               ']
#
#  swin_transformer_block_18 (Swi  (None, 16, 512)     1578072     ['patch_merging_4[0][0]']
#  nTransformerBlock)
#
#  swin_transformer_block_19 (Swi  (None, 16, 512)     1578136     ['swin_transformer_block_18[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_merging_5 (patch_merging  (None, 4, 1024)     2097152     ['swin_transformer_block_19[0][0]
#  )                                                               ']
#
#  swin_transformer_block_20 (Swi  (None, 4, 1024)     5252696     ['patch_merging_5[0][0]']
#  nTransformerBlock)
#
#  swin_transformer_block_21 (Swi  (None, 4, 1024)     5252712     ['swin_transformer_block_20[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_4 (patch_expan  (None, 16, 512)     2097152     ['swin_transformer_block_21[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_0 (Concatenat  (None, 16, 1024)    0           ['patch_expanding_4[0][0]',
#  e)                                                               'swin_transformer_block_19[0][0]
#                                                                  ']
#
#  swin_unet_concat_linear_proj_0  (None, 16, 512)     524288      ['swin_unet_concat_0[0][0]']
#   (Dense)
#
#  swin_transformer_block_22 (Swi  (None, 16, 512)     1578072     ['swin_unet_concat_linear_proj_0[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_23 (Swi  (None, 16, 512)     1578136     ['swin_transformer_block_22[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_5 (patch_expan  (None, 64, 256)     524288      ['swin_transformer_block_23[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_1 (Concatenat  (None, 64, 512)     0           ['patch_expanding_5[0][0]',
#  e)                                                               'swin_transformer_block_17[0][0]
#                                                                  ']
#
#  swin_unet_concat_linear_proj_1  (None, 64, 256)     131072      ['swin_unet_concat_1[0][0]']
#   (Dense)
#
#  swin_transformer_block_24 (Swi  (None, 64, 256)     527192      ['swin_unet_concat_linear_proj_1[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_25 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_24[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_6 (patch_expan  (None, 256, 128)    131072      ['swin_transformer_block_25[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_2 (Concatenat  (None, 256, 256)    0           ['patch_expanding_6[0][0]',
#  e)                                                               'swin_transformer_block_15[0][0]
#                                                                  ']
#
#  swin_unet_concat_linear_proj_2  (None, 256, 128)    32768       ['swin_unet_concat_2[0][0]']
#   (Dense)
#
#  swin_transformer_block_26 (Swi  (None, 256, 128)    198360      ['swin_unet_concat_linear_proj_2[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_27 (Swi  (None, 256, 128)    199384      ['swin_transformer_block_26[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_7 (patch_expan  (None, 64, 64, 32)  65536       ['swin_transformer_block_27[0][0]
#  ding)                                                           ']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 13)   416         ['patch_expanding_7[0][0]']
#
# ==================================================================================================
# Total params: 26,024,536
# Trainable params: 26,018,056
# Non-trainable params: 6,480
# __________________________________________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/swin-unet_tversky.hdf5',
    verbose=1,
    monitor='val_mean_io_u',
    save_best_only=True,
    save_weights_only=True,
    mode='max'
)

print('\n\t TRAINING\n')

model_history = swin_transformer.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)
# Out:
# 	 TRAINING
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4560 - mean_io_u: 0.6495 - dice_coeficient: 0.5449
# Epoch 1: val_mean_io_u improved from -inf to 0.71199, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 435s 8s/step - loss: 0.4560 - mean_io_u: 0.6495 - dice_coeficient: 0.5449 - val_loss: 0.3509 - val_mean_io_u: 0.7120 - val_dice_coeficient: 0.6501
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2930 - mean_io_u: 0.7532 - dice_coeficient: 0.7075
# Epoch 2: val_mean_io_u improved from 0.71199 to 0.78639, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 428s 8s/step - loss: 0.2930 - mean_io_u: 0.7532 - dice_coeficient: 0.7075 - val_loss: 0.2455 - val_mean_io_u: 0.7864 - val_dice_coeficient: 0.7551
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2188 - mean_io_u: 0.8079 - dice_coeficient: 0.7812
# Epoch 3: val_mean_io_u improved from 0.78639 to 0.82183, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 418s 8s/step - loss: 0.2188 - mean_io_u: 0.8079 - dice_coeficient: 0.7812 - val_loss: 0.2004 - val_mean_io_u: 0.8218 - val_dice_coeficient: 0.8003
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1840 - mean_io_u: 0.8337 - dice_coeficient: 0.8161
# Epoch 4: val_mean_io_u improved from 0.82183 to 0.84292, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 397s 8s/step - loss: 0.1840 - mean_io_u: 0.8337 - dice_coeficient: 0.8161 - val_loss: 0.1665 - val_mean_io_u: 0.8429 - val_dice_coeficient: 0.8340
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1523 - mean_io_u: 0.8544 - dice_coeficient: 0.8477
# Epoch 5: val_mean_io_u improved from 0.84292 to 0.86147, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 397s 8s/step - loss: 0.1523 - mean_io_u: 0.8544 - dice_coeficient: 0.8477 - val_loss: 0.1420 - val_mean_io_u: 0.8615 - val_dice_coeficient: 0.8585
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1278 - mean_io_u: 0.8700 - dice_coeficient: 0.8724
# Epoch 6: val_mean_io_u improved from 0.86147 to 0.87652, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 381s 7s/step - loss: 0.1278 - mean_io_u: 0.8700 - dice_coeficient: 0.8724 - val_loss: 0.1183 - val_mean_io_u: 0.8765 - val_dice_coeficient: 0.8822
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1019 - mean_io_u: 0.8858 - dice_coeficient: 0.8982
# Epoch 7: val_mean_io_u improved from 0.87652 to 0.89302, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 373s 7s/step - loss: 0.1019 - mean_io_u: 0.8858 - dice_coeficient: 0.8982 - val_loss: 0.0929 - val_mean_io_u: 0.8930 - val_dice_coeficient: 0.9074
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0883 - mean_io_u: 0.8962 - dice_coeficient: 0.9117
# Epoch 8: val_mean_io_u improved from 0.89302 to 0.89654, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 387s 8s/step - loss: 0.0883 - mean_io_u: 0.8962 - dice_coeficient: 0.9117 - val_loss: 0.0855 - val_mean_io_u: 0.8965 - val_dice_coeficient: 0.9148
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0817 - mean_io_u: 0.9006 - dice_coeficient: 0.9182
# Epoch 9: val_mean_io_u improved from 0.89654 to 0.90088, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 376s 7s/step - loss: 0.0817 - mean_io_u: 0.9006 - dice_coeficient: 0.9182 - val_loss: 0.0814 - val_mean_io_u: 0.9009 - val_dice_coeficient: 0.9189
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0784 - mean_io_u: 0.9033 - dice_coeficient: 0.9217
# Epoch 10: val_mean_io_u improved from 0.90088 to 0.90378, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 415s 8s/step - loss: 0.0784 - mean_io_u: 0.9033 - dice_coeficient: 0.9217 - val_loss: 0.0790 - val_mean_io_u: 0.9038 - val_dice_coeficient: 0.9214
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0754 - mean_io_u: 0.9059 - dice_coeficient: 0.9246
# Epoch 11: val_mean_io_u improved from 0.90378 to 0.90562, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 380s 7s/step - loss: 0.0754 - mean_io_u: 0.9059 - dice_coeficient: 0.9246 - val_loss: 0.0751 - val_mean_io_u: 0.9056 - val_dice_coeficient: 0.9253
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0715 - mean_io_u: 0.9095 - dice_coeficient: 0.9285
# Epoch 12: val_mean_io_u improved from 0.90562 to 0.90990, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 416s 8s/step - loss: 0.0715 - mean_io_u: 0.9095 - dice_coeficient: 0.9285 - val_loss: 0.0723 - val_mean_io_u: 0.9099 - val_dice_coeficient: 0.9281
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0690 - mean_io_u: 0.9123 - dice_coeficient: 0.9310
# Epoch 13: val_mean_io_u improved from 0.90990 to 0.91218, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 394s 8s/step - loss: 0.0690 - mean_io_u: 0.9123 - dice_coeficient: 0.9310 - val_loss: 0.0700 - val_mean_io_u: 0.9122 - val_dice_coeficient: 0.9303
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0669 - mean_io_u: 0.9151 - dice_coeficient: 0.9331
# Epoch 14: val_mean_io_u improved from 0.91218 to 0.91458, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 410s 8s/step - loss: 0.0669 - mean_io_u: 0.9151 - dice_coeficient: 0.9331 - val_loss: 0.0681 - val_mean_io_u: 0.9146 - val_dice_coeficient: 0.9322
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0623 - mean_io_u: 0.9180 - dice_coeficient: 0.9377
# Epoch 15: val_mean_io_u improved from 0.91458 to 0.92086, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 403s 8s/step - loss: 0.0623 - mean_io_u: 0.9180 - dice_coeficient: 0.9377 - val_loss: 0.0571 - val_mean_io_u: 0.9209 - val_dice_coeficient: 0.9431
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0534 - mean_io_u: 0.9259 - dice_coeficient: 0.9467
# Epoch 16: val_mean_io_u improved from 0.92086 to 0.92770, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 418s 8s/step - loss: 0.0534 - mean_io_u: 0.9259 - dice_coeficient: 0.9467 - val_loss: 0.0523 - val_mean_io_u: 0.9277 - val_dice_coeficient: 0.9479
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0496 - mean_io_u: 0.9299 - dice_coeficient: 0.9505
# Epoch 17: val_mean_io_u improved from 0.92770 to 0.92989, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 398s 8s/step - loss: 0.0496 - mean_io_u: 0.9299 - dice_coeficient: 0.9505 - val_loss: 0.0494 - val_mean_io_u: 0.9299 - val_dice_coeficient: 0.9508
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0474 - mean_io_u: 0.9314 - dice_coeficient: 0.9526
# Epoch 18: val_mean_io_u improved from 0.92989 to 0.93132, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 401s 8s/step - loss: 0.0474 - mean_io_u: 0.9314 - dice_coeficient: 0.9526 - val_loss: 0.0473 - val_mean_io_u: 0.9313 - val_dice_coeficient: 0.9528
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0420 - mean_io_u: 0.9349 - dice_coeficient: 0.9580
# Epoch 19: val_mean_io_u improved from 0.93132 to 0.93630, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 399s 8s/step - loss: 0.0420 - mean_io_u: 0.9349 - dice_coeficient: 0.9580 - val_loss: 0.0411 - val_mean_io_u: 0.9363 - val_dice_coeficient: 0.9590
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0378 - mean_io_u: 0.9396 - dice_coeficient: 0.9623
# Epoch 20: val_mean_io_u improved from 0.93630 to 0.93896, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 397s 8s/step - loss: 0.0378 - mean_io_u: 0.9396 - dice_coeficient: 0.9623 - val_loss: 0.0393 - val_mean_io_u: 0.9390 - val_dice_coeficient: 0.9608
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0355 - mean_io_u: 0.9426 - dice_coeficient: 0.9645
# Epoch 21: val_mean_io_u improved from 0.93896 to 0.94070, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 421s 8s/step - loss: 0.0355 - mean_io_u: 0.9426 - dice_coeficient: 0.9645 - val_loss: 0.0373 - val_mean_io_u: 0.9407 - val_dice_coeficient: 0.9628
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0338 - mean_io_u: 0.9451 - dice_coeficient: 0.9662
# Epoch 22: val_mean_io_u improved from 0.94070 to 0.94407, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 403s 8s/step - loss: 0.0338 - mean_io_u: 0.9451 - dice_coeficient: 0.9662 - val_loss: 0.0356 - val_mean_io_u: 0.9441 - val_dice_coeficient: 0.9645
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0321 - mean_io_u: 0.9476 - dice_coeficient: 0.9679
# Epoch 23: val_mean_io_u improved from 0.94407 to 0.94596, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 403s 8s/step - loss: 0.0321 - mean_io_u: 0.9476 - dice_coeficient: 0.9679 - val_loss: 0.0345 - val_mean_io_u: 0.9460 - val_dice_coeficient: 0.9655
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0310 - mean_io_u: 0.9493 - dice_coeficient: 0.9690
# Epoch 24: val_mean_io_u improved from 0.94596 to 0.94847, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 398s 8s/step - loss: 0.0310 - mean_io_u: 0.9493 - dice_coeficient: 0.9690 - val_loss: 0.0337 - val_mean_io_u: 0.9485 - val_dice_coeficient: 0.9664
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0301 - mean_io_u: 0.9509 - dice_coeficient: 0.9699
# Epoch 25: val_mean_io_u improved from 0.94847 to 0.94915, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 412s 8s/step - loss: 0.0301 - mean_io_u: 0.9509 - dice_coeficient: 0.9699 - val_loss: 0.0324 - val_mean_io_u: 0.9492 - val_dice_coeficient: 0.9676
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0291 - mean_io_u: 0.9524 - dice_coeficient: 0.9709
# Epoch 26: val_mean_io_u improved from 0.94915 to 0.95063, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 409s 8s/step - loss: 0.0291 - mean_io_u: 0.9524 - dice_coeficient: 0.9709 - val_loss: 0.0314 - val_mean_io_u: 0.9506 - val_dice_coeficient: 0.9686
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0282 - mean_io_u: 0.9540 - dice_coeficient: 0.9718
# Epoch 27: val_mean_io_u improved from 0.95063 to 0.95251, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 405s 8s/step - loss: 0.0282 - mean_io_u: 0.9540 - dice_coeficient: 0.9718 - val_loss: 0.0309 - val_mean_io_u: 0.9525 - val_dice_coeficient: 0.9692
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0272 - mean_io_u: 0.9556 - dice_coeficient: 0.9728
# Epoch 28: val_mean_io_u improved from 0.95251 to 0.95311, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 409s 8s/step - loss: 0.0272 - mean_io_u: 0.9556 - dice_coeficient: 0.9728 - val_loss: 0.0304 - val_mean_io_u: 0.9531 - val_dice_coeficient: 0.9697
# Epoch 29/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0264 - mean_io_u: 0.9570 - dice_coeficient: 0.9736
# Epoch 29: val_mean_io_u improved from 0.95311 to 0.95536, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 396s 8s/step - loss: 0.0264 - mean_io_u: 0.9570 - dice_coeficient: 0.9736 - val_loss: 0.0291 - val_mean_io_u: 0.9554 - val_dice_coeficient: 0.9710
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0256 - mean_io_u: 0.9585 - dice_coeficient: 0.9744
# Epoch 30: val_mean_io_u improved from 0.95536 to 0.95633, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 400s 8s/step - loss: 0.0256 - mean_io_u: 0.9585 - dice_coeficient: 0.9744 - val_loss: 0.0288 - val_mean_io_u: 0.9563 - val_dice_coeficient: 0.9713
# Epoch 31/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0250 - mean_io_u: 0.9595 - dice_coeficient: 0.9750
# Epoch 31: val_mean_io_u improved from 0.95633 to 0.95661, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 399s 8s/step - loss: 0.0250 - mean_io_u: 0.9595 - dice_coeficient: 0.9750 - val_loss: 0.0284 - val_mean_io_u: 0.9566 - val_dice_coeficient: 0.9717
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0247 - mean_io_u: 0.9604 - dice_coeficient: 0.9753
# Epoch 32: val_mean_io_u improved from 0.95661 to 0.95859, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 411s 8s/step - loss: 0.0247 - mean_io_u: 0.9604 - dice_coeficient: 0.9753 - val_loss: 0.0277 - val_mean_io_u: 0.9586 - val_dice_coeficient: 0.9724
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0239 - mean_io_u: 0.9617 - dice_coeficient: 0.9761
# Epoch 33: val_mean_io_u improved from 0.95859 to 0.95938, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 398s 8s/step - loss: 0.0239 - mean_io_u: 0.9617 - dice_coeficient: 0.9761 - val_loss: 0.0272 - val_mean_io_u: 0.9594 - val_dice_coeficient: 0.9728
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0231 - mean_io_u: 0.9629 - dice_coeficient: 0.9769
# Epoch 34: val_mean_io_u improved from 0.95938 to 0.96011, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 401s 8s/step - loss: 0.0231 - mean_io_u: 0.9629 - dice_coeficient: 0.9769 - val_loss: 0.0266 - val_mean_io_u: 0.9601 - val_dice_coeficient: 0.9735
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0228 - mean_io_u: 0.9636 - dice_coeficient: 0.9772
# Epoch 35: val_mean_io_u improved from 0.96011 to 0.96098, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 403s 8s/step - loss: 0.0228 - mean_io_u: 0.9636 - dice_coeficient: 0.9772 - val_loss: 0.0265 - val_mean_io_u: 0.9610 - val_dice_coeficient: 0.9735
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0222 - mean_io_u: 0.9646 - dice_coeficient: 0.9778
# Epoch 36: val_mean_io_u improved from 0.96098 to 0.96200, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 403s 8s/step - loss: 0.0222 - mean_io_u: 0.9646 - dice_coeficient: 0.9778 - val_loss: 0.0259 - val_mean_io_u: 0.9620 - val_dice_coeficient: 0.9742
# Epoch 37/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0218 - mean_io_u: 0.9655 - dice_coeficient: 0.9782
# Epoch 37: val_mean_io_u did not improve from 0.96200
# 51/51 [==============================] - 392s 8s/step - loss: 0.0218 - mean_io_u: 0.9655 - dice_coeficient: 0.9782 - val_loss: 0.0257 - val_mean_io_u: 0.9619 - val_dice_coeficient: 0.9744
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0216 - mean_io_u: 0.9662 - dice_coeficient: 0.9785
# Epoch 38: val_mean_io_u improved from 0.96200 to 0.96253, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 396s 8s/step - loss: 0.0216 - mean_io_u: 0.9662 - dice_coeficient: 0.9785 - val_loss: 0.0257 - val_mean_io_u: 0.9625 - val_dice_coeficient: 0.9743
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0212 - mean_io_u: 0.9669 - dice_coeficient: 0.9787
# Epoch 39: val_mean_io_u improved from 0.96253 to 0.96348, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 392s 8s/step - loss: 0.0212 - mean_io_u: 0.9669 - dice_coeficient: 0.9787 - val_loss: 0.0251 - val_mean_io_u: 0.9635 - val_dice_coeficient: 0.9749
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0208 - mean_io_u: 0.9676 - dice_coeficient: 0.9792
# Epoch 40: val_mean_io_u improved from 0.96348 to 0.96464, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 405s 8s/step - loss: 0.0208 - mean_io_u: 0.9676 - dice_coeficient: 0.9792 - val_loss: 0.0248 - val_mean_io_u: 0.9646 - val_dice_coeficient: 0.9753
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0205 - mean_io_u: 0.9683 - dice_coeficient: 0.9795
# Epoch 41: val_mean_io_u improved from 0.96464 to 0.96488, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 396s 8s/step - loss: 0.0205 - mean_io_u: 0.9683 - dice_coeficient: 0.9795 - val_loss: 0.0246 - val_mean_io_u: 0.9649 - val_dice_coeficient: 0.9755
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0203 - mean_io_u: 0.9688 - dice_coeficient: 0.9797
# Epoch 42: val_mean_io_u improved from 0.96488 to 0.96538, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 426s 8s/step - loss: 0.0203 - mean_io_u: 0.9688 - dice_coeficient: 0.9797 - val_loss: 0.0246 - val_mean_io_u: 0.9654 - val_dice_coeficient: 0.9755
# Epoch 43/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0199 - mean_io_u: 0.9695 - dice_coeficient: 0.9801
# Epoch 43: val_mean_io_u improved from 0.96538 to 0.96627, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 459s 9s/step - loss: 0.0199 - mean_io_u: 0.9695 - dice_coeficient: 0.9801 - val_loss: 0.0242 - val_mean_io_u: 0.9663 - val_dice_coeficient: 0.9759
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0197 - mean_io_u: 0.9700 - dice_coeficient: 0.9803
# Epoch 44: val_mean_io_u did not improve from 0.96627
# 51/51 [==============================] - 458s 9s/step - loss: 0.0197 - mean_io_u: 0.9700 - dice_coeficient: 0.9803 - val_loss: 0.0243 - val_mean_io_u: 0.9660 - val_dice_coeficient: 0.9758
# Epoch 45/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0196 - mean_io_u: 0.9704 - dice_coeficient: 0.9804
# Epoch 45: val_mean_io_u improved from 0.96627 to 0.96642, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 461s 9s/step - loss: 0.0196 - mean_io_u: 0.9704 - dice_coeficient: 0.9804 - val_loss: 0.0241 - val_mean_io_u: 0.9664 - val_dice_coeficient: 0.9759
# Epoch 46/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0196 - mean_io_u: 0.9708 - dice_coeficient: 0.9804
# Epoch 46: val_mean_io_u improved from 0.96642 to 0.96685, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 461s 9s/step - loss: 0.0196 - mean_io_u: 0.9708 - dice_coeficient: 0.9804 - val_loss: 0.0240 - val_mean_io_u: 0.9669 - val_dice_coeficient: 0.9760
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0192 - mean_io_u: 0.9715 - dice_coeficient: 0.9808
# Epoch 47: val_mean_io_u improved from 0.96685 to 0.96737, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 452s 9s/step - loss: 0.0192 - mean_io_u: 0.9715 - dice_coeficient: 0.9808 - val_loss: 0.0241 - val_mean_io_u: 0.9674 - val_dice_coeficient: 0.9760
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0193 - mean_io_u: 0.9716 - dice_coeficient: 0.9807
# Epoch 48: val_mean_io_u improved from 0.96737 to 0.96808, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 456s 9s/step - loss: 0.0193 - mean_io_u: 0.9716 - dice_coeficient: 0.9807 - val_loss: 0.0236 - val_mean_io_u: 0.9681 - val_dice_coeficient: 0.9765
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0189 - mean_io_u: 0.9723 - dice_coeficient: 0.9811
# Epoch 49: val_mean_io_u did not improve from 0.96808
# 51/51 [==============================] - 437s 9s/step - loss: 0.0189 - mean_io_u: 0.9723 - dice_coeficient: 0.9811 - val_loss: 0.0236 - val_mean_io_u: 0.9681 - val_dice_coeficient: 0.9765
# Epoch 50/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0187 - mean_io_u: 0.9728 - dice_coeficient: 0.9813
# Epoch 50: val_mean_io_u improved from 0.96808 to 0.96873, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 394s 8s/step - loss: 0.0187 - mean_io_u: 0.9728 - dice_coeficient: 0.9813 - val_loss: 0.0232 - val_mean_io_u: 0.9687 - val_dice_coeficient: 0.9769
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0185 - mean_io_u: 0.9732 - dice_coeficient: 0.9815
# Epoch 51: val_mean_io_u improved from 0.96873 to 0.96887, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 393s 8s/step - loss: 0.0185 - mean_io_u: 0.9732 - dice_coeficient: 0.9815 - val_loss: 0.0232 - val_mean_io_u: 0.9689 - val_dice_coeficient: 0.9769
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0183 - mean_io_u: 0.9736 - dice_coeficient: 0.9817
# Epoch 52: val_mean_io_u improved from 0.96887 to 0.96945, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 392s 8s/step - loss: 0.0183 - mean_io_u: 0.9736 - dice_coeficient: 0.9817 - val_loss: 0.0231 - val_mean_io_u: 0.9694 - val_dice_coeficient: 0.9770
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0183 - mean_io_u: 0.9738 - dice_coeficient: 0.9817
# Epoch 53: val_mean_io_u improved from 0.96945 to 0.96949, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 401s 8s/step - loss: 0.0183 - mean_io_u: 0.9738 - dice_coeficient: 0.9817 - val_loss: 0.0232 - val_mean_io_u: 0.9695 - val_dice_coeficient: 0.9769
# Epoch 54/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0182 - mean_io_u: 0.9742 - dice_coeficient: 0.9818
# Epoch 54: val_mean_io_u improved from 0.96949 to 0.96981, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 397s 8s/step - loss: 0.0182 - mean_io_u: 0.9742 - dice_coeficient: 0.9818 - val_loss: 0.0232 - val_mean_io_u: 0.9698 - val_dice_coeficient: 0.9769
# Epoch 55/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0179 - mean_io_u: 0.9747 - dice_coeficient: 0.9821
# Epoch 55: val_mean_io_u improved from 0.96981 to 0.97040, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 399s 8s/step - loss: 0.0179 - mean_io_u: 0.9747 - dice_coeficient: 0.9821 - val_loss: 0.0228 - val_mean_io_u: 0.9704 - val_dice_coeficient: 0.9772
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0179 - mean_io_u: 0.9750 - dice_coeficient: 0.9821
# Epoch 56: val_mean_io_u improved from 0.97040 to 0.97045, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 410s 8s/step - loss: 0.0179 - mean_io_u: 0.9750 - dice_coeficient: 0.9821 - val_loss: 0.0227 - val_mean_io_u: 0.9704 - val_dice_coeficient: 0.9774
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0177 - mean_io_u: 0.9753 - dice_coeficient: 0.9823
# Epoch 57: val_mean_io_u improved from 0.97045 to 0.97072, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 439s 9s/step - loss: 0.0177 - mean_io_u: 0.9753 - dice_coeficient: 0.9823 - val_loss: 0.0228 - val_mean_io_u: 0.9707 - val_dice_coeficient: 0.9772
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0176 - mean_io_u: 0.9756 - dice_coeficient: 0.9824
# Epoch 58: val_mean_io_u improved from 0.97072 to 0.97101, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 430s 8s/step - loss: 0.0176 - mean_io_u: 0.9756 - dice_coeficient: 0.9824 - val_loss: 0.0227 - val_mean_io_u: 0.9710 - val_dice_coeficient: 0.9774
# Epoch 59/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0176 - mean_io_u: 0.9758 - dice_coeficient: 0.9824
# Epoch 59: val_mean_io_u improved from 0.97101 to 0.97107, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 422s 8s/step - loss: 0.0176 - mean_io_u: 0.9758 - dice_coeficient: 0.9824 - val_loss: 0.0228 - val_mean_io_u: 0.9711 - val_dice_coeficient: 0.9773
# Epoch 60/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0175 - mean_io_u: 0.9761 - dice_coeficient: 0.9825
# Epoch 60: val_mean_io_u improved from 0.97107 to 0.97167, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 404s 8s/step - loss: 0.0175 - mean_io_u: 0.9761 - dice_coeficient: 0.9825 - val_loss: 0.0224 - val_mean_io_u: 0.9717 - val_dice_coeficient: 0.9777
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0175 - mean_io_u: 0.9763 - dice_coeficient: 0.9825
# Epoch 61: val_mean_io_u improved from 0.97167 to 0.97175, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 441s 9s/step - loss: 0.0175 - mean_io_u: 0.9763 - dice_coeficient: 0.9825 - val_loss: 0.0225 - val_mean_io_u: 0.9718 - val_dice_coeficient: 0.9776
# Epoch 62/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0172 - mean_io_u: 0.9767 - dice_coeficient: 0.9827
# Epoch 62: val_mean_io_u did not improve from 0.97175
# 51/51 [==============================] - 434s 9s/step - loss: 0.0172 - mean_io_u: 0.9767 - dice_coeficient: 0.9827 - val_loss: 0.0227 - val_mean_io_u: 0.9716 - val_dice_coeficient: 0.9774
# Epoch 63/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0172 - mean_io_u: 0.9769 - dice_coeficient: 0.9828
# Epoch 63: val_mean_io_u improved from 0.97175 to 0.97201, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 435s 9s/step - loss: 0.0172 - mean_io_u: 0.9769 - dice_coeficient: 0.9828 - val_loss: 0.0224 - val_mean_io_u: 0.9720 - val_dice_coeficient: 0.9777
# Epoch 64/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0172 - mean_io_u: 0.9771 - dice_coeficient: 0.9828
# Epoch 64: val_mean_io_u improved from 0.97201 to 0.97219, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.0172 - mean_io_u: 0.9771 - dice_coeficient: 0.9828 - val_loss: 0.0225 - val_mean_io_u: 0.9722 - val_dice_coeficient: 0.9776
# Epoch 65/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0172 - mean_io_u: 0.9772 - dice_coeficient: 0.9828
# Epoch 65: val_mean_io_u improved from 0.97219 to 0.97241, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 433s 9s/step - loss: 0.0172 - mean_io_u: 0.9772 - dice_coeficient: 0.9828 - val_loss: 0.0224 - val_mean_io_u: 0.9724 - val_dice_coeficient: 0.9777
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0171 - mean_io_u: 0.9775 - dice_coeficient: 0.9829
# Epoch 66: val_mean_io_u improved from 0.97241 to 0.97246, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 436s 9s/step - loss: 0.0171 - mean_io_u: 0.9775 - dice_coeficient: 0.9829 - val_loss: 0.0222 - val_mean_io_u: 0.9725 - val_dice_coeficient: 0.9778
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0171 - mean_io_u: 0.9776 - dice_coeficient: 0.9829
# Epoch 67: val_mean_io_u did not improve from 0.97246
# 51/51 [==============================] - 434s 9s/step - loss: 0.0171 - mean_io_u: 0.9776 - dice_coeficient: 0.9829 - val_loss: 0.0226 - val_mean_io_u: 0.9724 - val_dice_coeficient: 0.9775
# Epoch 68/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0170 - mean_io_u: 0.9779 - dice_coeficient: 0.9830
# Epoch 68: val_mean_io_u improved from 0.97246 to 0.97298, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 437s 9s/step - loss: 0.0170 - mean_io_u: 0.9779 - dice_coeficient: 0.9830 - val_loss: 0.0222 - val_mean_io_u: 0.9730 - val_dice_coeficient: 0.9779
# Epoch 69/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0170 - mean_io_u: 0.9780 - dice_coeficient: 0.9830
# Epoch 69: val_mean_io_u did not improve from 0.97298
# 51/51 [==============================] - 427s 8s/step - loss: 0.0170 - mean_io_u: 0.9780 - dice_coeficient: 0.9830 - val_loss: 0.0224 - val_mean_io_u: 0.9728 - val_dice_coeficient: 0.9776
# Epoch 70/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0170 - mean_io_u: 0.9782 - dice_coeficient: 0.9830
# Epoch 70: val_mean_io_u improved from 0.97298 to 0.97314, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 404s 8s/step - loss: 0.0170 - mean_io_u: 0.9782 - dice_coeficient: 0.9830 - val_loss: 0.0222 - val_mean_io_u: 0.9731 - val_dice_coeficient: 0.9779
# Epoch 71/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0168 - mean_io_u: 0.9785 - dice_coeficient: 0.9832
# Epoch 71: val_mean_io_u improved from 0.97314 to 0.97320, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 409s 8s/step - loss: 0.0168 - mean_io_u: 0.9785 - dice_coeficient: 0.9832 - val_loss: 0.0223 - val_mean_io_u: 0.9732 - val_dice_coeficient: 0.9778
# Epoch 72/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0169 - mean_io_u: 0.9785 - dice_coeficient: 0.9831
# Epoch 72: val_mean_io_u did not improve from 0.97320
# 51/51 [==============================] - 423s 8s/step - loss: 0.0169 - mean_io_u: 0.9785 - dice_coeficient: 0.9831 - val_loss: 0.0225 - val_mean_io_u: 0.9731 - val_dice_coeficient: 0.9776
# Epoch 73/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0169 - mean_io_u: 0.9787 - dice_coeficient: 0.9831
# Epoch 73: val_mean_io_u improved from 0.97320 to 0.97352, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.0169 - mean_io_u: 0.9787 - dice_coeficient: 0.9831 - val_loss: 0.0223 - val_mean_io_u: 0.9735 - val_dice_coeficient: 0.9778
# Epoch 74/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0168 - mean_io_u: 0.9788 - dice_coeficient: 0.9831
# Epoch 74: val_mean_io_u did not improve from 0.97352
# 51/51 [==============================] - 434s 9s/step - loss: 0.0168 - mean_io_u: 0.9788 - dice_coeficient: 0.9831 - val_loss: 0.0224 - val_mean_io_u: 0.9734 - val_dice_coeficient: 0.9777
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0168 - mean_io_u: 0.9790 - dice_coeficient: 0.9832
# Epoch 75: val_mean_io_u did not improve from 0.97352
# 51/51 [==============================] - 429s 8s/step - loss: 0.0168 - mean_io_u: 0.9790 - dice_coeficient: 0.9832 - val_loss: 0.0224 - val_mean_io_u: 0.9735 - val_dice_coeficient: 0.9776
# Epoch 76/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0168 - mean_io_u: 0.9790 - dice_coeficient: 0.9831
# Epoch 76: val_mean_io_u did not improve from 0.97352
# 51/51 [==============================] - 434s 9s/step - loss: 0.0168 - mean_io_u: 0.9790 - dice_coeficient: 0.9831 - val_loss: 0.0224 - val_mean_io_u: 0.9735 - val_dice_coeficient: 0.9777
# Epoch 77/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0168 - mean_io_u: 0.9791 - dice_coeficient: 0.9832
# Epoch 77: val_mean_io_u improved from 0.97352 to 0.97398, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 432s 8s/step - loss: 0.0168 - mean_io_u: 0.9791 - dice_coeficient: 0.9832 - val_loss: 0.0222 - val_mean_io_u: 0.9740 - val_dice_coeficient: 0.9779
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0168 - mean_io_u: 0.9792 - dice_coeficient: 0.9832
# Epoch 78: val_mean_io_u improved from 0.97398 to 0.97409, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 430s 8s/step - loss: 0.0168 - mean_io_u: 0.9792 - dice_coeficient: 0.9832 - val_loss: 0.0221 - val_mean_io_u: 0.9741 - val_dice_coeficient: 0.9780
# Epoch 79/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9795 - dice_coeficient: 0.9833
# Epoch 79: val_mean_io_u improved from 0.97409 to 0.97412, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 434s 9s/step - loss: 0.0167 - mean_io_u: 0.9795 - dice_coeficient: 0.9833 - val_loss: 0.0222 - val_mean_io_u: 0.9741 - val_dice_coeficient: 0.9779
# Epoch 80/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0166 - mean_io_u: 0.9797 - dice_coeficient: 0.9834
# Epoch 80: val_mean_io_u improved from 0.97412 to 0.97419, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 424s 8s/step - loss: 0.0166 - mean_io_u: 0.9797 - dice_coeficient: 0.9834 - val_loss: 0.0222 - val_mean_io_u: 0.9742 - val_dice_coeficient: 0.9779
# Epoch 81/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0166 - mean_io_u: 0.9798 - dice_coeficient: 0.9834
# Epoch 81: val_mean_io_u improved from 0.97419 to 0.97432, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 393s 8s/step - loss: 0.0166 - mean_io_u: 0.9798 - dice_coeficient: 0.9834 - val_loss: 0.0222 - val_mean_io_u: 0.9743 - val_dice_coeficient: 0.9779
# Epoch 82/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0166 - mean_io_u: 0.9798 - dice_coeficient: 0.9834
# Epoch 82: val_mean_io_u improved from 0.97432 to 0.97433, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 393s 8s/step - loss: 0.0166 - mean_io_u: 0.9798 - dice_coeficient: 0.9834 - val_loss: 0.0222 - val_mean_io_u: 0.9743 - val_dice_coeficient: 0.9779
# Epoch 83/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9799 - dice_coeficient: 0.9834
# Epoch 83: val_mean_io_u improved from 0.97433 to 0.97453, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 396s 8s/step - loss: 0.0167 - mean_io_u: 0.9799 - dice_coeficient: 0.9834 - val_loss: 0.0221 - val_mean_io_u: 0.9745 - val_dice_coeficient: 0.9780
# Epoch 84/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0165 - mean_io_u: 0.9801 - dice_coeficient: 0.9835
# Epoch 84: val_mean_io_u did not improve from 0.97453
# 51/51 [==============================] - 397s 8s/step - loss: 0.0165 - mean_io_u: 0.9801 - dice_coeficient: 0.9835 - val_loss: 0.0222 - val_mean_io_u: 0.9745 - val_dice_coeficient: 0.9779
# Epoch 85/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0166 - mean_io_u: 0.9801 - dice_coeficient: 0.9834
# Epoch 85: val_mean_io_u did not improve from 0.97453
# 51/51 [==============================] - 401s 8s/step - loss: 0.0166 - mean_io_u: 0.9801 - dice_coeficient: 0.9834 - val_loss: 0.0223 - val_mean_io_u: 0.9744 - val_dice_coeficient: 0.9778
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9801 - dice_coeficient: 0.9833
# Epoch 86: val_mean_io_u did not improve from 0.97453
# 51/51 [==============================] - 412s 8s/step - loss: 0.0167 - mean_io_u: 0.9801 - dice_coeficient: 0.9833 - val_loss: 0.0223 - val_mean_io_u: 0.9745 - val_dice_coeficient: 0.9778
# Epoch 87/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0165 - mean_io_u: 0.9803 - dice_coeficient: 0.9835
# Epoch 87: val_mean_io_u improved from 0.97453 to 0.97468, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 392s 8s/step - loss: 0.0165 - mean_io_u: 0.9803 - dice_coeficient: 0.9835 - val_loss: 0.0222 - val_mean_io_u: 0.9747 - val_dice_coeficient: 0.9779
# Epoch 88/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0165 - mean_io_u: 0.9803 - dice_coeficient: 0.9835
# Epoch 88: val_mean_io_u improved from 0.97468 to 0.97475, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 372s 7s/step - loss: 0.0165 - mean_io_u: 0.9803 - dice_coeficient: 0.9835 - val_loss: 0.0222 - val_mean_io_u: 0.9748 - val_dice_coeficient: 0.9779
# Epoch 89/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0168 - mean_io_u: 0.9802 - dice_coeficient: 0.9832
# Epoch 89: val_mean_io_u did not improve from 0.97475
# 51/51 [==============================] - 402s 8s/step - loss: 0.0168 - mean_io_u: 0.9802 - dice_coeficient: 0.9832 - val_loss: 0.0224 - val_mean_io_u: 0.9746 - val_dice_coeficient: 0.9777
# Epoch 90/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9803 - dice_coeficient: 0.9833
# Epoch 90: val_mean_io_u improved from 0.97475 to 0.97482, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 411s 8s/step - loss: 0.0167 - mean_io_u: 0.9803 - dice_coeficient: 0.9833 - val_loss: 0.0222 - val_mean_io_u: 0.9748 - val_dice_coeficient: 0.9779
# Epoch 91/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9804 - dice_coeficient: 0.9833
# Epoch 91: val_mean_io_u improved from 0.97482 to 0.97494, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 414s 8s/step - loss: 0.0167 - mean_io_u: 0.9804 - dice_coeficient: 0.9833 - val_loss: 0.0222 - val_mean_io_u: 0.9749 - val_dice_coeficient: 0.9779
# Epoch 92/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0166 - mean_io_u: 0.9806 - dice_coeficient: 0.9835
# Epoch 92: val_mean_io_u did not improve from 0.97494
# 51/51 [==============================] - 413s 8s/step - loss: 0.0166 - mean_io_u: 0.9806 - dice_coeficient: 0.9835 - val_loss: 0.0222 - val_mean_io_u: 0.9749 - val_dice_coeficient: 0.9778
# Epoch 93/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0166 - mean_io_u: 0.9806 - dice_coeficient: 0.9834
# Epoch 93: val_mean_io_u improved from 0.97494 to 0.97511, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 411s 8s/step - loss: 0.0166 - mean_io_u: 0.9806 - dice_coeficient: 0.9834 - val_loss: 0.0221 - val_mean_io_u: 0.9751 - val_dice_coeficient: 0.9780
# Epoch 94/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0166 - mean_io_u: 0.9807 - dice_coeficient: 0.9834
# Epoch 94: val_mean_io_u did not improve from 0.97511
# 51/51 [==============================] - 435s 9s/step - loss: 0.0166 - mean_io_u: 0.9807 - dice_coeficient: 0.9834 - val_loss: 0.0224 - val_mean_io_u: 0.9749 - val_dice_coeficient: 0.9777
# Epoch 95/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0166 - mean_io_u: 0.9808 - dice_coeficient: 0.9834
# Epoch 95: val_mean_io_u did not improve from 0.97511
# 51/51 [==============================] - 430s 8s/step - loss: 0.0166 - mean_io_u: 0.9808 - dice_coeficient: 0.9834 - val_loss: 0.0223 - val_mean_io_u: 0.9749 - val_dice_coeficient: 0.9778
# Epoch 96/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0166 - mean_io_u: 0.9807 - dice_coeficient: 0.9834
# Epoch 96: val_mean_io_u did not improve from 0.97511
# 51/51 [==============================] - 431s 8s/step - loss: 0.0166 - mean_io_u: 0.9807 - dice_coeficient: 0.9834 - val_loss: 0.0226 - val_mean_io_u: 0.9746 - val_dice_coeficient: 0.9774
# Epoch 97/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9807 - dice_coeficient: 0.9834
# Epoch 97: val_mean_io_u did not improve from 0.97511
# 51/51 [==============================] - 430s 8s/step - loss: 0.0167 - mean_io_u: 0.9807 - dice_coeficient: 0.9834 - val_loss: 0.0225 - val_mean_io_u: 0.9748 - val_dice_coeficient: 0.9775
# Epoch 98/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9808 - dice_coeficient: 0.9833
# Epoch 98: val_mean_io_u improved from 0.97511 to 0.97514, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 426s 8s/step - loss: 0.0167 - mean_io_u: 0.9808 - dice_coeficient: 0.9833 - val_loss: 0.0222 - val_mean_io_u: 0.9751 - val_dice_coeficient: 0.9779
# Epoch 99/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0166 - mean_io_u: 0.9809 - dice_coeficient: 0.9834
# Epoch 99: val_mean_io_u improved from 0.97514 to 0.97517, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 422s 8s/step - loss: 0.0166 - mean_io_u: 0.9809 - dice_coeficient: 0.9834 - val_loss: 0.0223 - val_mean_io_u: 0.9752 - val_dice_coeficient: 0.9778
# Epoch 100/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0165 - mean_io_u: 0.9810 - dice_coeficient: 0.9834
# Epoch 100: val_mean_io_u improved from 0.97517 to 0.97527, saving model to ../models\swin-unet_tversky.hdf5
# 51/51 [==============================] - 435s 9s/step - loss: 0.0165 - mean_io_u: 0.9810 - dice_coeficient: 0.9834 - val_loss: 0.0222 - val_mean_io_u: 0.9753 - val_dice_coeficient: 0.9779

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='lower right')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/swin-unet_Weights.hdf5')

# %%
pred = swin_transformer.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 37s 589ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1), cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx], cmap='afmhot', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
# --
# **TFG - Adrián Contreras Castillo**
# --
